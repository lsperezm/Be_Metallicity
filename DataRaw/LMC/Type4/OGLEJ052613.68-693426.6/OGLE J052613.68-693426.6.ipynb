# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
mu_cent='../../Mu_Centauri/ADP.2016-09-21T11:56:32.916.fits'
fnameH='../../Type4/OGLEJ052613.68-693426.6/Harps2007_Uves/ADP.2014-09-17T11:24:09.703.fits'
fnameU='../../Type4/OGLEJ052613.68-693426.6/Harps2007_Uves/ADP.2021-02-01T09:57:01.813.fits'

# %%
fits.getheader(fnameU)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2021-01-25T09:32:29' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# TELESCOP= 'ESO-VLT-U2'         / ESO Telescope Name
# INSTRUME= 'UVES    '           / Instrument used.
# RA      =            81.594796 / 05:26:22.7 RA (J2000) pointing
# DEC     =            -69.60185 / -69:36:06.6 DEC (J2000) pointing
# EQUINOX =                2000. / Standard FK5
# RADECSYS= 'FK5     '           / Coordinate reference frame
# MJD-OBS =      59163.157367788 / MJD start (2020-11-10T03:46:36.577)
# DATE-OBS= '2020-11-10T03:46:36.576' / Date of observation
# ...

# %%
fits.info(fname)
# Out:
# Filename: ../../Type4/OGLEJ052613.68-693426.6/Harps2007_Uves/ADP.2014-09-17T11:24:09.703.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    3051   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [313134D, 313134E, 313134E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fnameU)
cent=fits.getdata(mu_cent)

# %%
plt.figure(figsize=(15,5))
plt.plot(xd['WAVE'][0],xd['FLUX'][0],color='black')
plt.plot(cent['WAVE'][0],cent['FLUX'][0]+40, color='red')
plt.ylim(-.1,100)
plt.xlim(6440, 6680)#H-alpha
plt.margins(x=0)
