# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../DataRaw/SMC/OGLEJ003715.60-734546.0/ADP.2016-09-21T06:49:35.170.fits'

# %%
#fits.getheader(fname)

# %%
fits.info(fname)
# Out:
# Filename: ../../DataRaw/SMC/OGLEJ003715.60-734546.0/ADP.2016-09-21T06:49:35.170.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     457   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [94820D, 94820E, 94820E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([3527.39999863, 3527.45999863, 3527.51999862, ..., 9216.41987147, 9216.47987147, 9216.53987146], [ 0.00000000e+00,  6.81812704e-01,  7.47388303e-01, ..., -2.53756507e-03,  0.00000000e+00,  0.00000000e+00], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (94820,)), ('FLUX', '>f4', (94820,)), ('ERR', '>f4', (94820,))]))

# %%
plt.figure(figsize=(70,15))
plt.plot(xd['WAVE'][0],xd['FLUX'][0],'.-')
plt.ylim(-.1,1)
plt.xlim(6625,6650)
plt.margins(x=0)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
