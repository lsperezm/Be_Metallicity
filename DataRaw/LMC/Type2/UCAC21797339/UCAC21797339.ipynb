# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../Type2/UCAC21797339/ADP.2016-09-21T06:49:35.172.fits'
centauri='../../Mu_Centauri/ADP.2016-09-21T11:56:32.916.fits'
uves_='../../Type2/UCAC21797339/UVES/ADP.2021-02-01T09:55:45.855.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / Written by IDL:  Mon Sep 19 22:24:06 2016
# BITPIX  =                    8
# NAXIS   =                    0
# EXTEND  =                    T / File contains extensions
# DATASUM = '         0'         / data unit checksum updated 2016-09-19T22:24:06
# ORIGIN  = 'ESO-LASILLA'        / Origin
# FILENAME= 'f18021.bdf'         / Original file base-name
# OBJECT  = '69d59   '           / Object
# RA      =            75.752428 / [deg] Right ascension
# DEC     =            -69.03076 / [deg] Declination
# EQUINOX =               2000.0 / Equinox
# DATE-OBS= '2004-12-27T06:39:05.358' / Start of observation
# MJD-OBS =       53366.27714535 / [d] Start of observation
# TM-START=       23945.35824086 / MIDAS desc.: O_TIME(5)
# EXPTIME =            1799.9999 / [s] Total integration time
# TELESCOP= 'MPG/ESO-2.2'        / Telescope
# INSTRUME= 'FEROS   '           / Instrument
# RADECSYS= 'FK5     '           / Reference frame
# ...

# %%
fits.info(fname)
# Out:
# Filename: ../../Type2/UCAC21797339/ADP.2016-09-21T06:49:35.172.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     457   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [189642D, 189642E, 189642E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
cent=fits.getdata(centauri)
uves=fits.getdata(uves_)

# %%
plt.figure(figsize=(15,5))
plt.plot(xd['WAVE'][0],xd['FLUX'][0]*100,color='black')
plt.plot(uves['WAVE'][0],uves['FLUX'][0]-23,color='blue')
plt.plot(cent['WAVE'][0],cent['FLUX'][0]-3,color='red')

plt.ylim(-20,40)
plt.xlim(6440, 6680)#H-alpha
#plt.xlim(6630,6640)
plt.margins(x=0)
