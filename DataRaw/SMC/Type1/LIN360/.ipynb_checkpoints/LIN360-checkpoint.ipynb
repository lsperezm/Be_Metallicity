# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
fname='../../Type1/LIN360/ADP.2020-08-14T15:43:54.025.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2020-08-07T20:45:36' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# MJD-OBS =       52217.17164645 / MJD start (2001-11-04T04:07:10.253)
# DATE-OBS= '2001-11-04T04:07:10.253' / Date of observation
# INSTRUME= 'UVES    '           / Instrument used
# OBSERVER= 'UNKNOWN '           / Name of observer
# PI-COI  = 'UNKNOWN '           / Name of PI-COI
# TELESCOP= 'ESO-VLT-U2'         / ESO Telescope Name
# RA      =            14.746629 / 00:58:59.1 RA (J2000) pointing (deg)
# DEC     =             -72.7438 / -72:44:37.6 DEC (J2000) pointing (deg)
# EQUINOX =                2000. / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# LST     =             8246.373 / 02:17:26.373 LST at start (sec)
# UTC     =               14710. / 04:05:10.000 UTC at start (sec)
# ARCFILE = 'ADP.2020-08-14T15:43:54.025.fits' / Archive File Name
# PIPEFILE= 'r.UVES.2001-11-04T04:07:10.253_0000.fits' / no comment
# EXPTIME =            2000.0007 / Total integration time
# ORIGIN  = 'ESO     '           / European Southern Observatory
# PRODLVL =                    2 / Product level: 1-raw 2-science grade 3-advanced
# DISPELEM= 'CD#4    '
# SPECSYS = 'TOPOCENT'
# OBJECT  = 'av216   '           / Original target
# TEXPTIME=            2000.0007 / [s] Total integration time of all exposures
# EXT_OBJ =                    F / Extended object
# MJD-END =    52217.19479460625 / MJD of the last of the stop times
# PROG_ID = '68.D-0369(A)'
# OBID1   =            200112761 / Observation block ID
# M_EPOCH =                    F / T if resulting from multiple epochs
# PROV1   = 'UVES.2001-11-04T04:07:10.253.fits'
# PROCSOFT= 'uves/5.10.13'
# OBSTECH = 'ECHELLE '
# PRODCATG= 'SCIENCE.SPECTRUM'
# FLUXCAL = 'UNCALIBRATED'
# CONTNORM=                    F / T if normalised to the continuum
# WAVELMIN=             581.8723 / [nm] Minimum wavelength
# WAVELMAX=             961.1529 / [nm] Maximum wavelength
# SPEC_BIN=               0.0019 / [nm] Wavelength bin size
# SPEC_ERR=                4E-05
# SPEC_SYE=                2E-05
# TOT_FLUX=                    F / T if photom. cond. and all src flux captured
# FLUXERR =                   -2 / Uncertainty in flux scale (%)
# NCOMBINE=                    1 / # of combined raw science data files
# REFERENC= ''
# SNR     =              19.6097 / Median signal to noise ratio per order
# SPEC_RES=              30360.0 / Reference spectral resolving power
# DETRON  =                 3.69 / Readout noise per output (e-)
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.7' / OBS Dictionary
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PI-COI ID = 7655 / ESO internal PI-COI ID
# HIERARCH ESO OBS TARG NAME = 'av216   ' / OB target name
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS NAME = 'av216   ' / OB name
# HIERARCH ESO OBS ID = 200112761 / Observation block ID
# HIERARCH ESO OBS PROG ID = '68.D-0369(A)' / ESO program identification
# HIERARCH ESO OBS START = '2001-11-04T04:00:08' / OB start time
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.4' / Data dictionary for TPL
# HIERARCH ESO TPL ID = 'UVES_dic2_obs_expfree' / Template signature ID
# HIERARCH ESO TPL NAME = 'Dic2 Free Observation' / Template name
# HIERARCH ESO TPL PRESEQ = 'UVES_dic_obs.seq' / Sequencer script
# HIERARCH ESO TPL START = '2001-11-04T04:04:47' / TPL start time
# HIERARCH ESO TPL VERSION = '@(#) {Revision: 1.1$}' / Version of the template
# HIERARCH ESO TPL NEXP =      1 / Number of exposures within templat
# HIERARCH ESO TPL EXPNO =     1 / Exposure number within template
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL ID = 'v 1.370 ' / TCS version number
# HIERARCH ESO TEL DATE = 'not set ' / TCS installation date
# HIERARCH ESO TEL ALT =  40.713 / Alt angle at start (deg)
# HIERARCH ESO TEL AZ =    7.538 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL GEOELEV = 2648. / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -24.6254 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.403 / Tel geo longitute (+=East) (deg)
# HIERARCH ESO TEL OPER = 'I, Condor' / Telescope Operator
# HIERARCH ESO TEL FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 120. / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 1.718 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = -29.898 / M2 setting (mm)
# HIERARCH ESO TEL PARANG START = 23.683 / Parallactic angle at start (deg)
# HIERARCH ESO TEL AIRM START = 1.531 / Airmass at start
# HIERARCH ESO TEL AMBI FWHM START = 0.97 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES START = 743.98 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI WINDSP = 3.8 / Observatory ambient wind speed que
# HIERARCH ESO TEL AMBI WINDDIR = 101. / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI RHUM = 11. / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 11.56 / Observatory ambient temperature qu
# HIERARCH ESO TEL MOON RA = 50549.079825 / ~~:~~:~~.~ RA (J2000) (deg)
# HIERARCH ESO TEL MOON DEC = 222521.66713 / ~~:~~:~~.~ DEC (J2000) (deg)
# HIERARCH ESO TEL TH M1 TEMP = 10.05 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL CHOP ST =   F / True when chopping is active
# HIERARCH ESO TEL PARANG END = 33.518 / Parallactic angle at end (deg)
# HIERARCH ESO TEL AIRM END = 1.569 / Airmass at end
# HIERARCH ESO TEL AMBI FWHM END = 0.83 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES END = 743.95 / Observatory ambient air pressure q
# HIERARCH ESO INS ID = 'UVES    ' / Instrument ID
# HIERARCH ESO INS DID = 'UVES_ICS' / Data dictionary for INS
# HIERARCH ESO INS SOFW ID = '$Revision: 1.96 $' / Instrument SW
# HIERARCH ESO INS SOFW MODE = 'NORMAL  ' / Simulation mode
# HIERARCH ESO INS PATH = 'RED     ' / Optical path used
# HIERARCH ESO INS MODE = 'DICHR#2 ' / Instrument mode used
# HIERARCH ESO INS MIRR1 ID = 'FREE    ' / Mirror unique ID
# HIERARCH ESO INS MIRR1 NAME = 'FREE    ' / Mirror common name
# HIERARCH ESO INS MIRR1 NO =  1 / Mirror slide position
# HIERARCH ESO INS OPTI1 ID = '1       ' / General Optical device unique ID
# HIERARCH ESO INS OPTI1 NAME = 'OUT     ' / General Optical device common name
# HIERARCH ESO INS OPTI1 NO =  1 / Slot number
# HIERARCH ESO INS OPTI1 TYPE = 'FREE    ' / General Optical device Element
# HIERARCH ESO INS SLIT1 NAME = 'FREE    ' / Slit common name
# HIERARCH ESO INS SLIT1 NO =  1 / Slide position
# HIERARCH ESO INS SLIT1 WID = 0. / Slit width (arcsec)
# HIERARCH ESO INS SLIT1 LEN = 0. / Slit length (arcsec)
# HIERARCH ESO INS DROT MODE = 'ELEV    ' / Instrument derotator mode
# HIERARCH ESO INS DROT RA = 5859.19094 / %HOURANG RA (J2000) pointing (deg)
# HIERARCH ESO INS DROT DEC = -724437.696735 / %DEGREE DEC (J2000) pointing (de
# HIERARCH ESO INS DROT POSANG = 0. / Position angle (deg)
# HIERARCH ESO INS DROT BEGIN = 159.652 / Physical position at start (deg)
# HIERARCH ESO INS DPOL MODE = 'OFF     ' / Instrument depolarizer mode
# HIERARCH ESO INS DPOS NAME = 'OUT     ' / Instrument depolarizer slide posit
# HIERARCH ESO INS DPOS NO =   1 / Depolarizer slide position
# HIERARCH ESO INS ADC MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADCS NAME = 'OUT     ' / ADC slide position
# HIERARCH ESO INS ADCS NO =   1 / ADC slide position
# HIERARCH ESO INS ADC1 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC1 RA = 5859.19094 / %HOURANG RA (J2000) pointing (deg)
# HIERARCH ESO INS ADC1 DEC = -724437.696735 / %DEGREE DEC (J2000) pointing (de
# HIERARCH ESO INS ADC2 MODE = 'OFF     ' / ADC mode
# HIERARCH ESO INS ADC2 RA = 5859.19094 / %HOURANG RA (J2000) pointing (deg)
# HIERARCH ESO INS ADC2 DEC = -724437.696735 / %DEGREE DEC (J2000) pointing (de
# HIERARCH ESO INS FILT1 ID = 'FREE    ' / Filter unique id
# HIERARCH ESO INS FILT1 NAME = 'FREE    ' / Filter common name
# HIERARCH ESO INS FILT1 NO = 13 / Filter wheel position index
# HIERARCH ESO INS OPTI2 ID = 'DIAPHR.27MM' / General Optical device unique ID
# HIERARCH ESO INS OPTI2 NAME = 'OVRSIZ  ' / General Optical device common name
# HIERARCH ESO INS OPTI2 NO =  3 / Slot number
# HIERARCH ESO INS OPTI2 TYPE = 'SLIDE   ' / General Optical device Element
# HIERARCH ESO INS MIRR2 ID = 'DICHR#2 ' / Mirror unique ID
# HIERARCH ESO INS MIRR2 NAME = 'DICHR#2 ' / Mirror common name
# HIERARCH ESO INS MIRR2 NO =  4 / Mirror slide position
# HIERARCH ESO INS SHUT1 ID = 'TSH     ' / Shutter ID
# HIERARCH ESO INS SHUT1 NAME = 'Telescope shutter' / Shutter name
# HIERARCH ESO INS SHUT1 ST =  T / Shutter open
# HIERARCH ESO INS SHUT2 ID = 'SPSH    ' / Shutter ID
# HIERARCH ESO INS SHUT2 NAME = 'SPHERE_SHUTTER' / Shutter name
# HIERARCH ESO INS SHUT3 ID = 'TSH3    ' / Shutter ID
# HIERARCH ESO INS SHUT3 NAME = 'D2L_SHUTTER' / Shutter name
# HIERARCH ESO INS SHUT4 ID = 'TSH4    ' / Shutter ID
# HIERARCH ESO INS SHUT4 NAME = 'THAR_SHUTTER' / Shutter name
# HIERARCH ESO INS SLIT3 WID = 1.5 / Slit width (arcsec)
# HIERARCH ESO INS SLIT3 Y1FRML = 'ENC=OFFST+RESOL*acos(WID-(MAX+MIN)/(MAX-MIN))'
# HIERARCH ESO INS SLIT3 Y1OFFST = 4750. / Offset in Formula
# HIERARCH ESO INS SLIT3 Y1RESOL = 40. / Resolution in encoder steps
# HIERARCH ESO INS SLIT3 Y1MIN = 0.062 / Minimum slit width (arcsec)
# HIERARCH ESO INS SLIT3 Y1MAX = 5.572 / Maximum slit width (arcsec)
# HIERARCH ESO INS SLIT3 Y2FRML = 'ENC=OFFST+RESOL*acos(WID-(MAX+MIN)/(MAX-MIN))'
# HIERARCH ESO INS SLIT3 Y2OFFST = 4560. / Offset in Formula
# HIERARCH ESO INS SLIT3 Y2RESOL = 40. / Resolution in encoder steps
# HIERARCH ESO INS SLIT3 Y2MIN = 0.05 / Minimum slit width (arcsec)
# HIERARCH ESO INS SLIT3 Y2MAX = 5.513 / Maximum slit width (arcsec)
# HIERARCH ESO INS SLIT3 Y1ENC = 10295 / Slit Vertical top motor absolute e
# HIERARCH ESO INS SLIT3 Y2ENC = 10082 / Slit Vertical bottom motor absolut
# HIERARCH ESO INS SLIT3 LEN = 8. / Slit length (arcsec)
# HIERARCH ESO INS SLIT3 X1FRML = 'ENC=OFFST+RESOL*acos(LEN-(MAX+MIN)/(MAX-MIN))'
# HIERARCH ESO INS SLIT3 X1OFFST = 2381. / Offset in Formula
# HIERARCH ESO INS SLIT3 X1RESOL = 40. / Resolution in encoder steps
# HIERARCH ESO INS SLIT3 X1MIN = 0.087 / Minimum slit length (arcsec)
# HIERARCH ESO INS SLIT3 X1MAX = 15.752 / Maximum slit length (arcsec)
# HIERARCH ESO INS SLIT3 X2FRML = 'ENC=OFFST+RESOL*acos(LEN-(MAX+MIN)/(MAX-MIN))'
# HIERARCH ESO INS SLIT3 X2OFFST = 2307. / Offset in Formula
# HIERARCH ESO INS SLIT3 X2RESOL = 40. / Resolution in encoder steps
# HIERARCH ESO INS SLIT3 X2MIN = 0.064 / Minimum slit length (arcsec)
# HIERARCH ESO INS SLIT3 X2MAX = 15.833 / Maximum slit length (arcsec)
# HIERARCH ESO INS SLIT3 X1ENC = 7182 / Slit Horizontal left motor absolut
# HIERARCH ESO INS SLIT3 X2ENC = 7109 / Slit Horizontal right motor absolu
# HIERARCH ESO INS FILT3 ID = 'BS9     ' / Filter unique id
# HIERARCH ESO INS FILT3 NAME = 'BK7_5   ' / Filter common name
# HIERARCH ESO INS FILT3 NO =  9 / Filter wheel position index
# HIERARCH ESO INS DET6 NAME = 'Red exp. meter PMT' / detector name
# HIERARCH ESO INS DET6 CTMIN = 122. / Minimum count during exposure
# HIERARCH ESO INS DET6 CTMAX = 257. / Maximum count during exposure
# HIERARCH ESO INS DET6 CTMEAN = 189.2 / Average counts during exposure
# HIERARCH ESO INS DET6 CTRMS = 18.79 / RMS of counts during exposure
# HIERARCH ESO INS DET6 TMMEAN = 0.5 / Normalised mean exposure time
# HIERARCH ESO INS DET6 CTTOT = 375592. / Total counts during exposure
# HIERARCH ESO INS DET6 UIT = 1. / User defined Integration time
# HIERARCH ESO INS DET6 OFFDRK = 0. / Average dark background counts
# HIERARCH ESO INS DET6 OFFSKY = 6. / Average sky background counts
# HIERARCH ESO INS SHUT6 ID = 'REXS    ' / Shutter ID
# HIERARCH ESO INS SHUT6 NAME = 'Red exp. meter sh.' / Shutter name
# HIERARCH ESO INS SHUT6 ST =  T / Shutter open
# HIERARCH ESO INS GRAT2 ID = 'CD#4B   ' / Grating unique ID
# HIERARCH ESO INS GRAT2 NAME = 'CD#4    ' / Grating common name
# HIERARCH ESO INS PIXSCALE = 0.182 / Pixel scale
# HIERARCH ESO INS GRAT2 X = 2048. / X pixel for central wavelength
# HIERARCH ESO INS GRAT2 Y = 2048. / Y pixel for central wavelength
# HIERARCH ESO INS GRAT2 FRML = 'ENC=OFFST+RESOL*ASIN(WLEN*GRV/(2*COS(ROT)))' / C
# HIERARCH ESO INS GRAT2 OFFST = 3911988. / Offset in Formula
# HIERARCH ESO INS GRAT2 RESOL = 15000. / Resolution in encoder steps
# HIERARCH ESO INS GRAT2 GRV = 0.000312 / Grating grooves/nm
# HIERARCH ESO INS GRAT2 ROT = 22.668 / Grating rot angle
# HIERARCH ESO INS GRAT2 NO =  2 / Grating wheel position index
# HIERARCH ESO INS GRAT2 WLEN = 775. / Grating central wavelength
# HIERARCH ESO INS GRAT2 DISP = 0.1 / Grating dispersion
# HIERARCH ESO INS GRAT2 ENC = 4025060 / Grating absolute encoder position
# HIERARCH ESO INS TILT2 POS = 0. / Science camera tilt (pixels)
# HIERARCH ESO INS TILT2 FRML = 'ENC=OFFST+RESOL*ASIN(2*POS-(MAX+MIN)/(MAX-MIN))'
# HIERARCH ESO INS TILT2 OFFST = 15927. / Offset in Formula
# HIERARCH ESO INS TILT2 RESOL = -100. / Resolution in encoder steps
# HIERARCH ESO INS TILT2 POSMIN = -222. / Minimum camera tilt (pixels)
# HIERARCH ESO INS TILT2 POSMAX = 222. / Maximum camera tilt (pixels)
# HIERARCH ESO INS TILT2 ENC = 15927 / Camera tilt absolute encoder posit
# HIERARCH ESO INS SHUT7 ID = 'FPSH    ' / Shutter ID
# HIERARCH ESO INS SHUT7 NAME = 'FIBRPROJSHUTTER' / Shutter name
# HIERARCH ESO INS DROT END = 160.249 / Physical position at end (deg)
# HIERARCH ESO INS TEMP31 NAME = 'Iodine cell temp.' / Temperature sensor name
# HIERARCH ESO INS TEMP31 START = 11.1 / Temperature at start
# HIERARCH ESO INS TEMP31 STOP = 11.2 / Temperature at end
# HIERARCH ESO INS TEMP31 MIN = 11. / Minimum temperature
# HIERARCH ESO INS TEMP31 MAX = 11.4 / Maximum temperature
# HIERARCH ESO INS TEMP31 MEAN = 11.2 / Average temperature
# HIERARCH ESO INS TEMP1 NAME = 'Temp. blue camera' / Temperature sensor name
# HIERARCH ESO INS TEMP1 START = 9.6 / Temperature at start
# HIERARCH ESO INS TEMP1 STOP = 9.6 / Temperature at end
# HIERARCH ESO INS TEMP1 MIN = 9.6 / Minimum temperature
# HIERARCH ESO INS TEMP1 MAX = 9.6 / Maximum temperature
# HIERARCH ESO INS TEMP1 MEAN = 9.6 / Average temperature
# HIERARCH ESO INS TEMP2 NAME = 'Temp. red camera' / Temperature sensor name
# HIERARCH ESO INS TEMP2 START = 9.6 / Temperature at start
# HIERARCH ESO INS TEMP2 STOP = 9.7 / Temperature at end
# HIERARCH ESO INS TEMP2 MIN = 9.6 / Minimum temperature
# HIERARCH ESO INS TEMP2 MAX = 9.7 / Maximum temperature
# HIERARCH ESO INS TEMP2 MEAN = 9.6 / Average temperature
# HIERARCH ESO INS TEMP3 NAME = 'Temp. table' / Temperature sensor name
# HIERARCH ESO INS TEMP3 START = 10. / Temperature at start
# HIERARCH ESO INS TEMP3 STOP = 10. / Temperature at end
# HIERARCH ESO INS TEMP3 MIN = 10. / Minimum temperature
# HIERARCH ESO INS TEMP3 MAX = 10. / Maximum temperature
# HIERARCH ESO INS TEMP3 MEAN = 10. / Average temperature
# HIERARCH ESO INS TEMP4 NAME = 'Temp. inside air' / Temperature sensor name
# HIERARCH ESO INS TEMP4 START = 10.8 / Temperature at start
# HIERARCH ESO INS TEMP4 STOP = 10.8 / Temperature at end
# HIERARCH ESO INS TEMP4 MIN = 10.8 / Minimum temperature
# HIERARCH ESO INS TEMP4 MAX = 10.8 / Maximum temperature
# HIERARCH ESO INS TEMP4 MEAN = 10.8 / Average temperature
# HIERARCH ESO INS SENS26 NAME = 'Barometer pressure' / sensor common name
# HIERARCH ESO INS SENS26 START = 743.3 / sensor value at start
# HIERARCH ESO INS SENS26 STOP = 743.2 / sensor value at end
# HIERARCH ESO INS SENS26 MIN = 743.2 / Minimum sensor value
# HIERARCH ESO INS SENS26 MAX = 743.3 / Maximum sensor value
# HIERARCH ESO INS SENS26 MEAN = 743.3 / Average sensor vlaue
# HIERARCH ESO DET ID = 'CCD FIERA - Rev 2.69' / Detector system Id
# HIERARCH ESO DET NAME = 'ccdUvR - ccdUvr' / Name of detector system
# HIERARCH ESO DET DATE = '09-07-1998' / Installation date
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET BITS =     16 / Bits per pixel readout
# HIERARCH ESO DET RA = 14.74662892 / Apparent 00:58:59.1 RA at start
# HIERARCH ESO DET DEC = -72.74380465 / Apparent -72:44:37.6 DEC at start
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET CHIPS =     2 / # of chips in detector array
# HIERARCH ESO DET CHIP1 ID = 'CCID-20 ' / Detector chip identification
# HIERARCH ESO DET CHIP1 NAME = 'MIT/LL, EEV' / Detector chip name
# HIERARCH ESO DET CHIP1 DATE = '09-07-1998' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP1 X =   1 / X location in array
# HIERARCH ESO DET CHIP1 Y =   1 / Y location in array
# HIERARCH ESO DET CHIP1 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX = 15. / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY = 15. / Size of pixel in Y
# HIERARCH ESO DET CHIP2 ID = 'CCD-44  ' / Detector chip identification
# HIERARCH ESO DET CHIP2 NAME = 'MIT/LL, EEV' / Detector chip name
# HIERARCH ESO DET CHIP2 DATE = '09-07-1998' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP2 X =   2 / X location in array
# HIERARCH ESO DET CHIP2 Y =   1 / Y location in array
# HIERARCH ESO DET CHIP2 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP2 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET CHIP2 PSZX = 15. / Size of pixel in X
# HIERARCH ESO DET CHIP2 PSZY = 15. / Size of pixel in Y
# HIERARCH ESO DET EXP NO = 2001 / Unique exposure ID number
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP DUMDIT = 0 / # of dummy readouts
# HIERARCH ESO DET EXP RDTTIME = 39.605 / image readout time
# HIERARCH ESO DET EXP XFERTIM = 39.611 / image transfer time
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ SPEED = '2pts/225kHz/lg' / Readout speed
# HIERARCH ESO DET READ CLOCK = '225kHz/2ports/l' / Readout clock pattern used
# HIERARCH ESO DET OUTPUTS =   2 / # of outputs
# HIERARCH ESO DET OUTREF =    0 / reference output
# HIERARCH ESO DET OUT1 ID = 'L       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 NAME = 'L       ' / Description of output
# HIERARCH ESO DET OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET OUT1 X =    1 / X location of output
# HIERARCH ESO DET OUT1 Y =    1 / Y location of output
# HIERARCH ESO DET OUT1 NX = 2048 / valid pixels along X
# HIERARCH ESO DET OUT1 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET OUT1 CONAD = 1.46 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 RON = 3.69 / Readout noise per output (e-)
# HIERARCH ESO DET OUT1 GAIN = 0.68 / Conversion from electrons to ADU
# HIERARCH ESO DET OUT4 ID = 'R       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT4 NAME = 'R       ' / Description of output
# HIERARCH ESO DET OUT4 CHIP = 2 / Chip to which the output belongs
# HIERARCH ESO DET OUT4 X = 4096 / X location of output
# HIERARCH ESO DET OUT4 Y =    1 / Y location of output
# HIERARCH ESO DET OUT4 NX = 2048 / valid pixels along X
# HIERARCH ESO DET OUT4 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET OUT4 CONAD = 1.59 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT4 RON = 3.42 / Readout noise per output (e-)
# HIERARCH ESO DET OUT4 GAIN = 0.63 / Conversion from electrons to ADU
# HIERARCH ESO DET FRAM ID =   1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET WINDOWS =   1 / # of windows readout
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 NX = 4296 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET WIN1 BINX = 1 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 1 / Binning factor along Y
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 UIT1 = 2000. / user defined subintegration time
# HIERARCH ESO DET WIN1 DIT1 = 2000.000698 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 2000.66 / Dark current time
# HIERARCH ESO DET SHUT TYPE = 'Slit    ' / type of shutter
# HIERARCH ESO DET SHUT ID = 'ccdUvr shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMOPEN = 0.038 / Time taken to open shutter
# HIERARCH ESO DET SHUT TMCLOS = 0.039 / Time taken to close shutter
# HIERARCH ESO DET TELE INT = 60. / Interval between two successive te
# HIERARCH ESO DET TELE NO =   3 / # of sources active
# HIERARCH ESO DET TLM1 NAME = 'CCD T1  ' / Description of telemetry param.
# HIERARCH ESO DET TLM1 ID = 'CCD Sensor1' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 START = 135. / Telemetry value at read start
# HIERARCH ESO DET TLM1 END = 135. / Telemetry value at read completion
# HIERARCH ESO DET TLM2 NAME = 'CCD T2  ' / Description of telemetry param.
# HIERARCH ESO DET TLM2 ID = 'CCD Sensor2' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 START = 137.2 / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = 137.3 / Telemetry value at read completion
# HIERARCH ESO DET TLM3 NAME = 'EBOX T  ' / Description of telemetry param.
# HIERARCH ESO DET TLM3 ID = 'Box Temp' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 START = 284.2 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = 284.2 / Telemetry value at read completion
# HIERARCH ESO PRO ANCESTOR = 'UVES.2001-11-04T04:07:10.253.fits'
# HIERARCH ESO PRO DID = 'PRO-1.15' / Data dictionary for PRO
# HIERARCH ESO PRO CATG = 'RED_SCI_POINT_RED' / Category of pipeline product fram
# HIERARCH ESO PRO TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO SCIENCE =   T / Scientific product if T
# HIERARCH ESO PRO REC1 ID = 'uves_obs_scired' / Pipeline recipe (unique) identifi
# HIERARCH ESO PRO REC1 DRS ID = 'cpl-7.1.2' / Data Reduction System identifier
# HIERARCH ESO PRO REC1 PIPE ID = 'uves/5.10.13' / Pipeline (unique) identifier
# HIERARCH ESO PRO REC1 RAW1 NAME = 'UVES.2001-11-04T04:07:10.253.fits' / File nam
# HIERARCH ESO PRO REC1 RAW1 CATG = 'SCI_POINT_RED' / Category of raw frame
# HIERARCH ESO PRO DATANCOM =  1 / Number of combined frames
# HIERARCH ESO PRO REC1 CAL1 NAME = 'atmoexan.tfits' / File name of calibration fr
# HIERARCH ESO PRO REC1 CAL1 CATG = 'EXTCOEFF_TABLE' / Category of calibration fra
# HIERARCH ESO PRO REC1 CAL1 DATAMD5 = '8b6806a8b8ce62e0c4514763ce4be125' / MD5 si
# HIERARCH ESO PRO REC1 CAL2 NAME = 'r.UVES.2001-11-04T10:54:03.607_0000.fits' / F
# HIERARCH ESO PRO REC1 CAL2 CATG = 'ORDER_TABLE_REDL' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL2 DATAMD5 = '83046241573448dc329258d3d05a8815' / MD5 si
# HIERARCH ESO PRO REC1 CAL3 NAME = 'r.UVES.2001-11-04T10:52:26.246_0000.fits' / F
# HIERARCH ESO PRO REC1 CAL3 CATG = 'LINE_TABLE_REDL' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL3 DATAMD5 = '0b4fcfca6e92d57dc7a45efc715c23cb' / MD5 si
# HIERARCH ESO PRO REC1 CAL4 NAME = 'r.UVES.2001-11-04T09:35:07.153_tpl_0000.fits'
# HIERARCH ESO PRO REC1 CAL4 CATG = 'MASTER_BIAS_REDL' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL4 DATAMD5 = '56c98c8ac15d26699e5826e7b7ba91d8' / MD5 si
# HIERARCH ESO PRO REC1 CAL5 NAME = 'r.UVES.2001-11-04T10:46:52.270_tpl_0000.fits'
# HIERARCH ESO PRO REC1 CAL5 CATG = 'MASTER_FLAT_REDL' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL5 DATAMD5 = '1c7878b84a1dcc62abf2066bf798f846' / MD5 si
# HIERARCH ESO PRO REC1 CAL6 NAME = 'r.UVES.2001-11-04T10:54:03.607_0003.fits' / F
# HIERARCH ESO PRO REC1 CAL6 CATG = 'ORDER_TABLE_REDU' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL6 DATAMD5 = '5099b5b54fc2847ee954ac76b0068368' / MD5 si
# HIERARCH ESO PRO REC1 CAL7 NAME = 'r.UVES.2001-11-04T10:52:26.246_0004.fits' / F
# HIERARCH ESO PRO REC1 CAL7 CATG = 'LINE_TABLE_REDU' / Category of calibration fr
# HIERARCH ESO PRO REC1 CAL7 DATAMD5 = '32b2f87c4f2c537809300170a27a4335' / MD5 si
# HIERARCH ESO PRO REC1 CAL8 NAME = 'r.UVES.2001-11-04T09:35:07.153_tpl_0001.fits'
# HIERARCH ESO PRO REC1 CAL8 CATG = 'MASTER_BIAS_REDU' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL8 DATAMD5 = 'eabb29f75359fea1ae688387d1bec498' / MD5 si
# HIERARCH ESO PRO REC1 CAL9 NAME = 'r.UVES.2001-11-04T10:46:52.270_tpl_0002.fits'
# HIERARCH ESO PRO REC1 CAL9 CATG = 'MASTER_FLAT_REDU' / Category of calibration f
# HIERARCH ESO PRO REC1 CAL9 DATAMD5 = '0065ac73db297115bf8d70cecc4063bf' / MD5 si
# HIERARCH ESO PRO REC1 PARAM1 NAME = 'debug   ' / Whether or not to save intermed
# HIERARCH ESO PRO REC1 PARAM1 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM2 NAME = 'plotter ' / Any plots produced by the recip
# HIERARCH ESO PRO REC1 PARAM2 VALUE = 'no      ' / Default: 'no'
# HIERARCH ESO PRO REC1 PARAM3 NAME = 'process_chip' / For RED arm data process th
# HIERARCH ESO PRO REC1 PARAM3 VALUE = 'BOTH    ' / Default: 'both'
# HIERARCH ESO PRO REC1 PARAM4 NAME = 'clean_traps' / Clean detector traps. If TRU
# HIERARCH ESO PRO REC1 PARAM4 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM5 NAME = 'reduce.backsub.mmethod' / Background measur
# HIERARCH ESO PRO REC1 PARAM5 VALUE = 'median  ' / Default: 'median'
# HIERARCH ESO PRO REC1 PARAM6 NAME = 'reduce.backsub.npoints' / This is the numbe
# HIERARCH ESO PRO REC1 PARAM6 VALUE = '82      ' / Default: 82
# HIERARCH ESO PRO REC1 PARAM7 NAME = 'reduce.backsub.radiusy' / The height (in pi
# HIERARCH ESO PRO REC1 PARAM7 VALUE = '2       ' / Default: 2
# HIERARCH ESO PRO REC1 PARAM8 NAME = 'reduce.backsub.sdegree' / Degree of interpo
# HIERARCH ESO PRO REC1 PARAM8 VALUE = '1       ' / Default: 1
# HIERARCH ESO PRO REC1 PARAM9 NAME = 'reduce.backsub.smoothx' / If spline interpo
# HIERARCH ESO PRO REC1 PARAM9 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM10 NAME = 'reduce.backsub.smoothy' / If spline interp
# HIERARCH ESO PRO REC1 PARAM10 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM11 NAME = 'reduce.extract.method' / Extraction method
# HIERARCH ESO PRO REC1 PARAM11 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO REC1 PARAM12 NAME = 'reduce.extract.kappa' / In optimal extract
# HIERARCH ESO PRO REC1 PARAM12 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO REC1 PARAM13 NAME = 'reduce.extract.chunk' / In optimal extract
# HIERARCH ESO PRO REC1 PARAM13 VALUE = '32      ' / Default: 32
# HIERARCH ESO PRO REC1 PARAM14 NAME = 'reduce.extract.profile' / In optimal extra
# HIERARCH ESO PRO REC1 PARAM14 VALUE = 'auto    ' / Default: 'auto'
# HIERARCH ESO PRO REC1 PARAM15 NAME = 'reduce.extract.skymethod' / In optimal ext
# HIERARCH ESO PRO REC1 PARAM15 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO REC1 PARAM16 NAME = 'reduce.extract.oversample' / The oversampl
# HIERARCH ESO PRO REC1 PARAM16 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM17 NAME = 'reduce.extract.best' / (optimal extraction
# HIERARCH ESO PRO REC1 PARAM17 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM18 NAME = 'reduce.slitlength' / Extraction slit lengt
# HIERARCH ESO PRO REC1 PARAM18 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM19 NAME = 'reduce.skysub' / Do sky-subtraction (only
# HIERARCH ESO PRO REC1 PARAM19 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM20 NAME = 'reduce.objoffset' / Offset (in pixels) of
# HIERARCH ESO PRO REC1 PARAM20 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM21 NAME = 'reduce.objslit' / Object window size (in p
# HIERARCH ESO PRO REC1 PARAM21 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM22 NAME = 'reduce.tiltcorr' / If enabled (recommended
# HIERARCH ESO PRO REC1 PARAM22 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO REC1 PARAM23 NAME = 'reduce.ffmethod' / Flat-fielding method. I
# HIERARCH ESO PRO REC1 PARAM23 VALUE = 'pixel   ' / Default: 'extract'
# HIERARCH ESO PRO REC1 PARAM24 NAME = 'reduce.rebin.wavestep' / The bin size (in
# HIERARCH ESO PRO REC1 PARAM24 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO REC1 PARAM25 NAME = 'reduce.rebin.scale' / Whether or not to mu
# HIERARCH ESO PRO REC1 PARAM25 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO REC1 PARAM26 NAME = 'reduce.merge' / Order merging method. If '
# HIERARCH ESO PRO REC1 PARAM26 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO REC1 PARAM27 NAME = 'reduce.merge_delt1' / Order merging left h
# HIERARCH ESO PRO REC1 PARAM27 VALUE = '14      ' / Default: 0
# HIERARCH ESO PRO REC1 PARAM28 NAME = 'reduce.merge_delt2' / Order merging right
# HIERARCH ESO PRO REC1 PARAM28 VALUE = '4       ' / Default: 0
# HIERARCH ESO PRO DATAMED = 684.72697850609 / Median of pixel values
# HIERARCH ESO PRO DATAAVG = 854.561228644369 / Mean of pixel values
# HIERARCH ESO PRO DATARMS = 568.747555090104 / Standard deviation of pixel values
# HIERARCH ESO PRO REC1 START = '2020-08-07T20:45:19'
# HIERARCH ESO PRO REC1 STOP = '2020-08-07T20:45:36'
# HIERARCH ESO ADA ABSROT START = -244.38681 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA POSANG =   0. / Position angle at start
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA GUID RA = 14.5343 / 00:58:08.2 Guide star RA J2000
# HIERARCH ESO ADA GUID DEC = -72.64234 / -72:38:32.4 Guide star DEC J2000
# HIERARCH ESO ADA ABSROT END = -253.03846 / Abs rot angle at exp end (deg)
# HIERARCH ESO BNOISE =   1.1665 / Master bias RMS on frame
# HIERARCH ESO QC DID = 'UVES-1.14' / ESO QC DID
# HIERARCH ESO QC TEST1 ID = 'Science-Reduction-Test-Results' / Name of QC test
# HIERARCH ESO QC ORD1 OBJ SN = 54.5441 / Av. S/N at order center
# HIERARCH ESO QC ORD1 OBJ POS = 23.2552 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD1 OBJ FWHM = 7.4523 / Av. FWHM on order
# HIERARCH ESO QC ORD1 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD2 OBJ SN = 50.9281 / Av. S/N at order center
# HIERARCH ESO QC ORD2 OBJ POS = 23.1222 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD2 OBJ FWHM = 7.4352 / Av. FWHM on order
# HIERARCH ESO QC ORD2 OBJ RPLPAR = 1.6287 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD3 OBJ SN = 48.1792 / Av. S/N at order center
# HIERARCH ESO QC ORD3 OBJ POS = 23.0153 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD3 OBJ FWHM = 7.424 / Av. FWHM on order
# HIERARCH ESO QC ORD3 OBJ RPLPAR = 5.5681 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD4 OBJ SN = 45.8922 / Av. S/N at order center
# HIERARCH ESO QC ORD4 OBJ POS = 22.9255 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD4 OBJ FWHM = 7.3736 / Av. FWHM on order
# HIERARCH ESO QC ORD4 OBJ RPLPAR = 2.5501 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD5 OBJ SN = 43.9664 / Av. S/N at order center
# HIERARCH ESO QC ORD5 OBJ POS = 22.8456 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD5 OBJ FWHM = 7.3705 / Av. FWHM on order
# HIERARCH ESO QC ORD5 OBJ RPLPAR = 4.1473 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD6 OBJ SN = 41.8825 / Av. S/N at order center
# HIERARCH ESO QC ORD6 OBJ POS = 22.77 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD6 OBJ FWHM = 7.3256 / Av. FWHM on order
# HIERARCH ESO QC ORD6 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD7 OBJ SN = 39.7819 / Av. S/N at order center
# HIERARCH ESO QC ORD7 OBJ POS = 22.6949 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD7 OBJ FWHM = 7.2797 / Av. FWHM on order
# HIERARCH ESO QC ORD7 OBJ RPLPAR = 2.07 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD8 OBJ SN = 37.7368 / Av. S/N at order center
# HIERARCH ESO QC ORD8 OBJ POS = 22.6177 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD8 OBJ FWHM = 7.2659 / Av. FWHM on order
# HIERARCH ESO QC ORD8 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD9 OBJ SN = 36.3784 / Av. S/N at order center
# HIERARCH ESO QC ORD9 OBJ POS = 22.537 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD9 OBJ FWHM = 7.218 / Av. FWHM on order
# HIERARCH ESO QC ORD9 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD10 OBJ SN = 34.8379 / Av. S/N at order center
# HIERARCH ESO QC ORD10 OBJ POS = 22.4524 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD10 OBJ FWHM = 7.1901 / Av. FWHM on order
# HIERARCH ESO QC ORD10 OBJ RPLPAR = 0.1369 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD11 OBJ SN = 33.211 / Av. S/N at order center
# HIERARCH ESO QC ORD11 OBJ POS = 22.3643 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD11 OBJ FWHM = 7.1622 / Av. FWHM on order
# HIERARCH ESO QC ORD11 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD12 OBJ SN = 28.3068 / Av. S/N at order center
# HIERARCH ESO QC ORD12 OBJ POS = 22.2738 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD12 OBJ FWHM = 7.1203 / Av. FWHM on order
# HIERARCH ESO QC ORD12 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD13 OBJ SN = 30.2329 / Av. S/N at order center
# HIERARCH ESO QC ORD13 OBJ POS = 22.1823 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD13 OBJ FWHM = 7.0941 / Av. FWHM on order
# HIERARCH ESO QC ORD13 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD14 OBJ SN = 28.8677 / Av. S/N at order center
# HIERARCH ESO QC ORD14 OBJ POS = 22.0915 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD14 OBJ FWHM = 7.0453 / Av. FWHM on order
# HIERARCH ESO QC ORD14 OBJ RPLPAR = 0.8496 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD15 OBJ SN = 27.498 / Av. S/N at order center
# HIERARCH ESO QC ORD15 OBJ POS = 22.0031 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD15 OBJ FWHM = 7.0142 / Av. FWHM on order
# HIERARCH ESO QC ORD15 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD16 OBJ SN = 26.0529 / Av. S/N at order center
# HIERARCH ESO QC ORD16 OBJ POS = 21.9188 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD16 OBJ FWHM = 6.9598 / Av. FWHM on order
# HIERARCH ESO QC ORD16 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD17 OBJ SN = 24.6334 / Av. S/N at order center
# HIERARCH ESO QC ORD17 OBJ POS = 21.8399 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD17 OBJ FWHM = 6.9381 / Av. FWHM on order
# HIERARCH ESO QC ORD17 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD18 OBJ SN = 23.5649 / Av. S/N at order center
# HIERARCH ESO QC ORD18 OBJ POS = 21.7671 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD18 OBJ FWHM = 6.8931 / Av. FWHM on order
# HIERARCH ESO QC ORD18 OBJ RPLPAR = 0.2632 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD19 OBJ SN = 22.4388 / Av. S/N at order center
# HIERARCH ESO QC ORD19 OBJ POS = 21.7006 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD19 OBJ FWHM = 6.8222 / Av. FWHM on order
# HIERARCH ESO QC ORD19 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD20 OBJ SN = 20.9465 / Av. S/N at order center
# HIERARCH ESO QC ORD20 OBJ POS = 21.6397 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD20 OBJ FWHM = 6.8 / Av. FWHM on order
# HIERARCH ESO QC ORD20 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD21 OBJ SN = 19.7545 / Av. S/N at order center
# HIERARCH ESO QC ORD21 OBJ POS = 21.5825 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD21 OBJ FWHM = 6.7539 / Av. FWHM on order
# HIERARCH ESO QC ORD21 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD22 OBJ SN = 18.9219 / Av. S/N at order center
# HIERARCH ESO QC ORD22 OBJ POS = 21.5259 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD22 OBJ FWHM = 6.738 / Av. FWHM on order
# HIERARCH ESO QC ORD22 OBJ RPLPAR = 0.8673 / Av. relative ripple amplitude
# HIERARCH ESO QC ORD23 OBJ SN = 18.0001 / Av. S/N at order center
# HIERARCH ESO QC ORD23 OBJ POS = 21.4654 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD23 OBJ FWHM = 6.7192 / Av. FWHM on order
# HIERARCH ESO QC ORD23 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD24 OBJ SN = 16.9978 / Av. S/N at order center
# HIERARCH ESO QC ORD24 OBJ POS = 21.395 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD24 OBJ FWHM = 6.6752 / Av. FWHM on order
# HIERARCH ESO QC ORD24 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC ORD25 OBJ SN = 10.8841 / Av. S/N at order center
# HIERARCH ESO QC ORD25 OBJ POS = 21.3066 / Av. OBJ POS at order center
# HIERARCH ESO QC ORD25 OBJ FWHM = 6.6145 / Av. FWHM on order
# HIERARCH ESO QC ORD25 OBJ RPLPAR = -1. / Av. relative ripple amplitude
# HIERARCH ESO QC EX NORD =   25 / No. of orders extracted
# HIERARCH ESO QC EX XSIZE = 4096 / Input image width (pixels)
# HIERARCH ESO QC EX YSIZE =  42 / Extraction slit (pixels)
# HIERARCH ESO QC VRAD BARYCOR = -12.729445 / Barycentric radial velocity correcti
# HIERARCH ESO QC VRAD HELICOR = -12.734294 / Heliocentric radial velocity correct
# IS_FLUXD= 'no      '           / no flux calibration provided
# IS_IDP  = 'yes     '           / product is IDP
# HIERARCH ESO DET CHIP2 OUTPUTS = 2 / # of outputs
# HIERARCH ESO DET CHIP2 OUTREF = 0 / reference output
# HIERARCH ESO DET CHIP2 OUT1 ID = 'L       ' / Output ID as from manufacturer
# HIERARCH ESO DET CHIP2 OUT1 NAME = 'L       ' / Description of output
# HIERARCH ESO DET CHIP2 OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET CHIP2 OUT1 X = 1 / X location of output
# HIERARCH ESO DET CHIP2 OUT1 Y = 1 / Y location of output
# HIERARCH ESO DET CHIP2 OUT1 NX = 2048 / valid pixels along X
# HIERARCH ESO DET CHIP2 OUT1 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET CHIP2 OUT1 CONAD = 1.46 / Conversion from ADUs to electrons
# HIERARCH ESO DET CHIP2 OUT1 RON = 3.69 / Readout noise per output (e-)
# HIERARCH ESO DET CHIP2 OUT1 GAIN = 0.68 / Conversion from electrons to ADU
# HIERARCH ESO DET CHIP2 OUT4 ID = 'R       ' / Output ID as from manufacturer
# HIERARCH ESO DET CHIP2 OUT4 NAME = 'R       ' / Description of output
# HIERARCH ESO DET CHIP2 OUT4 CHIP = 2 / Chip to which the output belongs
# HIERARCH ESO DET CHIP2 OUT4 X = 4096 / X location of output
# HIERARCH ESO DET CHIP2 OUT4 Y = 1 / Y location of output
# HIERARCH ESO DET CHIP2 OUT4 NX = 2048 / valid pixels along X
# HIERARCH ESO DET CHIP2 OUT4 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET CHIP2 OUT4 CONAD = 1.59 / Conversion from ADUs to electrons
# HIERARCH ESO DET CHIP2 OUT4 RON = 3.42 / Readout noise per output (e-)
# HIERARCH ESO DET CHIP2 OUT4 GAIN = 0.63 / Conversion from electrons to ADU
# HIERARCH ESO PRO CHIP2 ANCESTOR = 'UVES.2001-11-04T04:07:10.253.fits'
# HIERARCH ESO PRO CHIP2 DID = 'PRO-1.15' / Data dictionary for PRO
# HIERARCH ESO PRO CHIP2 CATG = 'RED_SCI_POINT_REDL' / Category of pipeline produc
# HIERARCH ESO PRO CHIP2 TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO CHIP2 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO CHIP2 SCIENCE = T / Scientific product if T
# HIERARCH ESO PRO R1C2 ID = 'uves_obs_scired' / Pipeline recipe (unique) identifi
# HIERARCH ESO PRO R1C2 DRS ID = 'cpl-7.1.2' / Data Reduction System identifier
# HIERARCH ESO PRO R1C2 PIPE ID = 'uves/5.10.13' / Pipeline (unique) identifier
# HIERARCH ESO PRO R1C2 RAW1 NAME = 'UVES.2001-11-04T04:07:10.253.fits' / File nam
# ...
# HIERARCH ESO DET CHIP1 OUT1 ID = 'L       ' / Output ID as from manufacturer
# HIERARCH ESO DET CHIP1 OUT1 NAME = 'L       ' / Description of output
# HIERARCH ESO DET CHIP1 OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET CHIP1 OUT1 X = 1 / X location of output
# HIERARCH ESO DET CHIP1 OUT1 Y = 1 / Y location of output
# HIERARCH ESO DET CHIP1 OUT1 NX = 2048 / valid pixels along X
# HIERARCH ESO DET CHIP1 OUT1 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET CHIP1 OUT1 CONAD = 1.46 / Conversion from ADUs to electrons
# HIERARCH ESO DET CHIP1 OUT1 RON = 3.69 / Readout noise per output (e-)
# HIERARCH ESO DET CHIP1 OUT1 GAIN = 0.68 / Conversion from electrons to ADU
# HIERARCH ESO DET CHIP1 OUT4 ID = 'R       ' / Output ID as from manufacturer
# HIERARCH ESO DET CHIP1 OUT4 NAME = 'R       ' / Description of output
# HIERARCH ESO DET CHIP1 OUT4 CHIP = 2 / Chip to which the output belongs
# HIERARCH ESO DET CHIP1 OUT4 X = 4096 / X location of output
# HIERARCH ESO DET CHIP1 OUT4 Y = 1 / Y location of output
# HIERARCH ESO DET CHIP1 OUT4 NX = 2048 / valid pixels along X
# HIERARCH ESO DET CHIP1 OUT4 NY = 4096 / valid pixels along Y
# HIERARCH ESO DET CHIP1 OUT4 CONAD = 1.59 / Conversion from ADUs to electrons
# HIERARCH ESO DET CHIP1 OUT4 RON = 3.42 / Readout noise per output (e-)
# HIERARCH ESO DET CHIP1 OUT4 GAIN = 0.63 / Conversion from electrons to ADU
# HIERARCH ESO PRO CHIP1 ANCESTOR = 'UVES.2001-11-04T04:07:10.253.fits'
# HIERARCH ESO PRO CHIP1 DID = 'PRO-1.15' / Data dictionary for PRO
# HIERARCH ESO PRO CHIP1 CATG = 'RED_SCI_POINT_REDU' / Category of pipeline produc
# HIERARCH ESO PRO CHIP1 TYPE = 'REDUCED ' / Product type
# HIERARCH ESO PRO CHIP1 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO CHIP1 SCIENCE = T / Scientific product if T
# HIERARCH ESO PRO R1C1 ID = 'uves_obs_scired' / Pipeline recipe (unique) identifi
# HIERARCH ESO PRO R1C1 DRS ID = 'cpl-7.1.2' / Data Reduction System identifier
# HIERARCH ESO PRO R1C1 PIPE ID = 'uves/5.10.13' / Pipeline (unique) identifier
# HIERARCH ESO PRO R1C1 RAW1 NAME = 'UVES.2001-11-04T04:07:10.253.fits' / File nam
# HIERARCH ESO PRO R1C1 RAW1 CATG = 'SCI_POINT_RED' / Category of raw frame
# HIERARCH ESO PRO CHIP1 DATANCOM = 1 / Number of combined frames
# HIERARCH ESO PRO R1C1 CAL1 NAME = 'atmoexan.tfits' / File name of calibration fr
# HIERARCH ESO PRO R1C1 CAL1 CATG = 'EXTCOEFF_TABLE' / Category of calibration fra
# HIERARCH ESO PRO R1C1 CAL1 DATAMD5 = '8b6806a8b8ce62e0c4514763ce4be125' / MD5 si
# HIERARCH ESO PRO R1C1 CAL2 NAME = 'r.UVES.2001-11-04T10:54:03.607_0000.fits' / F
# HIERARCH ESO PRO R1C1 CAL2 CATG = 'ORDER_TABLE_REDL' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL2 DATAMD5 = '83046241573448dc329258d3d05a8815' / MD5 si
# HIERARCH ESO PRO R1C1 CAL3 NAME = 'r.UVES.2001-11-04T10:52:26.246_0000.fits' / F
# HIERARCH ESO PRO R1C1 CAL3 CATG = 'LINE_TABLE_REDL' / Category of calibration fr
# HIERARCH ESO PRO R1C1 CAL3 DATAMD5 = '0b4fcfca6e92d57dc7a45efc715c23cb' / MD5 si
# HIERARCH ESO PRO R1C1 CAL4 NAME = 'r.UVES.2001-11-04T09:35:07.153_tpl_0000.fits'
# HIERARCH ESO PRO R1C1 CAL4 CATG = 'MASTER_BIAS_REDL' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL4 DATAMD5 = '56c98c8ac15d26699e5826e7b7ba91d8' / MD5 si
# HIERARCH ESO PRO R1C1 CAL5 NAME = 'r.UVES.2001-11-04T10:46:52.270_tpl_0000.fits'
# HIERARCH ESO PRO R1C1 CAL5 CATG = 'MASTER_FLAT_REDL' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL5 DATAMD5 = '1c7878b84a1dcc62abf2066bf798f846' / MD5 si
# HIERARCH ESO PRO R1C1 CAL6 NAME = 'r.UVES.2001-11-04T10:54:03.607_0003.fits' / F
# HIERARCH ESO PRO R1C1 CAL6 CATG = 'ORDER_TABLE_REDU' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL6 DATAMD5 = '5099b5b54fc2847ee954ac76b0068368' / MD5 si
# HIERARCH ESO PRO R1C1 CAL7 NAME = 'r.UVES.2001-11-04T10:52:26.246_0004.fits' / F
# HIERARCH ESO PRO R1C1 CAL7 CATG = 'LINE_TABLE_REDU' / Category of calibration fr
# HIERARCH ESO PRO R1C1 CAL7 DATAMD5 = '32b2f87c4f2c537809300170a27a4335' / MD5 si
# HIERARCH ESO PRO R1C1 CAL8 NAME = 'r.UVES.2001-11-04T09:35:07.153_tpl_0001.fits'
# HIERARCH ESO PRO R1C1 CAL8 CATG = 'MASTER_BIAS_REDU' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL8 DATAMD5 = 'eabb29f75359fea1ae688387d1bec498' / MD5 si
# HIERARCH ESO PRO R1C1 CAL9 NAME = 'r.UVES.2001-11-04T10:46:52.270_tpl_0002.fits'
# HIERARCH ESO PRO R1C1 CAL9 CATG = 'MASTER_FLAT_REDU' / Category of calibration f
# HIERARCH ESO PRO R1C1 CAL9 DATAMD5 = '0065ac73db297115bf8d70cecc4063bf' / MD5 si
# HIERARCH ESO PRO R1C1 PARAM1 NAME = 'debug   ' / Whether or not to save intermed
# HIERARCH ESO PRO R1C1 PARAM1 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO R1C1 PARAM2 NAME = 'plotter ' / Any plots produced by the recip
# HIERARCH ESO PRO R1C1 PARAM2 VALUE = 'no      ' / Default: 'no'
# HIERARCH ESO PRO R1C1 PARAM3 NAME = 'process_chip' / For RED arm data process th
# HIERARCH ESO PRO R1C1 PARAM3 VALUE = 'BOTH    ' / Default: 'both'
# HIERARCH ESO PRO R1C1 PARAM4 NAME = 'clean_traps' / Clean detector traps. If TRU
# HIERARCH ESO PRO R1C1 PARAM4 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO R1C1 PARAM5 NAME = 'reduce.backsub.mmethod' / Background measur
# HIERARCH ESO PRO R1C1 PARAM5 VALUE = 'median  ' / Default: 'median'
# HIERARCH ESO PRO R1C1 PARAM6 NAME = 'reduce.backsub.npoints' / This is the numbe
# HIERARCH ESO PRO R1C1 PARAM6 VALUE = '82      ' / Default: 82
# HIERARCH ESO PRO R1C1 PARAM7 NAME = 'reduce.backsub.radiusy' / The height (in pi
# HIERARCH ESO PRO R1C1 PARAM7 VALUE = '2       ' / Default: 2
# HIERARCH ESO PRO R1C1 PARAM8 NAME = 'reduce.backsub.sdegree' / Degree of interpo
# HIERARCH ESO PRO R1C1 PARAM8 VALUE = '1       ' / Default: 1
# HIERARCH ESO PRO R1C1 PARAM9 NAME = 'reduce.backsub.smoothx' / If spline interpo
# HIERARCH ESO PRO R1C1 PARAM9 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM10 NAME = 'reduce.backsub.smoothy' / If spline interp
# HIERARCH ESO PRO R1C1 PARAM10 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM11 NAME = 'reduce.extract.method' / Extraction method
# HIERARCH ESO PRO R1C1 PARAM11 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO R1C1 PARAM12 NAME = 'reduce.extract.kappa' / In optimal extract
# HIERARCH ESO PRO R1C1 PARAM12 VALUE = '10      ' / Default: 10
# HIERARCH ESO PRO R1C1 PARAM13 NAME = 'reduce.extract.chunk' / In optimal extract
# HIERARCH ESO PRO R1C1 PARAM13 VALUE = '32      ' / Default: 32
# HIERARCH ESO PRO R1C1 PARAM14 NAME = 'reduce.extract.profile' / In optimal extra
# HIERARCH ESO PRO R1C1 PARAM14 VALUE = 'auto    ' / Default: 'auto'
# HIERARCH ESO PRO R1C1 PARAM15 NAME = 'reduce.extract.skymethod' / In optimal ext
# HIERARCH ESO PRO R1C1 PARAM15 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO R1C1 PARAM16 NAME = 'reduce.extract.oversample' / The oversampl
# HIERARCH ESO PRO R1C1 PARAM16 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM17 NAME = 'reduce.extract.best' / (optimal extraction
# HIERARCH ESO PRO R1C1 PARAM17 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO R1C1 PARAM18 NAME = 'reduce.slitlength' / Extraction slit lengt
# HIERARCH ESO PRO R1C1 PARAM18 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM19 NAME = 'reduce.skysub' / Do sky-subtraction (only
# HIERARCH ESO PRO R1C1 PARAM19 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO R1C1 PARAM20 NAME = 'reduce.objoffset' / Offset (in pixels) of
# HIERARCH ESO PRO R1C1 PARAM20 VALUE = '0       ' / Default: 0
# HIERARCH ESO PRO R1C1 PARAM21 NAME = 'reduce.objslit' / Object window size (in p
# HIERARCH ESO PRO R1C1 PARAM21 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM22 NAME = 'reduce.tiltcorr' / If enabled (recommended
# HIERARCH ESO PRO R1C1 PARAM22 VALUE = 'true    ' / Default: true
# HIERARCH ESO PRO R1C1 PARAM23 NAME = 'reduce.ffmethod' / Flat-fielding method. I
# HIERARCH ESO PRO R1C1 PARAM23 VALUE = 'pixel   ' / Default: 'extract'
# HIERARCH ESO PRO R1C1 PARAM24 NAME = 'reduce.rebin.wavestep' / The bin size (in
# HIERARCH ESO PRO R1C1 PARAM24 VALUE = '-1      ' / Default: -1
# HIERARCH ESO PRO R1C1 PARAM25 NAME = 'reduce.rebin.scale' / Whether or not to mu
# HIERARCH ESO PRO R1C1 PARAM25 VALUE = 'false   ' / Default: false
# HIERARCH ESO PRO R1C1 PARAM26 NAME = 'reduce.merge' / Order merging method. If '
# HIERARCH ESO PRO R1C1 PARAM26 VALUE = 'optimal ' / Default: 'optimal'
# HIERARCH ESO PRO R1C1 PARAM27 NAME = 'reduce.merge_delt1' / Order merging left h
# HIERARCH ESO PRO R1C1 PARAM27 VALUE = '14      ' / Default: 0
# HIERARCH ESO PRO R1C1 PARAM28 NAME = 'reduce.merge_delt2' / Order merging right
# HIERARCH ESO PRO R1C1 PARAM28 VALUE = '4       ' / Default: 0
# HIERARCH ESO PRO CHIP1 DATAMED = 161.181598871461 / Median of pixel values
# HIERARCH ESO PRO CHIP1 DATAAVG = 159.996748962462 / Mean of pixel values
# HIERARCH ESO PRO CHIP1 DATARMS = 67.6310317134793 / Standard deviation of pixel
# HIERARCH ESO PRO R1C1 START = '2020-08-07T20:45:19'
# HIERARCH ESO PRO R1C1 STOP = '2020-08-07T20:45:45'
# HIERARCH ESO CHIP1 BNOISE = 1.4806 / Master bias RMS on frame
# HIERARCH ESO QC CHIP1 ORD1 OBJ SN = 14.9759 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD1 OBJ POS = 20.9974 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD1 OBJ FWHM = 6.7028 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD1 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD2 OBJ SN = 14.1911 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD2 OBJ POS = 20.9145 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD2 OBJ FWHM = 6.6374 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD2 OBJ RPLPAR = 0.4407 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD3 OBJ SN = 13.4735 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD3 OBJ POS = 20.8466 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD3 OBJ FWHM = 6.5927 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD3 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD4 OBJ SN = 12.5086 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD4 OBJ POS = 20.7856 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD4 OBJ FWHM = 6.4947 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD4 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD5 OBJ SN = 12.0186 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD5 OBJ POS = 20.7269 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD5 OBJ FWHM = 6.5078 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD5 OBJ RPLPAR = 0.4685 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD6 OBJ SN = 11.388 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD6 OBJ POS = 20.6685 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD6 OBJ FWHM = 6.5149 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD6 OBJ RPLPAR = 0.4863 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD7 OBJ SN = 11.0203 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD7 OBJ POS = 20.6102 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD7 OBJ FWHM = 6.4664 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD7 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD8 OBJ SN = 10.1838 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD8 OBJ POS = 20.553 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD8 OBJ FWHM = 6.4224 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD8 OBJ RPLPAR = 0.3456 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD9 OBJ SN = 10.3518 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD9 OBJ POS = 20.4981 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD9 OBJ FWHM = 6.4241 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD9 OBJ RPLPAR = 0.2761 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD10 OBJ SN = 9.5456 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD10 OBJ POS = 20.4462 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD10 OBJ FWHM = 6.383 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD10 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD11 OBJ SN = 9.147399999999999 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD11 OBJ POS = 20.397 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD11 OBJ FWHM = 6.3792 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD11 OBJ RPLPAR = 0.4698 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD12 OBJ SN = 8.8521 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD12 OBJ POS = 20.3477 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD12 OBJ FWHM = 6.2976 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD12 OBJ RPLPAR = 0.7675999999999999 / Av. relative rippl
# HIERARCH ESO QC CHIP1 ORD13 OBJ SN = 8.224299999999999 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD13 OBJ POS = 20.2932 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD13 OBJ FWHM = 6.3593 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD13 OBJ RPLPAR = 0.8044 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD14 OBJ SN = 7.5388 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD14 OBJ POS = 20.2245 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD14 OBJ FWHM = 6.3465 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD14 OBJ RPLPAR = -1.0 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 ORD15 OBJ SN = 6.3233 / Av. S/N at order center
# HIERARCH ESO QC CHIP1 ORD15 OBJ POS = 20.1284 / Av. OBJ POS at order center
# HIERARCH ESO QC CHIP1 ORD15 OBJ FWHM = 6.2489 / Av. FWHM on order
# HIERARCH ESO QC CHIP1 ORD15 OBJ RPLPAR = 0.4417 / Av. relative ripple amplitude
# HIERARCH ESO QC CHIP1 EX NORD = 15 / No. of orders extracted
# IS_STACK= 'NO      '           / single exposure
# PRODLEVL= 'SINGLE  '           / processing level of product
# RELEASE = 'UVES_STACK'         / technical release ID
# VM_SM   = 'VM      '           / VM-Visitor Mode; SM-Service Mode
# OB_GRADE= 'X       '           / A-fully within B-mostly within C|D-out of specs
# QC_FLAG = 'S11000  '           / quality flag, see release description
# ORIGFILE= 'UV_SRED_200112761_2001-11-04T04:07:10.253_RED775d2_1x1_15.fits' / Ori
# ASSON1  = 'UV_S2DX_200112761_2001-11-04T04:07:10.253_REDL775d2_1x1_15.fits'
# ASSON2  = 'UV_S2DX_200112761_2001-11-04T04:07:10.253_REDU775d2_1x1_15.fits'
# ASSON3  = 'r.UVES.2001-11-04T04:07:10.253_0000.fits_1.png'
# ASSOC3  = 'ANCILLARY.PREVIEW'
# ASSOM3  = '724daa593924bb181c09f234048237c3'
# CHECKSUM= 'LaU3LRR1LXR1LXR1'   / HDU checksum updated 2020-08-14T15:43:58
# DATASUM = '         0'         / data unit checksum updated 2020-08-14T15:43:16
# P3ORIG  = 'IDP     '           / ESO internal data product

# %%
fits.info(fname)
# Out:
# Filename: ../../Type1/LIN360/ADP.2020-08-14T15:43:54.025.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     983   ()
#   1  SPECTRUM      1 BinTableHDU     55   1R x 4C   [176719D, 176719E, 176719E, 176719E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([5818.72321511, 5818.74180309, 5818.76039106, ..., 9611.48137801, 9611.50499506, 9611.52861212], [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00], [  1.       ,   1.       ,   1.       , ...,   1.       ,   1.       ,   1.       ], [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00])],
#          dtype=(numpy.record, [('WAVE', '>f8', (176719,)), ('FLUX_REDUCED', '>f4', (176719,)), ('ERR_REDUCED', '>f4', (176719,)), ('BGFLUX_REDUCED', '>f4', (176719,))]))

# %%
plt.figure(figsize=(15,5))
plt.plot(xd['WAVE'][0],xd['FLUX_REDUCED'][0])
#plt.ylim(-.1,1)
plt.xlim(6550,6600)
plt.margins(x=0)
