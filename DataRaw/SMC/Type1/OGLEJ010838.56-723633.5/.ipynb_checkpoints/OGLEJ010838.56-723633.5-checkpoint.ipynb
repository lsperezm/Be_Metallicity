# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../Type1/OGLEJ010838.56-723633.5/ADP.2014-10-07T08:35:09.440.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASUM = '0       '           / data unit checksum updated 2014-09-23T20:44:41
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2014-08-09T04:01:19.342' / UT date when this file was written
# INSTRUME= 'HARPS   '           / Instrument used.
# RA      =            17.051640 / 01:08:12.3 RA (J2000) pointing (deg)
# DEC     =            -72.52821 / -72:31:41.5 DEC (J2000) pointing (deg)
# EQUINOX =                2000. / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =            1075.0004 / Total integration time
# MJD-OBS =       56878.15511325 / MJD start (2014-08-09T03:43:21.785)
# DATE-OBS= '2014-08-09T03:43:21.784' / Date of observation
# UTC     =            13397.000 / 03:43:17.000 UTC at start (sec)
# LST     =            72636.179 / 20:10:36.179 LST at start (sec)
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# ORIGIN  = 'ESO     '           / European Southern Observatory
# TELESCOP= 'ESO-3.6 '           / ESO Telescope Name
# M_EPOCH =                    F / T if resulting from multiple epochs
# SINGLEXP=                    T / T if resulting from single exposure
# PRODLVL =                    2 / Product level: 1-raw 2-science grade 3-advanced
# DISPELEM= 'HARPS Echelle'      / Dispersive element name
# SPECSYS = 'BARYCENT'           / Reference frame
# OBJECT  = 'smc-cep-4017'       / Object
# TEXPTIME=            1075.0004 / [s] Total integration time of all exposures
# EXT_OBJ =                    F / T if extended
# MJD-END =       56878.16755538 / [d] End of observation
# PROG_ID = '190.D-0237(E)'      / ESO Programme ID
# OBID1   =            100359902 / Observation block ID
# PROCSOFT= 'EGGS_3.5'
# OBSTECH = 'ECHELLE '           / Observation technique
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# FLUXCAL = 'UNCALIBRATED'       / Type of flux calibration
# CONTNORM=                    F / T if normalised to the continuum
# WAVELMIN=              378.153 / [nm] Minimum wavelength
# WAVELMAX=              691.316 / [nm] Maximum wavelength
# SPEC_BIN=                0.001 / [nm] Wavelength bin size
# TOT_FLUX=                    F / T if photom. cond. and all src flux captured
# FLUXERR =                 -1.0 / Uncertainty in flux scale (%)
# NCOMBINE=                    1 / # of combined raw science data files
# REFERENC= '        '           / Bibliographic reference
# SNR     =                  6.0 / Median signal to noise
# SPEC_RES=              80000.0 / Reference spectral resolving power
# GAIN    =                 0.66 / Conversion from electrons to ADU
# DETRON  =                  3.3 / Readout noise per output (e-)
# ASSOC1  = 'ANCILLARY.HARPSTAR' / Associated file 1 category
# ASSON1  = 'HARPS.2014-08-09T03:43:21.785_DRS_EGGS_3.5.tar' / Associated file 1 n
# ASSOM1  = '65b4c54fad916174401cfa63fd0134fb' / Associated file 1 md5sum
# PROV1   = 'HARPS.2014-08-09T03:43:21.785.fits' / Originating file name
# HIERARCH ESO ADA ABSROT END = 89.96976 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 89.96976 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID DEC = 0.00000 / 00:00:00.0 Guide star DEC J2000
# HIERARCH ESO ADA GUID RA = 0.000000 / 00:00:00.0 Guide star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.00000 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIPS = 2 / # of chips in detector array
# HIERARCH ESO DET DATE = '2001-11-01' / Installation date
# HIERARCH ESO DET DEC = 0.00000000 / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 1191 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 87.251 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 87.237 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'harps - Harps' / Name of detector system
# HIERARCH ESO DET OUTPUTS = 2 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0.00000000 / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = '104kpx/rr' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = '104kHz,1,high' / Readout speed
# HIERARCH ESO DET SHUT ID = 'SESO    ' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.018 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.017 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'IRIS    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = 600.0 / Interval between two successive te
# HIERARCH ESO DET TELE NO = 3 / # of sources active
# HIERARCH ESO DET TLM1 END = 150.60 / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = 'CCD Sensor1' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = 'CCD T1  ' / Description of telemetry param.
# HIERARCH ESO DET TLM1 START = 150.60 / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = 283.70 / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = 'Box Temp' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = 'EBOX T  ' / Description of telemetry param.
# HIERARCH ESO DET TLM2 START = 283.70 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = 2.50 / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = 'CCD Vacuum' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = 'CCD Vacuum' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = 2.60 / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 1 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 1 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1075.000435 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1075.0781 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 4296 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1075.000000 / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Observation category
# HIERARCH ESO DPR TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO DPR TYPE = 'STAR,DARK,NONE' / Observation type
# HIERARCH ESO INS ADC1 DEC = -723135.927073 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC1 END = 164.1280 / Position angle at end [deg].
# HIERARCH ESO INS ADC1 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC1 RA = 10812.059860 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADC2 DEC = -723135.935688 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC2 END = 348.6980 / Position angle at end [deg].
# HIERARCH ESO INS ADC2 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC2 RA = 10812.059860 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADCS NAME = 'IN      ' / ADC slide position.
# HIERARCH ESO INS ADCS NO = 2 / ADC slide position.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DET1 CTMAX = 120. / Maximum count during exposure.
# HIERARCH ESO INS DET1 CTMEAN = 74.9 / Average counts during exposure.
# HIERARCH ESO INS DET1 CTMIN = 34. / Minimum count during exposure.
# HIERARCH ESO INS DET1 CTRMS = 14.84 / RMS of counts during exposure.
# HIERARCH ESO INS DET1 CTTOT = 80536. / Total counts during exposure.
# HIERARCH ESO INS DET1 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET1 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET1 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET1 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET1 TMMEAN = 0.49 / Normalised mean exposure time.
# HIERARCH ESO INS DET1 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DET2 CTMAX = 42. / Maximum count during exposure.
# HIERARCH ESO INS DET2 CTMEAN = 20.3 / Average counts during exposure.
# HIERARCH ESO INS DET2 CTMIN = 7. / Minimum count during exposure.
# HIERARCH ESO INS DET2 CTRMS = 4.95 / RMS of counts during exposure.
# HIERARCH ESO INS DET2 CTTOT = 21843. / Total counts during exposure.
# HIERARCH ESO INS DET2 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET2 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET2 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET2 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET2 TMMEAN = 0.50 / Normalised mean exposure time.
# HIERARCH ESO INS DET2 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.HARPS_ICS-195279' / Data dictionary
# HIERARCH ESO INS HEFS ST = T / High Eff. Fiber Shutter If T=EGGS
# HIERARCH ESO INS ID = 'HARPS/1.57' / Instrument ID.
# HIERARCH ESO INS LAMP3 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS LAMP7 ST = F / Lamp activated.
# HIERARCH ESO INS MIRR1 ID = 'FIBB    ' / Mirror unique ID.
# HIERARCH ESO INS MIRR1 NAME = 'FIBB    ' / Mirror name.
# HIERARCH ESO INS MIRR1 NO = 4 / Mirror slide position.
# HIERARCH ESO INS MODE = 'EGGS    ' / Instrument mode used.
# HIERARCH ESO INS OPTI2 ID = 'CES     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI2 NAME = 'CES     ' / OPTIi name.
# HIERARCH ESO INS OPTI2 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI2 TYPE = 'FIBHEAD ' / OPTIi element.
# HIERARCH ESO INS OPTI3 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI3 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI3 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI3 TYPE = 'COVER   ' / OPTIi element.
# HIERARCH ESO INS OPTI4 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI4 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI4 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI4 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS OPTI4 TYPE = 'I2CELL  ' / OPTIi element.
# HIERARCH ESO INS OPTI5 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI5 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI5 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI5 TYPE = 'LAMPSELA' / OPTIi element.
# HIERARCH ESO INS OPTI6 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI6 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI6 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI6 TYPE = 'LAMPSELB' / OPTIi element.
# HIERARCH ESO INS OPTI7 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI7 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI7 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI7 TYPE = 'POLHEAD ' / OPTIi element.
# HIERARCH ESO INS PATH = 'DEFAULT ' / Optical path used.
# HIERARCH ESO INS ROT1 ENC = 6 / Absolute position [Enc].
# HIERARCH ESO INS ROT1 POS = 0.025 / Density [density].
# HIERARCH ESO INS SENS1 DETCOEF = 0.819807 / RMS of linear regression slope.
# HIERARCH ESO INS SENS1 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS1 ID = 'PRSS    ' / sensor ID.
# HIERARCH ESO INS SENS1 LRCONST = 0.006530 / Linear regression constant.
# HIERARCH ESO INS SENS1 LRRMS = 0.000011 / Linear regression RMS.
# HIERARCH ESO INS SENS1 MAX = 0.006622 / Maximum value.
# HIERARCH ESO INS SENS1 MEAN = 0.006573 / Average value.
# HIERARCH ESO INS SENS1 MIN = 0.006531 / Minimum value.
# HIERARCH ESO INS SENS1 NAME = 'Vacuum vessel pressure' / sensor common name.
# HIERARCH ESO INS SENS1 RMS = 0.000026 / RMS of samples over exposure.
# HIERARCH ESO INS SENS1 VAL = 0.006622 / Sensor numeric value.
# HIERARCH ESO INS SENS2 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS SENS2 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS2 ID = 'LNLV    ' / sensor ID.
# HIERARCH ESO INS SENS2 LRCONST = 100.000000 / Linear regression constant.
# HIERARCH ESO INS SENS2 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS SENS2 MAX = 100.000000 / Maximum value.
# HIERARCH ESO INS SENS2 MEAN = 100.000000 / Average value.
# HIERARCH ESO INS SENS2 MIN = 100.000000 / Minimum value.
# HIERARCH ESO INS SENS2 NAME = 'LN2 level' / sensor common name.
# HIERARCH ESO INS SENS2 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS SENS2 VAL = 100.000000 / Sensor numeric value.
# HIERARCH ESO INS SENS6 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS SENS6 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS6 ID = 'PRFP    ' / sensor ID.
# HIERARCH ESO INS SENS6 LRCONST = 0.000000 / Linear regression constant.
# HIERARCH ESO INS SENS6 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS SENS6 MAX = 0.000000 / Maximum value.
# HIERARCH ESO INS SENS6 MEAN = 0.000000 / Average value.
# HIERARCH ESO INS SENS6 MIN = 0.000000 / Minimum value.
# HIERARCH ESO INS SENS6 NAME = 'Fabry Perot P' / sensor common name.
# HIERARCH ESO INS SENS6 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS SENS6 VAL = 2.900000 / Sensor numeric value.
# HIERARCH ESO INS SENSOR2 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS SENSOR4 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR5 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR6 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR7 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR8 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR9 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SHUT1 ID = 'PMSH    ' / Shutter ID.
# HIERARCH ESO INS SHUT1 NAME = 'PM_Shutter' / Shutter name.
# HIERARCH ESO INS SHUT1 ST = T / Shutter open.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TEMP1 DETCOEF = 0.761964 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP1 GRAD = -0.000028 / Linear regression slope.
# HIERARCH ESO INS TEMP1 ID = 'CFAS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP1 LRCONST = 13.649842 / Linear regression constant.
# HIERARCH ESO INS TEMP1 LRRMS = 0.005477 / Linear regression RMS.
# HIERARCH ESO INS TEMP1 MAX = 13.650000 / Maximum value.
# HIERARCH ESO INS TEMP1 MEAN = 13.632000 / Average value.
# HIERARCH ESO INS TEMP1 MIN = 13.620000 / Minimum value.
# HIERARCH ESO INS TEMP1 NAME = 'HCFA air temperature' / Temperature sensor name.
# HIERARCH ESO INS TEMP1 RMS = 0.011225 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP1 VAL = 13.620 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP10 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP10 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP10 ID = 'PA108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP10 LRCONST = 16.821333 / Linear regression constant.
# HIERARCH ESO INS TEMP10 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP10 MAX = 16.821000 / Maximum value.
# HIERARCH ESO INS TEMP10 MEAN = 16.820333 / Average value.
# HIERARCH ESO INS TEMP10 MIN = 16.820000 / Minimum value.
# HIERARCH ESO INS TEMP10 NAME = 'CFC inside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP10 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP10 VAL = 16.821 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP11 DETCOEF = 0.250000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP11 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP11 ID = 'PA209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP11 LRCONST = 16.974000 / Linear regression constant.
# HIERARCH ESO INS TEMP11 LRRMS = 0.000707 / Linear regression RMS.
# HIERARCH ESO INS TEMP11 MAX = 16.976000 / Maximum value.
# HIERARCH ESO INS TEMP11 MEAN = 16.975000 / Average value.
# HIERARCH ESO INS TEMP11 MIN = 16.974000 / Minimum value.
# HIERARCH ESO INS TEMP11 NAME = 'Opt. Bench top-Detector' / Temperature sensor na
# HIERARCH ESO INS TEMP11 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP11 VAL = 16.976 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP12 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP12 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP12 ID = 'PA210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP12 LRCONST = 16.985333 / Linear regression constant.
# HIERARCH ESO INS TEMP12 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP12 MAX = 16.985000 / Maximum value.
# HIERARCH ESO INS TEMP12 MEAN = 16.984333 / Average value.
# HIERARCH ESO INS TEMP12 MIN = 16.984000 / Minimum value.
# HIERARCH ESO INS TEMP12 NAME = 'Opt. Bench bottom-Detector' / Temperature sensor
# HIERARCH ESO INS TEMP12 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP12 VAL = 16.984 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP13 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP13 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP13 ID = 'PA211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP13 LRCONST = 17.037333 / Linear regression constant.
# HIERARCH ESO INS TEMP13 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP13 MAX = 17.039000 / Maximum value.
# HIERARCH ESO INS TEMP13 MEAN = 17.038333 / Average value.
# HIERARCH ESO INS TEMP13 MIN = 17.038000 / Minimum value.
# HIERARCH ESO INS TEMP13 NAME = 'Opt. Bench top-left' / Temperature sensor name.
# HIERARCH ESO INS TEMP13 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP13 VAL = 17.038 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP14 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP14 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP14 ID = 'PA212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP14 LRCONST = 17.018667 / Linear regression constant.
# HIERARCH ESO INS TEMP14 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP14 MAX = 17.020000 / Maximum value.
# HIERARCH ESO INS TEMP14 MEAN = 17.019667 / Average value.
# HIERARCH ESO INS TEMP14 MIN = 17.019000 / Minimum value.
# HIERARCH ESO INS TEMP14 NAME = 'Opt. Bench bottom-Collimator' / Temperature sens
# HIERARCH ESO INS TEMP14 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP14 VAL = 17.019 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP15 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP15 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP15 ID = 'PA213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP15 LRCONST = 16.989333 / Linear regression constant.
# HIERARCH ESO INS TEMP15 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP15 MAX = 16.991000 / Maximum value.
# HIERARCH ESO INS TEMP15 MEAN = 16.990333 / Average value.
# HIERARCH ESO INS TEMP15 MIN = 16.990000 / Minimum value.
# HIERARCH ESO INS TEMP15 NAME = 'Opt. Bench top-right' / Temperature sensor name.
# HIERARCH ESO INS TEMP15 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP15 VAL = 16.990 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP16 DETCOEF = -0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP16 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP16 ID = 'PA214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP16 LRCONST = 17.022000 / Linear regression constant.
# HIERARCH ESO INS TEMP16 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP16 MAX = 17.022000 / Maximum value.
# HIERARCH ESO INS TEMP16 MEAN = 17.022000 / Average value.
# HIERARCH ESO INS TEMP16 MIN = 17.022000 / Minimum value.
# HIERARCH ESO INS TEMP16 NAME = 'Opt. Bench bottom-right' / Temperature sensor na
# HIERARCH ESO INS TEMP16 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP16 VAL = 17.022 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP17 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP17 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP17 ID = 'PA215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP17 LRCONST = 17.035667 / Linear regression constant.
# HIERARCH ESO INS TEMP17 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP17 MAX = 17.037000 / Maximum value.
# HIERARCH ESO INS TEMP17 MEAN = 17.036667 / Average value.
# HIERARCH ESO INS TEMP17 MIN = 17.036000 / Minimum value.
# HIERARCH ESO INS TEMP17 NAME = 'Opt. Bench top-Collimator' / Temperature sensor
# HIERARCH ESO INS TEMP17 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP17 VAL = 17.036 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP18 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP18 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP18 ID = 'PA216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP18 LRCONST = 17.007333 / Linear regression constant.
# HIERARCH ESO INS TEMP18 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP18 MAX = 17.008000 / Maximum value.
# HIERARCH ESO INS TEMP18 MEAN = 17.007333 / Average value.
# HIERARCH ESO INS TEMP18 MIN = 17.007000 / Minimum value.
# HIERARCH ESO INS TEMP18 NAME = 'Opt. Bench bottom-left' / Temperature sensor nam
# HIERARCH ESO INS TEMP18 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP18 VAL = 17.007 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP19 ID = 'PA2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP19 NAME = 'Opt. Bench Spare 1' / Temperature sensor name.
# HIERARCH ESO INS TEMP19 VAL = 17.026 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP2 ID = 'IODS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP2 NAME = 'Iodine cell temperature' / Temperature sensor na
# HIERARCH ESO INS TEMP2 VAL = 9999.000 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP20 ID = 'PA1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP20 NAME = 'VV inside Spare 1 - not conn.' / Temperature sen
# HIERARCH ESO INS TEMP20 VAL = 17.003 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP21 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP21 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP21 ID = 'PB101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP21 LRCONST = 17.013333 / Linear regression constant.
# HIERARCH ESO INS TEMP21 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP21 MAX = 17.015000 / Maximum value.
# HIERARCH ESO INS TEMP21 MEAN = 17.014333 / Average value.
# HIERARCH ESO INS TEMP21 MIN = 17.014000 / Minimum value.
# HIERARCH ESO INS TEMP21 NAME = 'Fiber Exit' / Temperature sensor name.
# HIERARCH ESO INS TEMP21 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP21 VAL = 17.015 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP22 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP22 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP22 ID = 'PB102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP22 LRCONST = 17.103333 / Linear regression constant.
# HIERARCH ESO INS TEMP22 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP22 MAX = 17.106000 / Maximum value.
# HIERARCH ESO INS TEMP22 MEAN = 17.105333 / Average value.
# HIERARCH ESO INS TEMP22 MIN = 17.104000 / Minimum value.
# HIERARCH ESO INS TEMP22 NAME = 'Collimator' / Temperature sensor name.
# HIERARCH ESO INS TEMP22 RMS = 0.000943 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP22 VAL = 17.106 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP23 DETCOEF = 0.250000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP23 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP23 ID = 'PB103   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP23 LRCONST = 17.043000 / Linear regression constant.
# HIERARCH ESO INS TEMP23 LRRMS = 0.000707 / Linear regression RMS.
# HIERARCH ESO INS TEMP23 MAX = 17.045000 / Maximum value.
# HIERARCH ESO INS TEMP23 MEAN = 17.044000 / Average value.
# HIERARCH ESO INS TEMP23 MIN = 17.043000 / Minimum value.
# HIERARCH ESO INS TEMP23 NAME = 'Echelle Grating' / Temperature sensor name.
# HIERARCH ESO INS TEMP23 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP23 VAL = 17.045 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP24 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP24 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP24 ID = 'PB104   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP24 LRCONST = 17.055667 / Linear regression constant.
# HIERARCH ESO INS TEMP24 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP24 MAX = 17.059000 / Maximum value.
# HIERARCH ESO INS TEMP24 MEAN = 17.057667 / Average value.
# HIERARCH ESO INS TEMP24 MIN = 17.057000 / Minimum value.
# HIERARCH ESO INS TEMP24 NAME = 'Grism   ' / Temperature sensor name.
# HIERARCH ESO INS TEMP24 RMS = 0.000943 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP24 VAL = 17.059 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP25 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP25 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP25 ID = 'PB105   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP25 LRCONST = 17.020333 / Linear regression constant.
# HIERARCH ESO INS TEMP25 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP25 MAX = 17.020000 / Maximum value.
# HIERARCH ESO INS TEMP25 MEAN = 17.019333 / Average value.
# HIERARCH ESO INS TEMP25 MIN = 17.019000 / Minimum value.
# HIERARCH ESO INS TEMP25 NAME = 'Camera Optics Detector side' / Temperature senso
# HIERARCH ESO INS TEMP25 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP25 VAL = 17.019 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP26 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP26 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP26 ID = 'PB106   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP26 LRCONST = 16.820333 / Linear regression constant.
# HIERARCH ESO INS TEMP26 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP26 MAX = 16.821000 / Maximum value.
# HIERARCH ESO INS TEMP26 MEAN = 16.820333 / Average value.
# HIERARCH ESO INS TEMP26 MIN = 16.820000 / Minimum value.
# HIERARCH ESO INS TEMP26 NAME = 'Camera Optics Collimator side' / Temperature sen
# HIERARCH ESO INS TEMP26 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP26 VAL = 16.820 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP27 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP27 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP27 ID = 'PB107   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP27 LRCONST = 16.169333 / Linear regression constant.
# HIERARCH ESO INS TEMP27 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP27 MAX = 16.170000 / Maximum value.
# HIERARCH ESO INS TEMP27 MEAN = 16.169333 / Average value.
# HIERARCH ESO INS TEMP27 MIN = 16.169000 / Minimum value.
# HIERARCH ESO INS TEMP27 NAME = 'Detector-Head body back' / Temperature sensor na
# HIERARCH ESO INS TEMP27 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP27 VAL = 16.169 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP28 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP28 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP28 ID = 'PB108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP28 LRCONST = 16.363333 / Linear regression constant.
# HIERARCH ESO INS TEMP28 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP28 MAX = 16.365000 / Maximum value.
# HIERARCH ESO INS TEMP28 MEAN = 16.364333 / Average value.
# HIERARCH ESO INS TEMP28 MIN = 16.364000 / Minimum value.
# HIERARCH ESO INS TEMP28 NAME = 'Detector-Head holding ring' / Temperature sensor
# HIERARCH ESO INS TEMP28 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP28 VAL = 16.365 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP29 DETCOEF = 0.024194 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP29 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP29 ID = 'PB209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP29 LRCONST = 15.095333 / Linear regression constant.
# HIERARCH ESO INS TEMP29 LRRMS = 0.002593 / Linear regression RMS.
# HIERARCH ESO INS TEMP29 MAX = 15.100000 / Maximum value.
# HIERARCH ESO INS TEMP29 MEAN = 15.096333 / Average value.
# HIERARCH ESO INS TEMP29 MIN = 15.094000 / Minimum value.
# HIERARCH ESO INS TEMP29 NAME = 'VV outside Foot S2' / Temperature sensor name.
# HIERARCH ESO INS TEMP29 RMS = 0.002625 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP29 VAL = 15.095 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP3 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP3 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP3 ID = 'PA101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP3 LRCONST = 17.105333 / Linear regression constant.
# HIERARCH ESO INS TEMP3 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP3 MAX = 17.106000 / Maximum value.
# HIERARCH ESO INS TEMP3 MEAN = 17.105333 / Average value.
# HIERARCH ESO INS TEMP3 MIN = 17.105000 / Minimum value.
# HIERARCH ESO INS TEMP3 NAME = 'VV inside top' / Temperature sensor name.
# HIERARCH ESO INS TEMP3 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP3 VAL = 17.105 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP30 DETCOEF = 0.964286 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP30 GRAD = -0.000005 / Linear regression slope.
# HIERARCH ESO INS TEMP30 ID = 'PB210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP30 LRCONST = 14.383667 / Linear regression constant.
# HIERARCH ESO INS TEMP30 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP30 MAX = 14.381000 / Maximum value.
# HIERARCH ESO INS TEMP30 MEAN = 14.377667 / Average value.
# HIERARCH ESO INS TEMP30 MIN = 14.375000 / Minimum value.
# HIERARCH ESO INS TEMP30 NAME = 'Air-Coude room W' / Temperature sensor name.
# HIERARCH ESO INS TEMP30 RMS = 0.002494 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP30 VAL = 14.375 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP31 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP31 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP31 ID = 'PB211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP31 LRCONST = 15.370333 / Linear regression constant.
# HIERARCH ESO INS TEMP31 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP31 MAX = 15.371000 / Maximum value.
# HIERARCH ESO INS TEMP31 MEAN = 15.370333 / Average value.
# HIERARCH ESO INS TEMP31 MIN = 15.370000 / Minimum value.
# HIERARCH ESO INS TEMP31 NAME = 'Air-HARPS Enclosure' / Temperature sensor name.
# HIERARCH ESO INS TEMP31 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP31 VAL = 15.370 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP32 DETCOEF = 0.057692 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP32 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP32 ID = 'PB212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP32 LRCONST = 17.052333 / Linear regression constant.
# HIERARCH ESO INS TEMP32 LRRMS = 0.001650 / Linear regression RMS.
# HIERARCH ESO INS TEMP32 MAX = 17.053000 / Maximum value.
# HIERARCH ESO INS TEMP32 MEAN = 17.051333 / Average value.
# HIERARCH ESO INS TEMP32 MIN = 17.049000 / Minimum value.
# HIERARCH ESO INS TEMP32 NAME = 'Air-HARPS Isolation Box' / Temperature sensor na
# HIERARCH ESO INS TEMP32 RMS = 0.001700 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP32 VAL = 17.052 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP33 DETCOEF = 0.157895 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP33 GRAD = -0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP33 ID = 'PB213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP33 LRCONST = 17.361333 / Linear regression constant.
# HIERARCH ESO INS TEMP33 LRRMS = 0.001886 / Linear regression RMS.
# HIERARCH ESO INS TEMP33 MAX = 17.362000 / Maximum value.
# HIERARCH ESO INS TEMP33 MEAN = 17.359333 / Average value.
# HIERARCH ESO INS TEMP33 MIN = 17.357000 / Minimum value.
# HIERARCH ESO INS TEMP33 NAME = 'Air-through Fan 4 IB' / Temperature sensor name.
# HIERARCH ESO INS TEMP33 RMS = 0.002055 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP33 VAL = 17.357 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP34 DETCOEF = 0.250000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP34 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP34 ID = 'PB214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP34 LRCONST = 17.015000 / Linear regression constant.
# HIERARCH ESO INS TEMP34 LRRMS = 0.000707 / Linear regression RMS.
# HIERARCH ESO INS TEMP34 MAX = 17.017000 / Maximum value.
# HIERARCH ESO INS TEMP34 MEAN = 17.016000 / Average value.
# HIERARCH ESO INS TEMP34 MIN = 17.015000 / Minimum value.
# HIERARCH ESO INS TEMP34 NAME = 'Image Scrambler outside VV' / Temperature sensor
# HIERARCH ESO INS TEMP34 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP34 VAL = 17.016 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP35 DETCOEF = 0.837425 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP35 GRAD = -0.000063 / Linear regression slope.
# HIERARCH ESO INS TEMP35 ID = 'PB215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP35 LRCONST = 16.599333 / Linear regression constant.
# HIERARCH ESO INS TEMP35 LRRMS = 0.013671 / Linear regression RMS.
# HIERARCH ESO INS TEMP35 MAX = 16.571000 / Maximum value.
# HIERARCH ESO INS TEMP35 MEAN = 16.523333 / Average value.
# HIERARCH ESO INS TEMP35 MIN = 16.495000 / Minimum value.
# HIERARCH ESO INS TEMP35 NAME = 'CFC outside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP35 RMS = 0.033905 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP35 VAL = 16.495 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP36 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP36 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP36 ID = 'PB216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP36 LRCONST = 17.043667 / Linear regression constant.
# HIERARCH ESO INS TEMP36 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP36 MAX = 17.044000 / Maximum value.
# HIERARCH ESO INS TEMP36 MEAN = 17.043667 / Average value.
# HIERARCH ESO INS TEMP36 MIN = 17.043000 / Minimum value.
# HIERARCH ESO INS TEMP36 NAME = 'VV outside Detector side' / Temperature sensor n
# HIERARCH ESO INS TEMP36 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP36 VAL = 17.044 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP37 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP37 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP37 ID = 'PB2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP37 LRCONST = 17.160333 / Linear regression constant.
# HIERARCH ESO INS TEMP37 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP37 MAX = 17.160000 / Maximum value.
# HIERARCH ESO INS TEMP37 MEAN = 17.159333 / Average value.
# HIERARCH ESO INS TEMP37 MIN = 17.159000 / Minimum value.
# HIERARCH ESO INS TEMP37 NAME = 'VV outside Collimator side' / Temperature sensor
# HIERARCH ESO INS TEMP37 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP37 VAL = 17.159 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP38 ID = 'PB1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP38 NAME = 'Spectrograph Spare 2' / Temperature sensor name.
# HIERARCH ESO INS TEMP38 VAL = 17.054 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP4 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP4 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP4 ID = 'PA102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP4 LRCONST = 16.946667 / Linear regression constant.
# HIERARCH ESO INS TEMP4 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP4 MAX = 16.947000 / Maximum value.
# HIERARCH ESO INS TEMP4 MEAN = 16.946667 / Average value.
# HIERARCH ESO INS TEMP4 MIN = 16.946000 / Minimum value.
# HIERARCH ESO INS TEMP4 NAME = 'VV inside bottom' / Temperature sensor name.
# HIERARCH ESO INS TEMP4 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP4 VAL = 16.947 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP40 DETCOEF = 0.098515 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP40 GRAD = 0.000006 / Linear regression slope.
# HIERARCH ESO INS TEMP40 ID = 'CCD1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP40 LRCONST = 148.147480 / Linear regression constant.
# HIERARCH ESO INS TEMP40 LRRMS = 0.005709 / Linear regression RMS.
# HIERARCH ESO INS TEMP40 MAX = 148.160000 / Maximum value.
# HIERARCH ESO INS TEMP40 MEAN = 148.150751 / Average value.
# HIERARCH ESO INS TEMP40 MIN = 148.140000 / Minimum value.
# HIERARCH ESO INS TEMP40 NAME = 'CCD control reference' / Temperature sensor name
# HIERARCH ESO INS TEMP40 RMS = 0.006013 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP40 VAL = 148.150 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP41 DETCOEF = 0.129765 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP41 GRAD = 0.000007 / Linear regression slope.
# HIERARCH ESO INS TEMP41 ID = 'CCD2    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP41 LRCONST = 148.215216 / Linear regression constant.
# HIERARCH ESO INS TEMP41 LRRMS = 0.005896 / Linear regression RMS.
# HIERARCH ESO INS TEMP41 MAX = 148.230000 / Maximum value.
# HIERARCH ESO INS TEMP41 MEAN = 148.219163 / Average value.
# HIERARCH ESO INS TEMP41 MIN = 148.210000 / Minimum value.
# HIERARCH ESO INS TEMP41 NAME = 'CCD secondary' / Temperature sensor name.
# HIERARCH ESO INS TEMP41 RMS = 0.006321 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP41 VAL = 148.220 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP42 DETCOEF = 0.000001 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP42 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP42 ID = 'IBX1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP42 LRCONST = 17.003674 / Linear regression constant.
# HIERARCH ESO INS TEMP42 LRRMS = 0.001908 / Linear regression RMS.
# HIERARCH ESO INS TEMP42 MAX = 17.008000 / Maximum value.
# HIERARCH ESO INS TEMP42 MEAN = 17.003672 / Average value.
# HIERARCH ESO INS TEMP42 MIN = 16.998000 / Minimum value.
# HIERARCH ESO INS TEMP42 NAME = 'Isolation box control reference' / Temperature s
# HIERARCH ESO INS TEMP42 RMS = 0.001908 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP42 VAL = 17.005 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP43 DETCOEF = 0.039875 / RMS of linear regression slope.
# ...
# HIERARCH ESO DRS CAL TH COEFF LL144 = 1.06214083340654E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG LL = 4 / degre polyn fit ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL339 = -4.03892189539616E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL96 = 0.0136899882123136 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL97 = -4.67728748797088E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL94 = -9.47214736326951E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL95 = 4285.32029790206 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL92 = -4.70124091796704E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL93 = 5.42221382134935E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL90 = 4255.35860851391 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL91 = 0.0135998713359804 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL98 = -1.46012064798299E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL99 = 1.44408785981398E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X243 = -0.141005171665348 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X242 = 1147.76072818556 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X241 = -4152637.48428443 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X240 = 5634571779.09219 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X247 = 1200.10816136875 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X246 = -4383284.43191958 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X245 = 6004026210.12282 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X244 = 6.49672823704795E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X320 = 5730351027.15595 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X321 = -3619540.45081645 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X249 = 6.66572729987229E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X248 = -0.146048322885003 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X324 = 3.56492218340439E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X325 = 5379082375.38132 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X326 = -3363558.7464054 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X277 = 1031.20685847517 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X322 = 857.412296276485 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL310 = 6208.55949029649 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X323 = -0.0902780276156888 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL219 = 1.04954406133563E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL218 = -1.77838663372004E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL217 = -5.61938901043869E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL216 = 0.0164986612661494 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL215 = 5156.64459799228 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL188 = 1.26514199862171E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL213 = -3.52036509407999E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL212 = -5.54028490015271E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL211 = 0.0163582796260971 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL210 = 5113.32322386101 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X48 = -0.34802291179588 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X49 = 2.1762761367475E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X40 = 5858029047.11674 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X41 = -5895746.97064243 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X42 = 2225.30867169057 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X43 = -0.373334143247271 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X44 = 2.34898717564135E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X45 = 5562848523.03208 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X46 = -5564234.18193707 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X47 = 2087.26796134158 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X188 = -0.207486819212243 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X189 = 1.05781902029264E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X184 = 9.54085858466258E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X185 = 6119583535.17634 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X186 = -4990582.35641874 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X187 = 1526.31279503432 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X180 = 5326407949.4184 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X181 = -4382533.31188969 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X182 = 1352.32622805504 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL182 = -5.31580089248356E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL356 = 0.0219045521533016 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL357 = -7.50477843342696E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL354 = 1.07715391181239E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL355 = 6836.13145562614 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL352 = -7.41469818598278E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL181 = 0.0155699169160169 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL350 = 6760.20278388874 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL351 = 0.0216634259551243 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL358 = -5.8555194455017E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL359 = 4.51017501384054E-18 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL323 = -2.47291212872044E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL322 = -6.90606263622441E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL321 = 0.0203032588452959 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL320 = 6337.85400423814 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL327 = -6.94449214965131E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL326 = 0.0205154553161279 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL325 = 6404.54170663903 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL324 = 1.90896518582663E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL329 = 4.13146363599835E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL328 = -4.09145970215275E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X287 = 1032.44376549927 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X286 = -4063825.69482193 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X119 = 1.42492723357405E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X118 = -0.25091307844379 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X113 = -0.254872548198716 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X112 = 1671.13704221397 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X111 = -4870337.52944912 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X110 = 5323185820.04808 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X117 = 1657.03327364694 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X116 = -4864033.70923047 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X115 = 5354599094.91326 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X114 = 1.45784713191018E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH LITTROW ONE MEAN = 1.63453756359651 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH LITTROW THREE MAXDEV = 75.450227469174 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF LL168 = -3.27426904608828E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL107 = -4.71143026749352E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL106 = 0.0138832747657317 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL105 = 4346.52401437048 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL104 = -1.01848914780714E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL103 = 3.92105134298205E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL102 = -4.75604148166745E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL101 = 0.0137921519592293 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL100 = 4315.70346772901 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH ORDER NRED = 26 / nb red orders
# HIERARCH ESO DRS CAL TH COEFF LL109 = 2.09451343624291E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL108 = -2.32524547466485E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL166 = 0.0151981562849041 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X280 = 5246479307.13489 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL198 = -2.16521647406287E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL199 = 2.07487927959631E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL194 = 2.79351577862385E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL195 = 4987.62121112637 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL196 = 0.0159558932867025 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG X = 4 / degre polyn fit x(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL190 = 4947.08371593011 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL191 = 0.015823891495584 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL192 = -5.38013827384425E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL193 = -2.69549835379859E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X209 = 7.81940041254608E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X208 = -0.158309574249283 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X207 = 1202.04255997246 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X206 = -4056872.09502339 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X205 = 5134864416.98936 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X204 = 8.81100012965011E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X203 = -0.177004091313838 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X202 = 1333.57510692613 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X201 = -4465890.52337053 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X200 = 5608709603.60786 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X99 = 1.66991075499089E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X98 = -0.285883024593375 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X93 = -0.311898979172302 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X92 = 1989.40231784872 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X91 = -5640099.47306401 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X90 = 5996731281.80061 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X97 = 1835.52410451949 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X96 = -5238280.58869415 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X95 = 5606376031.0152 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X94 = 1.83391882318709E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X281 = -3591918.53928292 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH FILE LINES = 'TH_sel_R100000_A0.5-0.25-0.1.dat' / file n
# HIERARCH ESO DRS CAL TH COEFF LL74 = 1.87861364372374E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL75 = 4167.94640647423 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL76 = 0.0133093496990162 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL77 = -4.53221678178543E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL70 = 4139.60156164927 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL71 = 0.0132151140457595 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL72 = -4.48978643408947E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL73 = -2.03370783450496E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL78 = -2.01824929850367E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL79 = 2.18425112810299E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X278 = -0.118745279714383 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X279 = 5.12817266067136E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X272 = 1022.19128530432 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X273 = -0.118862083361795 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X270 = 5601266604.54888 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X271 = -3907303.85943259 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X276 = -3980443.1102932 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X19 = 2.80855452127868E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X274 = 5.18358640853849E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X275 = 5762106078.33473 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL240 = 5432.76609163485 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL241 = 0.017394586545595 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL242 = -5.95987214966706E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL243 = -4.14285203865731E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL244 = -6.53212833797277E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL245 = 5481.6946405132 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL246 = 0.0175446283113849 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL247 = -5.94642521728972E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL248 = -2.90896618059196E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL249 = 2.48725997475768E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH LITTROW THREE RMS = 22.5358457397214 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF X71 = -5452501.86342134 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X70 = 5637255514.25891 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X73 = -0.31888782540192 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X72 = 1977.82801708081 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X75 = 5375380698.62822 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X74 = 1.92825165704628E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X77 = 1861.49691401285 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X76 = -5165389.22028964 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X79 = 1.79132416735068E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X78 = -0.298180611347334 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X157 = 1542.65623353325 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X156 = -4808631.76271612 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X155 = 5621319704.53168 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X154 = 1.12131259451931E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X153 = -0.207961460153155 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X152 = 1446.4965117814 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X151 = -4472086.79053919 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X150 = 5185239236.37645 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X159 = 1.1763963108251E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X158 = -0.219974995888433 / coeff x=(ll,order)
# ARCFILE = 'ADP.2014-10-07T08:35:09.440.fits' / Archive File Name
# P3ORIG  = 'IDP     '           / ESO internal data product
# HDRVER  = '2014-10-07T12:49:13.122' / ESO Archive header timetag
# COMMENT processed by hotfly version 2.0 on 2025-04-26T15:45:11.971 UT

# %%
fits.info(fname)
# Out:
# Filename: ../../Type1/OGLEJ010838.56-723633.5/ADP.2014-10-07T08:35:09.440.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    3357   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [313164D, 313164E, 313164E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([3781.53, 3781.54, 3781.55, ..., 6913.14, 6913.15, 6913.16], [-6.25901031e+01, -1.04261789e+01,  9.93832474e+01, ...,  4.05639648e+01,  3.25566254e+01,  3.78372917e+01], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (313164,)), ('FLUX', '>f4', (313164,)), ('ERR', '>f4', (313164,))]))

# %%
plt.figure(figsize=(70,15))
plt.plot(xd['WAVE'][0],xd['FLUX'][0],'.-')
#plt.ylim(-.1,1)
#plt.xlim(6625,6650)
plt.margins(x=0)
