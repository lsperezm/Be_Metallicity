# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../Type4/OGLEJ003836.25-734813.4/ADP.2016-09-21T09:18:32.929.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Sep 20 12:27:19 2016
# BITPIX  =                    8
# NAXIS   =                    0
# EXTEND  =                    T / File contains extensions
# DATASUM = '         0'         / data unit checksum updated 2016-09-20T12:27:20
# ORIGIN  = 'ESO-LASILLA'        / Origin
# FILENAME= 'f27831.bdf'         / Original file base-name
# OBJECT  = 'hv1338  '           / Object
# RA      =             9.499255 / [deg] Right ascension
# DEC     =            -73.82566 / [deg] Declination
# EQUINOX =               2000.0 / Equinox
# DATE-OBS= '2005-09-30T08:03:56.439' / Start of observation
# MJD-OBS =       53643.33606990 / [d] Start of observation
# TM-START=       29036.44022474 / MIDAS desc.: O_TIME(5)
# EXPTIME =             599.9999 / [s] Total integration time
# TELESCOP= 'MPG/ESO-2.2'        / Telescope
# INSTRUME= 'FEROS   '           / Instrument
# RADECSYS= 'FK5     '           / Reference frame
# OBSERVER= 'UNKNOWN '           / MIDAS desc.: OBSERVER(1)
# AIRMASS =             1.605443 / MIDAS desc.: O_AIRM(1)
# NLINES  =                    9
# UTC     =            28950.001 / 08:02:30.001 UTC at start (sec)
# LST     =            14176.044 / 03:56:16.044 LST at start (sec)
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# EXPTYPE = 'SCIENCE '
# FOCOFF  =              1571.44
# PIPEFILE= 'r.FEROS.2005-09-30T08:03:56.440.1101.fits'
# MEFFILE = 'r.FEROS.2005-09-30T08:03:56.440.1081.fits'
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.9 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIP1 DATE = '03/10/03' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP1 ID = 'CCD-60  ' / Detector chip identification
# HIERARCH ESO DET CHIP1 INDEX = 1 / Chip index
# HIERARCH ESO DET CHIP1 NAME = 'EEV CCD-44' / Detector chip name
# HIERARCH ESO DET CHIP1 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX = 15. / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY = 15. / Size of pixel in Y
# HIERARCH ESO DET CHIP1 X = 1 / X location in array
# HIERARCH ESO DET CHIP1 XGAP = 0. / Gap between chips along x
# HIERARCH ESO DET CHIP1 Y = 1 / Y location in array
# HIERARCH ESO DET CHIP1 YGAP = 0. / Gap between chips along y
# HIERARCH ESO DET CHIPS = 1 / # of chips in detector array
# HIERARCH ESO DET DATE = '03/10/03' / Installation date
# HIERARCH ESO DET DEC = 0. / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 16161 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 38.513 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 38.518 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = '        ' / Detector system Id
# HIERARCH ESO DET NAME = 'feros - FEROS' / Name of detector system
# HIERARCH ESO DET OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET OUT1 CONAD = 0.83 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 GAIN = 1.2 / Conversion from electrons to ADU
# HIERARCH ESO DET OUT1 ID = 'R       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 INDEX = 2 / Output index
# HIERARCH ESO DET OUT1 NAME = 'R       ' / Description of output
# HIERARCH ESO DET OUT1 NX = 1024 / valid pixels along X
# HIERARCH ESO DET OUT1 NY = 2048 / valid pixels along Y
# HIERARCH ESO DET OUT1 OVSCX = 25 / Overscan region in X
# HIERARCH ESO DET OUT1 OVSCY = 0 / Overscan region in Y
# HIERARCH ESO DET OUT1 PRSCX = 25 / Prescan region in X
# HIERARCH ESO DET OUT1 PRSCY = 0 / Prescan region in Y
# HIERARCH ESO DET OUT1 RON = 2.6 / Readout noise per output (e-)
# HIERARCH ESO DET OUT1 X = 2048 / X location of output
# HIERARCH ESO DET OUT1 Y = 1 / Y location of output
# HIERARCH ESO DET OUTPUTS = 1 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0. / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = 'R 60Kps High Gai' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = 'Slow    ' / Readout speed
# HIERARCH ESO DET SHUT ID = 'Feros shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.001 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.001 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'IRIS    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = 1. / Interval between two successive te
# HIERARCH ESO DET TELE NO = 5 / # of sources active
# HIERARCH ESO DET TLM1 END = 138. / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = 'CCD     ' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = 'CCD Cold Plate' / Description of telemetry par
# HIERARCH ESO DET TLM1 START = 138. / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = 139.7 / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = 'CCD2    ' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = 'CCD Cold Plate2' / Description of telemetry pa
# HIERARCH ESO DET TLM2 START = 139.7 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = 0. / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = 'FBOX    ' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = 'FBOX    ' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = 0. / Telemetry value at read start
# HIERARCH ESO DET TLM4 END = 273.2 / Telemetry value at read completion
# HIERARCH ESO DET TLM4 ID = 'Pulpo Reference' / ID of telemetry sensor
# HIERARCH ESO DET TLM4 NAME = 'Pulpo Reference' / Description of telemetry pa
# HIERARCH ESO DET TLM4 START = 273.2 / Telemetry value at read start
# HIERARCH ESO DET TLM5 END = 0. / Telemetry value at read completion
# HIERARCH ESO DET TLM5 ID = 'Vacuum  ' / ID of telemetry sensor
# HIERARCH ESO DET TLM5 NAME = 'Vacuum  ' / Description of telemetry param.
# HIERARCH ESO DET TLM5 START = 0. / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 2 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 599.999933 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 600.4494 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 1074 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 2048 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 600. / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO INS ADC1 DEC = -734932.9468 / Telescope desclination [deg].
# HIERARCH ESO INS ADC1 END = 119.045 / Position angle at end [deg].
# HIERARCH ESO INS ADC1 MODE = 'OFF     ' / ADC mode.
# HIERARCH ESO INS ADC1 RA = 3759.760506 / Telescope right ascension [deg].
# HIERARCH ESO INS ADC2 DEC = -734932.9468 / Telescope desclination [deg].
# HIERARCH ESO INS ADC2 END = 5.8732 / Position angle at end [deg].
# HIERARCH ESO INS ADC2 MODE = 'OFF     ' / ADC mode.
# HIERARCH ESO INS ADC2 RA = 3759.760506 / Telescope right ascension [deg].
# HIERARCH ESO INS ADCA NAME = 'OUT     ' / ADC arm position name.
# HIERARCH ESO INS CALMIRR1 ID = 'PARK    ' / Sliding cal. sel. mirror unique ID
# HIERARCH ESO INS CALMIRR1 NAME = 'PARK    ' / Sliding cal. sel. mirror name.
# HIERARCH ESO INS CALMIRR1 NO = 1 / Sliding cal. sel. mirror number.
# HIERARCH ESO INS CALMIRR1 TYPE = 'FREE    ' / Sliding cal. sel. mirror element.
# HIERARCH ESO INS CALMIRR2 ID = 'LAMP1   ' / Rotating sel. mirror unique ID.
# HIERARCH ESO INS CALMIRR2 NAME = 'LAMP1   ' / Rotating sel. mirror name.
# HIERARCH ESO INS CALMIRR2 NO = 2 / Rotating sel. mirror number.
# HIERARCH ESO INS CALMIRR2 TYPE = 'LAMP    ' / Rotating sel. mirror element.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.FEROS_ICS-1.6' / Data dictionary for
# HIERARCH ESO INS FILT1 ENC = 9816 / Absolute position [Enc].
# HIERARCH ESO INS FILT1 POS = 1.778 / NDFW Position [density].
# HIERARCH ESO INS ID = 'FEROS/1.56' / Instrument ID.
# HIERARCH ESO INS MIRR3 NAME = 'FEROS   ' / FEROS-WFI sel.mirror name.
# HIERARCH ESO INS MODE = 'FEROS   ' / Instrument mode used.
# HIERARCH ESO INS PATH = 'DEFAULT ' / Optical path used.
# HIERARCH ESO INS SENS7 ID = 'HUMI    ' / sensor ID.
# HIERARCH ESO INS SENS7 MAX = 19.83 / Maximum value.
# HIERARCH ESO INS SENS7 MEAN = 19.802727 / Average value.
# HIERARCH ESO INS SENS7 MIN = 19.79 / Minimum value.
# HIERARCH ESO INS SENS7 NAME = 'Humidity' / sensor common name.
# HIERARCH ESO INS SENS7 VAL = 19.76 / Sensor numeric value.
# HIERARCH ESO INS SENS8 ID = 'LNLV    ' / sensor ID.
# HIERARCH ESO INS SENS8 NAME = 'LN2 level' / sensor common name.
# HIERARCH ESO INS SENS8 VAL = 39.24 / Sensor numeric value.
# HIERARCH ESO INS SHUT1 ID = 'DARK    ' / FCU shutter unique ID.
# HIERARCH ESO INS SHUT1 NAME = 'DARK    ' / FCU shutter name.
# HIERARCH ESO INS SHUT1 NO = 1 / FCU shutter number.
# HIERARCH ESO INS SHUT1 TYPE = 'FREE    ' / FCU shutter element.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TEMP1 ID = 'TEMP1   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP1 MAX = 14.22 / Maximum value [C].
# HIERARCH ESO INS TEMP1 MEAN = 14.22 / Average value [C].
# HIERARCH ESO INS TEMP1 MIN = 14.22 / Minimum value [C].
# HIERARCH ESO INS TEMP1 NAME = 'Temperature 1' / Temperature sensor name.
# HIERARCH ESO INS TEMP1 VAL = 14.22 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP2 ID = 'TEMP2   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP2 MAX = 14.31 / Maximum value [C].
# HIERARCH ESO INS TEMP2 MEAN = 14.31 / Average value [C].
# HIERARCH ESO INS TEMP2 MIN = 14.31 / Minimum value [C].
# HIERARCH ESO INS TEMP2 NAME = 'Temperature 2' / Temperature sensor name.
# HIERARCH ESO INS TEMP2 VAL = 14.31 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP3 ID = 'TEMP3   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP3 MAX = 14.42 / Maximum value [C].
# HIERARCH ESO INS TEMP3 MEAN = 14.403636 / Average value [C].
# HIERARCH ESO INS TEMP3 MIN = 14.4 / Minimum value [C].
# HIERARCH ESO INS TEMP3 NAME = 'Temperature 3' / Temperature sensor name.
# HIERARCH ESO INS TEMP3 VAL = 14.39 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP4 ID = 'TEMP4   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP4 MAX = 14.3 / Maximum value [C].
# HIERARCH ESO INS TEMP4 MEAN = 14.296364 / Average value [C].
# HIERARCH ESO INS TEMP4 MIN = 14.28 / Minimum value [C].
# HIERARCH ESO INS TEMP4 NAME = 'Temperature 4' / Temperature sensor name.
# HIERARCH ESO INS TEMP4 VAL = 14.3 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP5 ID = 'TEMP5   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP5 MAX = 14.47 / Maximum value [C].
# HIERARCH ESO INS TEMP5 MEAN = 14.468182 / Average value [C].
# HIERARCH ESO INS TEMP5 MIN = 14.46 / Minimum value [C].
# HIERARCH ESO INS TEMP5 NAME = 'Temperature 5' / Temperature sensor name.
# HIERARCH ESO INS TEMP5 VAL = 14.47 / Temperature sensor numeric value [
# HIERARCH ESO INS TEMP6 ID = 'TEMP6   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP6 MAX = 13.55 / Maximum value [C].
# HIERARCH ESO INS TEMP6 MEAN = 13.524545 / Average value [C].
# HIERARCH ESO INS TEMP6 MIN = 13.47 / Minimum value [C].
# HIERARCH ESO INS TEMP6 NAME = 'Temperature 6' / Temperature sensor name.
# HIERARCH ESO INS TEMP6 VAL = 13.55 / Temperature sensor numeric value [
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.10' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 1105 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID = 171381 / Observation block ID
# HIERARCH ESO OBS NAME = 'SMC_HV1338_ph04' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 2474 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '074.D-0086(A)' / ESO program identification
# HIERARCH ESO OBS START = '2005-09-30T08:00:03' / OB start time
# HIERARCH ESO OBS TARG NAME = 'hv1338  ' / OB target name
# HIERARCH ESO OBS TPLNO = 2 / Template number within OB
# HIERARCH ESO OCS DET1 IMGNAME = 'FEROS_ech_obs_objsky' / Data File Name.
# HIERARCH ESO OCS DET1 NAMING = 'Sequence-Naming' / Data File Naming Type.
# HIERARCH ESO TEL AG FIBSELEC = 'OBJFIB  ' / Fiber currently used (SKY or OBJ)
# HIERARCH ESO TEL AG FIBX = 0. / Fiber position X
# HIERARCH ESO TEL AG FIBY = 0. / Fiber position Y
# HIERARCH ESO TEL AG REFX = 496.5 / Autoguider reference pixel X
# HIERARCH ESO TEL AG REFY = 254.5 / Autoguider reference pixel Y
# HIERARCH ESO TEL AIRM END = 1.613 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.592 / Airmass at start
# HIERARCH ESO TEL ALT = 38.846 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 1.61 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = -1. / Observatory Seeing queried
# HIERARCH ESO TEL AMBI PRES END = 770.7 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 770.6 / Observatory ambient air pr
# HIERARCH ESO TEL AMBI RHUM = 25. / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 7.8 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 36. / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 8.05 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 15.778 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST = F / True when chopping is active
# HIERARCH ESO TEL DATE = '2000-10-15T15:21:35.745' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-2P2-DIC.TCS-1.8' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'CLOSED  ' / Dome status
# HIERARCH ESO TEL FOCU ID = 'CA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 8.009 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 11.65 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = 24894. / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2335. / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2543 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7346 / Tel geo longitute (+=East) (deg)
# HIERARCH ESO TEL HSS HUMI1 END = 18.81 / outside south of dome in shadow
# HIERARCH ESO TEL HSS HUMI1 START = 16.84 / outside south of dome in s
# HIERARCH ESO TEL HSS HUMI2 END = 19.32 / inside dome midheight
# HIERARCH ESO TEL HSS HUMI2 START = 17.67 / inside dome midheight
# HIERARCH ESO TEL ID = 'v 3.61  ' / TCS version number
# HIERARCH ESO TEL MOON DEC = 14.17744 / 14:10:38.7 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON DIST = 117.52867 / Moon distance to target
# HIERARCH ESO TEL MOON RA = 156.677335 / 10:26:42.5 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I,Condor' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 61.123 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = 58.389 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 3818.6 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG DELTA = -734850. / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000. / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Ju
# HIERARCH ESO TEL TARG EQUINOX = 2000. / Equinox
# HIERARCH ESO TEL TARG PMA = 0. / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0. / Proper motion Delta
# HIERARCH ESO TEL TRAK RATEA = 15. / Tracking rate in RA (arcsec/sec)
# HIERARCH ESO TEL TRAK RATED = 0. / Tracking rate in DEC (arcsec/sec)
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP1 END = 7.08 / air outside south of dome in shado
# HIERARCH ESO TEL TSS TEMP1 START = 7.1 / air outside south of dome
# HIERARCH ESO TEL TSS TEMP10 END = 2.95 / plate sensor looking into sky top
# HIERARCH ESO TEL TSS TEMP10 START = 3.58 / plate sensor looking into
# HIERARCH ESO TEL TSS TEMP11 END = 7.12 / air inside dome midheight
# HIERARCH ESO TEL TSS TEMP11 START = 7.41 / air inside dome midheight
# HIERARCH ESO TEL TSS TEMP12 END = 8.39 / air for instrument
# HIERARCH ESO TEL TSS TEMP12 START = 8.22 / air for instrument
# HIERARCH ESO TEL TSS TEMP13 END = 13.58 / surface delta hydrostatic pad
# HIERARCH ESO TEL TSS TEMP13 START = 13.73 / surface delta hydrostatic
# HIERARCH ESO TEL TSS TEMP14 END = 8.44 / air inside adapter
# HIERARCH ESO TEL TSS TEMP14 START = 8.24 / air inside adapter
# HIERARCH ESO TEL TSS TEMP2 END = 6.67 / air outside north of dome, road he
# HIERARCH ESO TEL TSS TEMP2 START = 7.04 / air outside north of dome,
# HIERARCH ESO TEL TSS TEMP3 END = 8.47 / air at low level in dome near floo
# HIERARCH ESO TEL TSS TEMP3 START = 8.5 / air at low level in dome n
# HIERARCH ESO TEL TSS TEMP4 END = 6.84 / surface of M1
# HIERARCH ESO TEL TSS TEMP4 START = 7.18 / surface of M1
# HIERARCH ESO TEL TSS TEMP5 END = 6.78 / air close to M1 surface
# HIERARCH ESO TEL TSS TEMP5 START = 6.73 / air close to M1 surface
# HIERARCH ESO TEL TSS TEMP6 END = 6.08 / surface midheight of lower Serruri
# HIERARCH ESO TEL TSS TEMP6 START = 6.25 / surface midheight of lower
# HIERARCH ESO TEL TSS TEMP7 END = 7.78 / surface midheight of upper Serruri
# HIERARCH ESO TEL TSS TEMP7 START = 7.97 / surface midheight of upper
# HIERARCH ESO TEL TSS TEMP8 END = 5.76 / surface on M2
# HIERARCH ESO TEL TSS TEMP8 START = 6.08 / surface on M2
# HIERARCH ESO TEL TSS TEMP9 END = 5.8 / air close to top ring
# HIERARCH ESO TEL TSS TEMP9 START = 6.04 / air close to top ring
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO = 1 / Exposure number within template
# HIERARCH ESO TPL ID = 'FEROS_ech_obs_objsky' / Template signature ID
# HIERARCH ESO TPL NAME = 'FEROS obs. object-sky' / Template name
# HIERARCH ESO TPL NEXP = 1 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'FEROS_ech_obs_objsky.seq' / Sequencer script
# HIERARCH ESO TPL START = '2005-09-30T08:02:33' / TPL start time
# HIERARCH ESO TPL VERSION = '1.0     ' / Version of the template
# HIERARCH ESO PRO CATG = 'RED_SCI_1'
# HIERARCH ESO PRO TYPE = 'REDUCED_SOS'
# HIERARCH ESO PRO REC1 DRS ID = 'ESO-MIDAS/15SEPpl1.0'
# HIERARCH ESO PRO REC1 PIPE ID = 'fern/1.0.0'
# HIERARCH ESO DRS BARYCORR = -11.2674
# HIERARCH ESO PRO REC1 FIBRE NO = 1
# HIERARCH ESO PRO REC1 FIBRE NAME = 'OBJECT  '
# HIERARCH ESO PRO REC1 LOC_CUTSTEP = 10
# HIERARCH ESO PRO REC1 LOC_WINDOW = 13
# HIERARCH ESO PRO REC1 FIT_DEG = 5
# HIERARCH ESO PRO REC1 LOC_THRES = 0.9
# HIERARCH ESO PRO REC1 LOC_MODE = 'G       '
# HIERARCH ESO PRO REC1 LOC_METHOD = 'R       '
# HIERARCH ESO PRO REC1 BG_MODE = 'B       '
# HIERARCH ESO PRO REC1 BG_STEPX = 26
# HIERARCH ESO PRO REC1 BG_STEPY = 26
# HIERARCH ESO PRO REC1 BG_WIDTHX = 11
# HIERARCH ESO PRO REC1 BG_WIDTHY = 23
# HIERARCH ESO PRO REC1 BG_MEDIANX = 2
# HIERARCH ESO PRO REC1 BG_MEDIANY = 6
# HIERARCH ESO PRO REC1 BG_DIST = 25
# HIERARCH ESO PRO REC1 PROFILE_W = 9
# HIERARCH ESO PRO REC1 FIBER_OFF1 = -4
# HIERARCH ESO PRO REC1 FIBER_OFF2 = 4
# HIERARCH ESO PRO REC1 FIBER_MODE = 2
# HIERARCH ESO PRO REC1 IMG_WRITE = 'N       '
# HIERARCH ESO PRO REC1 SPECTR_TYPE = 'G       '
# HIERARCH ESO PRO REC1 EXT_MODE = 'S       '
# HIERARCH ESO PRO REC1 PROFILE_GET = 'N       '
# HIERARCH ESO PRO REC1 EXT_ITER = 3
# HIERARCH ESO PRO REC1 CCD_RON = 1.688
# HIERARCH ESO PRO REC1 CCD_GAIN = 2.962
# HIERARCH ESO PRO REC1 CCD_THRES = 4.
# HIERARCH ESO PRO REC1 CCD_ROT = 2.4
# HIERARCH ESO PRO REC1 CCD_SHIFT = 0.
# HIERARCH ESO PRO REC1 INIT_WLC = 'C       '
# HIERARCH ESO PRO REC1 ORDER_FIRST = 25
# HIERARCH ESO PRO REC1 ORDER_LAST = 63
# HIERARCH ESO PRO REC1 LINE_W = 5
# HIERARCH ESO PRO REC1 LINE_THRES = 1000.
# HIERARCH ESO PRO REC1 ID_ALPHA = 0.2
# HIERARCH ESO PRO REC1 ID_TOL = 0.2
# HIERARCH ESO PRO REC1 ID_THRES = 0.
# HIERARCH ESO PRO REC1 SPECTR_G = 79.
# HIERARCH ESO PRO REC1 SPECTR_F = 410.
# HIERARCH ESO PRO REC1 SPECTR_THB = 63.4
# HIERARCH ESO PRO REC1 REBIN_SCL = 'I       '
# HIERARCH ESO PRO REC1 REBIN_STEP = 0.06
# HIERARCH ESO PRO REC1 REBIN_MTD = 'S       '
# HIERARCH ESO PRO REC1 MERGE_OPT = 'YES     '
# HIERARCH ESO PRO REC1 MERGE_MTD = 'SINC    '
# HIERARCH ESO PRO REC1 MERGE_DELTA = 1.
# HIERARCH ESO PRO REC1 FF NAME = 'FF2844  '
# HIERARCH ESO PRO REC1 FF PRO CATG = 'MASTER_FLAT'
# HIERARCH ESO PRO REC1 FF PRO TYPE = 'PREPROCESSED'
# HIERARCH ESO PRO REC1 FF OBS NAME = 'Calibration' / OB name
# HIERARCH ESO PRO REC1 FF OBS START = '2005-09-30T09:57:23' / OB start time
# HIERARCH ESO PRO REC1 FF TPL NAME = 'FEROS FlatField' / Template name
# HIERARCH ESO PRO REC1 FF TPL START = '2005-09-30T11:59:17' / TPL start time
# HIERARCH ESO PRO REC1 FF RAW1 NAME = 'FEROS.2005-09-30T12:05:47.160.fits'
# HIERARCH ESO PRO REC1 FF RAW1 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW1 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW1 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW2 NAME = 'FEROS.2005-09-30T12:06:14.360.fits'
# HIERARCH ESO PRO REC1 FF RAW2 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW2 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW2 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW3 NAME = 'FEROS.2005-09-30T12:06:41.650.fits'
# HIERARCH ESO PRO REC1 FF RAW3 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW3 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW3 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW4 NAME = 'FEROS.2005-09-30T12:07:09.190.fits'
# HIERARCH ESO PRO REC1 FF RAW4 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW4 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW4 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW5 NAME = 'FEROS.2005-09-30T12:07:35.600.fits'
# HIERARCH ESO PRO REC1 FF RAW5 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW5 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW5 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW6 NAME = 'FEROS.2005-09-30T12:08:02.950.fits'
# HIERARCH ESO PRO REC1 FF RAW6 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW6 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW6 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW7 NAME = 'FEROS.2005-09-30T12:08:30.570.fits'
# HIERARCH ESO PRO REC1 FF RAW7 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW7 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW7 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW8 NAME = 'FEROS.2005-09-30T12:08:59.630.fits'
# HIERARCH ESO PRO REC1 FF RAW8 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW8 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW8 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW9 NAME = 'FEROS.2005-09-30T12:09:27.310.fits'
# HIERARCH ESO PRO REC1 FF RAW9 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW9 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW9 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 FF RAW10 NAME = 'FEROS.2005-09-30T12:09:54.780.fits'
# HIERARCH ESO PRO REC1 FF RAW10 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 FF RAW10 TYPE = 'FLAT    ' / Observation type
# HIERARCH ESO PRO REC1 FF RAW10 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC NAME = 'ThArNe2887'
# HIERARCH ESO PRO REC1 WLC PRO CATG = 'MASTER_WAVE'
# HIERARCH ESO PRO REC1 WLC PRO TYPE = 'PREPROCESSED'
# HIERARCH ESO PRO REC1 WLC OBS NAME = 'Calibration' / OB name
# HIERARCH ESO PRO REC1 WLC OBS START = '2005-09-30T09:57:23' / OB start time
# HIERARCH ESO PRO REC1 WLC TPL NAME = 'FEROS wavelength calibration' / Templa
# HIERARCH ESO PRO REC1 WLC TPL START = '2005-09-30T13:17:01' / TPL start time
# HIERARCH ESO PRO REC1 WLC QC FIB1 NLINALL = 381
# HIERARCH ESO PRO REC1 WLC QC FIB1 NLINSEL = 381
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDMIN = -0.013531
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDMAX = 0.0236035
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDAVG = 1.13388E-13
# HIERARCH ESO PRO REC1 WLC QC FIB1 LINE RESIDRMS = 0.00346712
# HIERARCH ESO PRO REC1 WLC QC FIB2 NLINALL = 273
# HIERARCH ESO PRO REC1 WLC QC FIB2 NLINSEL = 273
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDMIN = -0.0170017
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDMAX = 0.0256638
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDAVG = 1.46585E-13
# HIERARCH ESO PRO REC1 WLC QC FIB2 LINE RESIDRMS = 0.00393849
# HIERARCH ESO PRO REC1 WLC RAW1 NAME = 'FEROS.2005-09-30T13:19:35.230.fits'
# HIERARCH ESO PRO REC1 WLC RAW1 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW1 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW1 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW2 NAME = 'FEROS.2005-09-30T13:20:28.441.fits'
# HIERARCH ESO PRO REC1 WLC RAW2 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW2 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW2 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW3 NAME = 'FEROS.2005-09-30T13:21:28.451.fits'
# HIERARCH ESO PRO REC1 WLC RAW3 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW3 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW3 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW4 NAME = 'FEROS.2005-09-30T13:22:25.090.fits'
# HIERARCH ESO PRO REC1 WLC RAW4 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW4 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW4 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW5 NAME = 'FEROS.2005-09-30T13:23:25.250.fits'
# HIERARCH ESO PRO REC1 WLC RAW5 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW5 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW5 TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO PRO REC1 WLC RAW6 NAME = 'FEROS.2005-09-30T13:24:20.650.fits'
# HIERARCH ESO PRO REC1 WLC RAW6 CATG = 'CALIB   ' / Observation category
# HIERARCH ESO PRO REC1 WLC RAW6 TYPE = 'WAVE    ' / Observation type
# HIERARCH ESO PRO REC1 WLC RAW6 TECH = 'ECHELLE ' / Observation technique
# M_EPOCH =                    F / True if resulting from multiple epochs
# SINGLEXP=                    T / True is resulting from single exposure
# NCOMBINE=                    1 / No of combined raw science files
# FLUXCAL = 'UNCALIBRATED'       / Type of flux calibration
# SPEC_RES=              48000.0 / Resolving power
# REFERENC= '        '           / Bibliographic reference
# PROCSOFT= 'FERN_DRS_1.0'       / Data reduction software
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# PRODLVL =                    2 / Phase 3 product level
# SPECSYS = 'BARYCENT'           / Reference frame
# EXT_OBJ =                    F / True if extended
# CONTNORM=                    F / True if normalised to continuum
# TOT_FLUX=                    F / True if photometric
# FLUXERR =                 -1.0 / Unknown flux scale uncertainty
# DISPELEM= 'FEROS ECHELLE'      / Dispersive element name
# OBSTECH = 'ECHELLE '           / Observation technique
# ASSOC1  = 'ANCILLARY.FEROSTAR' / Associated files 1 category
# TEXPTIME=             599.9999 / [s] Total integration time of all exposures
# PROG_ID = '074.D-0086(A)'      / ESO Programme ID
# OBID1   =               171381 / Obs block ID
# MJD-END =       53643.34301434 / [d] End of observation
# DATE-END= '2005-09-30T08:13:56.439' / End of observation
# WAVELMIN=       352.7399999966 / [nm] Min wavelength
# WAVELMAX=       921.6419872806 / [nm] Max wavelength
# SPEC_BIN=               0.0060 / [nm] Wavelength bin size
# SNR     =                  4.6 / Median signal to noise (DER_SNR method)
# PROV1   = 'FEROS.2005-09-30T08:03:56.440.fits' / Originating file name
# ASSON1  = 'FEROS.2005-09-30T08:03:56.440_DRS_FERN_1.0.tgz' / Associated file 1 n
# ASSOM1  = '865dd2e5f8a5a9f0d7b101520d444fca' / Associated file 1 md5sum
# DATE    = '2016-09-20T12:27:20.000' / Date this file was written
# ARCFILE = 'ADP.2016-09-21T09:18:32.929.fits' / Archive File Name
# ORIGFILE= 'FEROS.2005-09-30T08:03:56.440_DRS_FERN_1.0_ESOSDP.fits' / Original Fi
# P3ORIG  = 'IDP     '           / ESO internal data product
# HDRVER  = '2016-09-21T10:35:07.348' / ESO Archive header timetag
# COMMENT processed by hotfly version 2.1 on 2025-04-26T17:55:09.651 UT

# %%
fits.info(fname)
# Out:
# Filename: ../../Type4/OGLEJ003836.25-734813.4/ADP.2016-09-21T09:18:32.929.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     467   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [94818D, 94818E, 94818E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([3527.39999997, 3527.45999996, 3527.51999996, ..., 9216.29987281, 9216.35987281, 9216.41987281], [ 0.00000000e+00,  4.66033876e-01,  4.26336795e-01, ...,  5.53274620e-03,  0.00000000e+00,  0.00000000e+00], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (94818,)), ('FLUX', '>f4', (94818,)), ('ERR', '>f4', (94818,))]))

# %%
plt.figure(figsize=(15,5))
plt.plot(xd['WAVE'][0],xd['FLUX'][0])
#plt.ylim(-.1,1)
#plt.xlim(6525,6650)
plt.margins(x=0)
