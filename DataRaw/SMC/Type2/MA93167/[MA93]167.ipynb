# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../Type2/OGLEJ004319.46-731705.7/ADP.2014-09-26T16:52:09.357.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASUM = '0       '           / data unit checksum updated 2014-09-18T04:48:12
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2012-10-11T02:54:48.047' / UT date when this file was written
# INSTRUME= 'HARPS   '           / Instrument used.
# RA      =            10.784530 / 00:43:08.2 RA (J2000) pointing (deg)
# DEC     =            -73.32800 / -73:19:40.8 DEC (J2000) pointing (deg)
# EQUINOX =                2000. / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =            1378.0054 / Total integration time
# MJD-OBS =       56211.10540881 / MJD start (2012-10-11T02:31:47.321)
# DATE-OBS= '2012-10-11T02:31:47.321' / Date of observation
# UTC     =             9102.000 / 02:31:42.000 UTC at start (sec)
# LST     =            83348.031 / 23:09:08.031 LST at start (sec)
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# ORIGIN  = 'ESO     '           / European Southern Observatory
# TELESCOP= 'ESO-3.6 '           / ESO Telescope Name
# M_EPOCH =                    F / T if resulting from multiple epochs
# SINGLEXP=                    T / T if resulting from single exposure
# PRODLVL =                    2 / Product level: 1-raw 2-science grade 3-advanced
# DISPELEM= 'HARPS Echelle'      / Dispersive element name
# SPECSYS = 'BARYCENT'           / Reference frame
# OBJECT  = 'smc-cep-0518'       / Object
# TEXPTIME=            1378.0054 / [s] Total integration time of all exposures
# EXT_OBJ =                    F / T if extended
# MJD-END =       56211.12135795 / [d] End of observation
# PROG_ID = '190.D-0237(A)'      / ESO Programme ID
# OBID1   =            100315927 / Observation block ID
# PROCSOFT= 'EGGS_3.5'
# OBSTECH = 'ECHELLE '           / Observation technique
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# FLUXCAL = 'UNCALIBRATED'       / Type of flux calibration
# CONTNORM=                    F / T if normalised to the continuum
# WAVELMIN=              378.133 / [nm] Minimum wavelength
# WAVELMAX=              691.287 / [nm] Maximum wavelength
# SPEC_BIN=                0.001 / [nm] Wavelength bin size
# TOT_FLUX=                    F / T if photom. cond. and all src flux captured
# FLUXERR =                 -1.0 / Uncertainty in flux scale (%)
# NCOMBINE=                    1 / # of combined raw science data files
# REFERENC= '        '           / Bibliographic reference
# SNR     =                  4.9 / Median signal to noise
# SPEC_RES=              80000.0 / Reference spectral resolving power
# GAIN    =                 0.66 / Conversion from electrons to ADU
# DETRON  =                  3.3 / Readout noise per output (e-)
# ASSOC1  = 'ANCILLARY.HARPSTAR' / Associated file 1 category
# ASSON1  = 'HARPS.2012-10-11T02:31:47.321_DRS_EGGS_3.5.tar' / Associated file 1 n
# ASSOM1  = 'f7aa0d6e027d09288982b4d2f57f97d9' / Associated file 1 md5sum
# PROV1   = 'HARPS.2012-10-11T02:31:47.321.fits' / Originating file name
# HIERARCH ESO ADA ABSROT END = 90.04517 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 90.04517 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID DEC = -73.09486 / -73:05:41.4 Guide star DEC J2000
# HIERARCH ESO ADA GUID RA = 10.038430 / 00:40:09.2 Guide star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.00000 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIPS = 2 / # of chips in detector array
# HIERARCH ESO DET DATE = '2001-11-01' / Installation date
# HIERARCH ESO DET DEC = 0.00000000 / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 11951 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 87.249 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 87.235 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'harps - Harps' / Name of detector system
# HIERARCH ESO DET OUTPUTS = 2 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0.00000000 / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = '104kpx/rr' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = '104kHz,1,high' / Readout speed
# HIERARCH ESO DET SHUT ID = 'SESO    ' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.029 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.018 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'IRIS    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = 600.0 / Interval between two successive te
# HIERARCH ESO DET TELE NO = 3 / # of sources active
# HIERARCH ESO DET TLM1 END = 150.60 / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = 'CCD Sensor1' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = 'CCD T1  ' / Description of telemetry param.
# HIERARCH ESO DET TLM1 START = 150.60 / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = 283.60 / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = 'Box Temp' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = 'EBOX T  ' / Description of telemetry param.
# HIERARCH ESO DET TLM2 START = 283.60 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = 1.90 / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = 'CCD Vacuum' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = 'CCD Vacuum' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = 1.90 / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 1 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 1 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1378.005429 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1378.0728 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 4296 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1378.000000 / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Observation category
# HIERARCH ESO DPR TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO DPR TYPE = 'STAR,DARK,NONE' / Observation type
# HIERARCH ESO INS ADC1 DEC = -731938.910881 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC1 END = 122.0040 / Position angle at end [deg].
# HIERARCH ESO INS ADC1 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC1 RA = 4308.622718 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADC2 DEC = -731938.910881 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC2 END = 274.3510 / Position angle at end [deg].
# HIERARCH ESO INS ADC2 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC2 RA = 4308.622718 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADCS NAME = 'IN      ' / ADC slide position.
# HIERARCH ESO INS ADCS NO = 2 / ADC slide position.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DET1 CTMAX = 89. / Maximum count during exposure.
# HIERARCH ESO INS DET1 CTMEAN = 49.2 / Average counts during exposure.
# HIERARCH ESO INS DET1 CTMIN = 7. / Minimum count during exposure.
# HIERARCH ESO INS DET1 CTRMS = 13.46 / RMS of counts during exposure.
# HIERARCH ESO INS DET1 CTTOT = 67848. / Total counts during exposure.
# HIERARCH ESO INS DET1 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET1 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET1 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET1 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET1 TMMEAN = 0.53 / Normalised mean exposure time.
# HIERARCH ESO INS DET1 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DET2 CTMAX = 38. / Maximum count during exposure.
# HIERARCH ESO INS DET2 CTMEAN = 19.5 / Average counts during exposure.
# HIERARCH ESO INS DET2 CTMIN = 6. / Minimum count during exposure.
# HIERARCH ESO INS DET2 CTRMS = 4.91 / RMS of counts during exposure.
# HIERARCH ESO INS DET2 CTTOT = 26819. / Total counts during exposure.
# HIERARCH ESO INS DET2 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET2 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET2 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET2 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET2 TMMEAN = 0.50 / Normalised mean exposure time.
# HIERARCH ESO INS DET2 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.HARPS_ICS-195279' / Data dictionary
# HIERARCH ESO INS HEFS ST = T / High Eff. Fiber Shutter If T=EGGS
# HIERARCH ESO INS ID = 'HARPS/1.57' / Instrument ID.
# HIERARCH ESO INS LAMP3 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS LAMP5 ID = 'THAR2   ' / Lamp ID.
# HIERARCH ESO INS LAMP5 NAME = 'THAR2   ' / Lamp name.
# HIERARCH ESO INS LAMP5 ST = T / Lamp activated.
# HIERARCH ESO INS LAMP7 ST = F / Lamp activated.
# HIERARCH ESO INS MIRR1 ID = 'FIBB    ' / Mirror unique ID.
# HIERARCH ESO INS MIRR1 NAME = 'FIBB    ' / Mirror name.
# HIERARCH ESO INS MIRR1 NO = 4 / Mirror slide position.
# HIERARCH ESO INS MODE = 'EGGS    ' / Instrument mode used.
# HIERARCH ESO INS OPTI2 ID = 'CES     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI2 NAME = 'CES     ' / OPTIi name.
# HIERARCH ESO INS OPTI2 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI2 TYPE = 'FIBHEAD ' / OPTIi element.
# HIERARCH ESO INS OPTI3 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI3 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI3 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI3 TYPE = 'COVER   ' / OPTIi element.
# HIERARCH ESO INS OPTI4 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI4 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI4 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI4 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS OPTI4 TYPE = 'I2CELL  ' / OPTIi element.
# HIERARCH ESO INS OPTI5 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI5 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI5 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI5 TYPE = 'LAMPSELA' / OPTIi element.
# HIERARCH ESO INS OPTI6 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI6 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI6 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI6 TYPE = 'LAMPSELB' / OPTIi element.
# HIERARCH ESO INS OPTI7 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI7 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI7 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI7 TYPE = 'POLHEAD ' / OPTIi element.
# HIERARCH ESO INS PATH = 'DEFAULT ' / Optical path used.
# HIERARCH ESO INS ROT1 ENC = 6 / Absolute position [Enc].
# HIERARCH ESO INS ROT1 POS = 0.025 / Density [density].
# HIERARCH ESO INS SENS1 DETCOEF = 0.427180 / RMS of linear regression slope.
# HIERARCH ESO INS SENS1 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS1 ID = 'PRSS    ' / sensor ID.
# HIERARCH ESO INS SENS1 LRCONST = 0.003073 / Linear regression constant.
# HIERARCH ESO INS SENS1 LRRMS = 0.000014 / Linear regression RMS.
# HIERARCH ESO INS SENS1 MAX = 0.003155 / Maximum value.
# HIERARCH ESO INS SENS1 MEAN = 0.003095 / Average value.
# HIERARCH ESO INS SENS1 MIN = 0.003069 / Minimum value.
# HIERARCH ESO INS SENS1 NAME = 'Vacuum vessel pressure' / sensor common name.
# HIERARCH ESO INS SENS1 RMS = 0.000019 / RMS of samples over exposure.
# HIERARCH ESO INS SENS1 VAL = 0.003126 / Sensor numeric value.
# HIERARCH ESO INS SENS2 DETCOEF = 0.797142 / RMS of linear regression slope.
# HIERARCH ESO INS SENS2 GRAD = -0.000112 / Linear regression slope.
# HIERARCH ESO INS SENS2 ID = 'LNLV    ' / sensor ID.
# HIERARCH ESO INS SENS2 LRCONST = 40.643600 / Linear regression constant.
# HIERARCH ESO INS SENS2 LRRMS = 0.024401 / Linear regression RMS.
# HIERARCH ESO INS SENS2 MAX = 40.690000 / Maximum value.
# HIERARCH ESO INS SENS2 MEAN = 40.556400 / Average value.
# HIERARCH ESO INS SENS2 MIN = 40.460000 / Minimum value.
# HIERARCH ESO INS SENS2 NAME = 'LN2 level' / sensor common name.
# HIERARCH ESO INS SENS2 RMS = 0.054176 / RMS of samples over exposure.
# HIERARCH ESO INS SENS2 VAL = 40.460000 / Sensor numeric value.
# HIERARCH ESO INS SENS6 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS SENS6 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS6 ID = 'PRFP    ' / sensor ID.
# HIERARCH ESO INS SENS6 LRCONST = 0.000000 / Linear regression constant.
# HIERARCH ESO INS SENS6 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS SENS6 MAX = 0.000000 / Maximum value.
# HIERARCH ESO INS SENS6 MEAN = 0.000000 / Average value.
# HIERARCH ESO INS SENS6 MIN = 0.000000 / Minimum value.
# HIERARCH ESO INS SENS6 NAME = 'Fabry Perot P' / sensor common name.
# HIERARCH ESO INS SENS6 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS SENS6 VAL = 1.100000 / Sensor numeric value.
# HIERARCH ESO INS SENSOR2 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS SENSOR4 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR5 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR6 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR7 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR8 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR9 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SHUT1 ID = 'PMSH    ' / Shutter ID.
# HIERARCH ESO INS SHUT1 NAME = 'PM_Shutter' / Shutter name.
# HIERARCH ESO INS SHUT1 ST = T / Shutter open.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TEMP1 DETCOEF = 0.855396 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP1 GRAD = -0.000036 / Linear regression slope.
# HIERARCH ESO INS TEMP1 ID = 'CFAS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP1 LRCONST = 13.349900 / Linear regression constant.
# HIERARCH ESO INS TEMP1 LRRMS = 0.006363 / Linear regression RMS.
# HIERARCH ESO INS TEMP1 MAX = 13.350000 / Maximum value.
# HIERARCH ESO INS TEMP1 MEAN = 13.322000 / Average value.
# HIERARCH ESO INS TEMP1 MIN = 13.300000 / Minimum value.
# HIERARCH ESO INS TEMP1 NAME = 'HCFA air temperature' / Temperature sensor name.
# HIERARCH ESO INS TEMP1 RMS = 0.016733 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP1 VAL = 13.300 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP10 DETCOEF = 0.890909 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP10 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP10 ID = 'PA108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP10 LRCONST = 16.863000 / Linear regression constant.
# HIERARCH ESO INS TEMP10 LRRMS = 0.000274 / Linear regression RMS.
# HIERARCH ESO INS TEMP10 MAX = 16.862000 / Maximum value.
# HIERARCH ESO INS TEMP10 MEAN = 16.861250 / Average value.
# HIERARCH ESO INS TEMP10 MIN = 16.860000 / Minimum value.
# HIERARCH ESO INS TEMP10 NAME = 'CFC inside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP10 RMS = 0.000829 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP10 VAL = 16.860 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP11 DETCOEF = 0.066667 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP11 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP11 ID = 'PA209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP11 LRCONST = 17.008000 / Linear regression constant.
# HIERARCH ESO INS TEMP11 LRRMS = 0.000418 / Linear regression RMS.
# HIERARCH ESO INS TEMP11 MAX = 17.008000 / Maximum value.
# HIERARCH ESO INS TEMP11 MEAN = 17.007750 / Average value.
# HIERARCH ESO INS TEMP11 MIN = 17.007000 / Minimum value.
# HIERARCH ESO INS TEMP11 NAME = 'Opt. Bench top-Detector' / Temperature sensor na
# HIERARCH ESO INS TEMP11 RMS = 0.000433 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP11 VAL = 17.008 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP12 DETCOEF = 0.800000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP12 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP12 ID = 'PA210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP12 LRCONST = 17.015500 / Linear regression constant.
# HIERARCH ESO INS TEMP12 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP12 MAX = 17.017000 / Maximum value.
# HIERARCH ESO INS TEMP12 MEAN = 17.016500 / Average value.
# HIERARCH ESO INS TEMP12 MIN = 17.016000 / Minimum value.
# HIERARCH ESO INS TEMP12 NAME = 'Opt. Bench bottom-Detector' / Temperature sensor
# HIERARCH ESO INS TEMP12 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP12 VAL = 17.017 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP13 DETCOEF = 0.300000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP13 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP13 ID = 'PA211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP13 LRCONST = 17.068500 / Linear regression constant.
# HIERARCH ESO INS TEMP13 LRRMS = 0.001025 / Linear regression RMS.
# HIERARCH ESO INS TEMP13 MAX = 17.069000 / Maximum value.
# HIERARCH ESO INS TEMP13 MEAN = 17.067000 / Average value.
# HIERARCH ESO INS TEMP13 MIN = 17.066000 / Minimum value.
# HIERARCH ESO INS TEMP13 NAME = 'Opt. Bench top-left' / Temperature sensor name.
# HIERARCH ESO INS TEMP13 RMS = 0.001225 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP13 VAL = 17.067 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP14 DETCOEF = 0.800000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP14 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP14 ID = 'PA212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP14 LRCONST = 17.046500 / Linear regression constant.
# HIERARCH ESO INS TEMP14 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP14 MAX = 17.046000 / Maximum value.
# HIERARCH ESO INS TEMP14 MEAN = 17.045500 / Average value.
# HIERARCH ESO INS TEMP14 MIN = 17.045000 / Minimum value.
# HIERARCH ESO INS TEMP14 NAME = 'Opt. Bench bottom-Collimator' / Temperature sens
# HIERARCH ESO INS TEMP14 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP14 VAL = 17.045 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP15 DETCOEF = 0.800000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP15 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP15 ID = 'PA213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP15 LRCONST = 17.018500 / Linear regression constant.
# HIERARCH ESO INS TEMP15 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP15 MAX = 17.020000 / Maximum value.
# HIERARCH ESO INS TEMP15 MEAN = 17.019500 / Average value.
# HIERARCH ESO INS TEMP15 MIN = 17.019000 / Minimum value.
# HIERARCH ESO INS TEMP15 NAME = 'Opt. Bench top-right' / Temperature sensor name.
# HIERARCH ESO INS TEMP15 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP15 VAL = 17.020 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP16 DETCOEF = 0.599999 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP16 GRAD = -0.508525 / Linear regression slope.
# HIERARCH ESO INS TEMP16 ID = 'PA214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP16 LRCONST = 525.576000 / Linear regression constant.
# HIERARCH ESO INS TEMP16 LRRMS = 278.531161 / Linear regression RMS.
# HIERARCH ESO INS TEMP16 MAX = 17.052000 / Maximum value.
# HIERARCH ESO INS TEMP16 MEAN = -237.211750 / Average value.
# HIERARCH ESO INS TEMP16 MIN = -1000.000000 / Minimum value.
# HIERARCH ESO INS TEMP16 NAME = 'Opt. Bench bottom-right' / Temperature sensor na
# HIERARCH ESO INS TEMP16 RMS = 440.396001 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP16 VAL = -1000.000 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP17 DETCOEF = 0.200000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP17 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP17 ID = 'PA215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP17 LRCONST = 17.060000 / Linear regression constant.
# HIERARCH ESO INS TEMP17 LRRMS = 0.000447 / Linear regression RMS.
# HIERARCH ESO INS TEMP17 MAX = 17.060000 / Maximum value.
# HIERARCH ESO INS TEMP17 MEAN = 17.059500 / Average value.
# HIERARCH ESO INS TEMP17 MIN = 17.059000 / Minimum value.
# HIERARCH ESO INS TEMP17 NAME = 'Opt. Bench top-Collimator' / Temperature sensor
# HIERARCH ESO INS TEMP17 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP17 VAL = 17.059 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP18 DETCOEF = 0.160000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP18 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP18 ID = 'PA216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP18 LRCONST = 17.038500 / Linear regression constant.
# HIERARCH ESO INS TEMP18 LRRMS = 0.001025 / Linear regression RMS.
# HIERARCH ESO INS TEMP18 MAX = 17.039000 / Maximum value.
# HIERARCH ESO INS TEMP18 MEAN = 17.037500 / Average value.
# HIERARCH ESO INS TEMP18 MIN = 17.036000 / Minimum value.
# HIERARCH ESO INS TEMP18 NAME = 'Opt. Bench bottom-left' / Temperature sensor nam
# HIERARCH ESO INS TEMP18 RMS = 0.001118 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP18 VAL = 17.037 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP19 ID = 'PA2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP19 NAME = 'Opt. Bench Spare 1' / Temperature sensor name.
# HIERARCH ESO INS TEMP19 VAL = 17.057 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP2 ID = 'IODS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP2 NAME = 'Iodine cell temperature' / Temperature sensor na
# HIERARCH ESO INS TEMP2 VAL = 9999.000 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP20 ID = 'PA1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP20 NAME = 'VV inside Spare 1 - not conn.' / Temperature sen
# HIERARCH ESO INS TEMP20 VAL = 17.031 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP21 DETCOEF = 0.800000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP21 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP21 ID = 'PB101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP21 LRCONST = 17.002500 / Linear regression constant.
# HIERARCH ESO INS TEMP21 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP21 MAX = 17.002000 / Maximum value.
# HIERARCH ESO INS TEMP21 MEAN = 17.001500 / Average value.
# HIERARCH ESO INS TEMP21 MIN = 17.001000 / Minimum value.
# HIERARCH ESO INS TEMP21 NAME = 'Fiber Exit' / Temperature sensor name.
# HIERARCH ESO INS TEMP21 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP21 VAL = 17.001 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP22 DETCOEF = 0.600000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP22 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP22 ID = 'PB102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP22 LRCONST = 17.099000 / Linear regression constant.
# HIERARCH ESO INS TEMP22 LRRMS = 0.000274 / Linear regression RMS.
# HIERARCH ESO INS TEMP22 MAX = 17.100000 / Maximum value.
# HIERARCH ESO INS TEMP22 MEAN = 17.099750 / Average value.
# HIERARCH ESO INS TEMP22 MIN = 17.099000 / Minimum value.
# HIERARCH ESO INS TEMP22 NAME = 'Collimator' / Temperature sensor name.
# HIERARCH ESO INS TEMP22 RMS = 0.000433 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP22 VAL = 17.100 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP23 DETCOEF = 0.515789 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP23 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP23 ID = 'PB103   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP23 LRCONST = 17.042000 / Linear regression constant.
# HIERARCH ESO INS TEMP23 LRRMS = 0.000758 / Linear regression RMS.
# HIERARCH ESO INS TEMP23 MAX = 17.045000 / Maximum value.
# HIERARCH ESO INS TEMP23 MEAN = 17.043750 / Average value.
# HIERARCH ESO INS TEMP23 MIN = 17.042000 / Minimum value.
# HIERARCH ESO INS TEMP23 NAME = 'Echelle Grating' / Temperature sensor name.
# HIERARCH ESO INS TEMP23 RMS = 0.001090 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP23 VAL = 17.044 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP24 DETCOEF = 0.066667 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP24 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP24 ID = 'PB104   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP24 LRCONST = 17.012000 / Linear regression constant.
# HIERARCH ESO INS TEMP24 LRRMS = 0.000837 / Linear regression RMS.
# HIERARCH ESO INS TEMP24 MAX = 17.013000 / Maximum value.
# HIERARCH ESO INS TEMP24 MEAN = 17.012500 / Average value.
# HIERARCH ESO INS TEMP24 MIN = 17.011000 / Minimum value.
# HIERARCH ESO INS TEMP24 NAME = 'Grism   ' / Temperature sensor name.
# HIERARCH ESO INS TEMP24 RMS = 0.000866 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP24 VAL = 17.013 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP25 DETCOEF = 0.890909 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP25 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP25 ID = 'PB105   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP25 LRCONST = 16.943500 / Linear regression constant.
# HIERARCH ESO INS TEMP25 LRRMS = 0.000274 / Linear regression RMS.
# HIERARCH ESO INS TEMP25 MAX = 16.946000 / Maximum value.
# HIERARCH ESO INS TEMP25 MEAN = 16.945250 / Average value.
# HIERARCH ESO INS TEMP25 MIN = 16.944000 / Minimum value.
# HIERARCH ESO INS TEMP25 NAME = 'Camera Optics Detector side' / Temperature senso
# HIERARCH ESO INS TEMP25 RMS = 0.000829 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP25 VAL = 16.946 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP26 DETCOEF = 0.100000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP26 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP26 ID = 'PB106   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP26 LRCONST = 16.969500 / Linear regression constant.
# HIERARCH ESO INS TEMP26 LRRMS = 0.000671 / Linear regression RMS.
# HIERARCH ESO INS TEMP26 MAX = 16.971000 / Maximum value.
# HIERARCH ESO INS TEMP26 MEAN = 16.970000 / Average value.
# HIERARCH ESO INS TEMP26 MIN = 16.969000 / Minimum value.
# HIERARCH ESO INS TEMP26 NAME = 'Camera Optics Collimator side' / Temperature sen
# HIERARCH ESO INS TEMP26 RMS = 0.000707 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP26 VAL = 16.970 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP27 DETCOEF = 0.900000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP27 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP27 ID = 'PB107   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP27 LRCONST = 16.232500 / Linear regression constant.
# HIERARCH ESO INS TEMP27 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP27 MAX = 16.235000 / Maximum value.
# HIERARCH ESO INS TEMP27 MEAN = 16.234000 / Average value.
# HIERARCH ESO INS TEMP27 MIN = 16.233000 / Minimum value.
# HIERARCH ESO INS TEMP27 NAME = 'Detector-Head body back' / Temperature sensor na
# HIERARCH ESO INS TEMP27 RMS = 0.000707 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP27 VAL = 16.235 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP28 DETCOEF = 0.900000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP28 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP28 ID = 'PB108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP28 LRCONST = 16.796500 / Linear regression constant.
# HIERARCH ESO INS TEMP28 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP28 MAX = 16.799000 / Maximum value.
# HIERARCH ESO INS TEMP28 MEAN = 16.798000 / Average value.
# HIERARCH ESO INS TEMP28 MIN = 16.797000 / Minimum value.
# HIERARCH ESO INS TEMP28 NAME = 'Detector-Head holding ring' / Temperature sensor
# HIERARCH ESO INS TEMP28 RMS = 0.000707 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP28 VAL = 16.799 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP29 DETCOEF = 0.018182 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP29 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP29 ID = 'PB209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP29 LRCONST = 15.575000 / Linear regression constant.
# HIERARCH ESO INS TEMP29 LRRMS = 0.000822 / Linear regression RMS.
# HIERARCH ESO INS TEMP29 MAX = 15.576000 / Maximum value.
# HIERARCH ESO INS TEMP29 MEAN = 15.574750 / Average value.
# HIERARCH ESO INS TEMP29 MIN = 15.574000 / Minimum value.
# HIERARCH ESO INS TEMP29 NAME = 'VV outside Foot S2' / Temperature sensor name.
# HIERARCH ESO INS TEMP29 RMS = 0.000829 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP29 VAL = 15.574 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP3 DETCOEF = 0.600000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP3 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP3 ID = 'PA101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP3 LRCONST = 17.114000 / Linear regression constant.
# HIERARCH ESO INS TEMP3 LRRMS = 0.000274 / Linear regression RMS.
# HIERARCH ESO INS TEMP3 MAX = 17.115000 / Maximum value.
# HIERARCH ESO INS TEMP3 MEAN = 17.114750 / Average value.
# HIERARCH ESO INS TEMP3 MIN = 17.114000 / Minimum value.
# HIERARCH ESO INS TEMP3 NAME = 'VV inside top' / Temperature sensor name.
# HIERARCH ESO INS TEMP3 RMS = 0.000433 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP3 VAL = 17.115 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP30 DETCOEF = 0.429104 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP30 GRAD = -0.000027 / Linear regression slope.
# HIERARCH ESO INS TEMP30 ID = 'PB210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP30 LRCONST = 15.023500 / Linear regression constant.
# HIERARCH ESO INS TEMP30 LRRMS = 0.020891 / Linear regression RMS.
# HIERARCH ESO INS TEMP30 MAX = 15.030000 / Maximum value.
# HIERARCH ESO INS TEMP30 MEAN = 14.983000 / Average value.
# HIERARCH ESO INS TEMP30 MIN = 14.963000 / Minimum value.
# HIERARCH ESO INS TEMP30 NAME = 'Air-Coude room W' / Temperature sensor name.
# HIERARCH ESO INS TEMP30 RMS = 0.027650 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP30 VAL = 14.976 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP31 DETCOEF = 0.108587 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP31 GRAD = 0.000005 / Linear regression slope.
# HIERARCH ESO INS TEMP31 ID = 'PB211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP31 LRCONST = 15.321500 / Linear regression constant.
# HIERARCH ESO INS TEMP31 LRRMS = 0.008969 / Linear regression RMS.
# HIERARCH ESO INS TEMP31 MAX = 15.338000 / Maximum value.
# HIERARCH ESO INS TEMP31 MEAN = 15.328500 / Average value.
# HIERARCH ESO INS TEMP31 MIN = 15.313000 / Minimum value.
# HIERARCH ESO INS TEMP31 NAME = 'Air-HARPS Enclosure' / Temperature sensor name.
# HIERARCH ESO INS TEMP31 RMS = 0.009500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP31 VAL = 15.338 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP32 DETCOEF = 0.246914 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP32 GRAD = 0.000003 / Linear regression slope.
# HIERARCH ESO INS TEMP32 ID = 'PB212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP32 LRCONST = 17.045500 / Linear regression constant.
# HIERARCH ESO INS TEMP32 LRRMS = 0.003905 / Linear regression RMS.
# HIERARCH ESO INS TEMP32 MAX = 17.057000 / Maximum value.
# HIERARCH ESO INS TEMP32 MEAN = 17.050500 / Average value.
# HIERARCH ESO INS TEMP32 MIN = 17.045000 / Minimum value.
# HIERARCH ESO INS TEMP32 NAME = 'Air-HARPS Isolation Box' / Temperature sensor na
# HIERARCH ESO INS TEMP32 RMS = 0.004500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP32 VAL = 17.057 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP33 DETCOEF = 0.946039 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP33 GRAD = 0.000008 / Linear regression slope.
# HIERARCH ESO INS TEMP33 ID = 'PB213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP33 LRCONST = 17.372500 / Linear regression constant.
# HIERARCH ESO INS TEMP33 LRRMS = 0.001255 / Linear regression RMS.
# HIERARCH ESO INS TEMP33 MAX = 17.391000 / Maximum value.
# HIERARCH ESO INS TEMP33 MEAN = 17.384250 / Average value.
# HIERARCH ESO INS TEMP33 MIN = 17.378000 / Minimum value.
# HIERARCH ESO INS TEMP33 NAME = 'Air-through Fan 4 IB' / Temperature sensor name.
# HIERARCH ESO INS TEMP33 RMS = 0.005403 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP33 VAL = 17.391 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP34 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP34 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP34 ID = 'PB214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP34 LRCONST = 16.970000 / Linear regression constant.
# HIERARCH ESO INS TEMP34 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP34 MAX = 16.970000 / Maximum value.
# HIERARCH ESO INS TEMP34 MEAN = 16.970000 / Average value.
# HIERARCH ESO INS TEMP34 MIN = 16.970000 / Minimum value.
# HIERARCH ESO INS TEMP34 NAME = 'Image Scrambler outside VV' / Temperature sensor
# HIERARCH ESO INS TEMP34 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP34 VAL = 16.970 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP35 DETCOEF = 0.682581 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP35 GRAD = -0.000008 / Linear regression slope.
# HIERARCH ESO INS TEMP35 ID = 'PB215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP35 LRCONST = 16.545000 / Linear regression constant.
# HIERARCH ESO INS TEMP35 LRRMS = 0.003507 / Linear regression RMS.
# HIERARCH ESO INS TEMP35 MAX = 16.539000 / Maximum value.
# HIERARCH ESO INS TEMP35 MEAN = 16.533500 / Average value.
# HIERARCH ESO INS TEMP35 MIN = 16.523000 / Minimum value.
# HIERARCH ESO INS TEMP35 NAME = 'CFC outside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP35 RMS = 0.006225 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP35 VAL = 16.523 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP36 DETCOEF = 0.263158 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP36 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP36 ID = 'PB216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP36 LRCONST = 17.068000 / Linear regression constant.
# HIERARCH ESO INS TEMP36 LRRMS = 0.000935 / Linear regression RMS.
# HIERARCH ESO INS TEMP36 MAX = 17.068000 / Maximum value.
# HIERARCH ESO INS TEMP36 MEAN = 17.066750 / Average value.
# HIERARCH ESO INS TEMP36 MIN = 17.065000 / Minimum value.
# HIERARCH ESO INS TEMP36 NAME = 'VV outside Detector side' / Temperature sensor n
# HIERARCH ESO INS TEMP36 RMS = 0.001090 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP36 VAL = 17.067 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP37 DETCOEF = 0.800000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP37 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP37 ID = 'PB2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP37 LRCONST = 17.120500 / Linear regression constant.
# HIERARCH ESO INS TEMP37 LRRMS = 0.000224 / Linear regression RMS.
# HIERARCH ESO INS TEMP37 MAX = 17.120000 / Maximum value.
# HIERARCH ESO INS TEMP37 MEAN = 17.119500 / Average value.
# HIERARCH ESO INS TEMP37 MIN = 17.119000 / Minimum value.
# HIERARCH ESO INS TEMP37 NAME = 'VV outside Collimator side' / Temperature sensor
# HIERARCH ESO INS TEMP37 RMS = 0.000500 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP37 VAL = 17.119 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP38 ID = 'PB1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP38 NAME = 'Spectrograph Spare 2' / Temperature sensor name.
# HIERARCH ESO INS TEMP38 VAL = 17.066 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP4 DETCOEF = 0.084746 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP4 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP4 ID = 'PA102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP4 LRCONST = 16.987000 / Linear regression constant.
# HIERARCH ESO INS TEMP4 LRRMS = 0.001837 / Linear regression RMS.
# HIERARCH ESO INS TEMP4 MAX = 16.988000 / Maximum value.
# HIERARCH ESO INS TEMP4 MEAN = 16.985750 / Average value.
# HIERARCH ESO INS TEMP4 MIN = 16.983000 / Minimum value.
# HIERARCH ESO INS TEMP4 NAME = 'VV inside bottom' / Temperature sensor name.
# HIERARCH ESO INS TEMP4 RMS = 0.001920 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP4 VAL = 16.987 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP40 DETCOEF = 0.073401 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP40 GRAD = 0.000004 / Linear regression slope.
# HIERARCH ESO INS TEMP40 ID = 'CCD1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP40 LRCONST = 148.145794 / Linear regression constant.
# HIERARCH ESO INS TEMP40 LRRMS = 0.006563 / Linear regression RMS.
# HIERARCH ESO INS TEMP40 MAX = 148.170000 / Maximum value.
# HIERARCH ESO INS TEMP40 MEAN = 148.148996 / Average value.
# HIERARCH ESO INS TEMP40 MIN = 148.140000 / Minimum value.
# HIERARCH ESO INS TEMP40 NAME = 'CCD control reference' / Temperature sensor name
# HIERARCH ESO INS TEMP40 RMS = 0.006818 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP40 VAL = 148.140 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP41 DETCOEF = 0.067110 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP41 GRAD = 0.000005 / Linear regression slope.
# HIERARCH ESO INS TEMP41 ID = 'CCD2    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP41 LRCONST = 148.210177 / Linear regression constant.
# HIERARCH ESO INS TEMP41 LRRMS = 0.007588 / Linear regression RMS.
# HIERARCH ESO INS TEMP41 MAX = 148.230000 / Maximum value.
# HIERARCH ESO INS TEMP41 MEAN = 148.213704 / Average value.
# HIERARCH ESO INS TEMP41 MIN = 148.200000 / Minimum value.
# HIERARCH ESO INS TEMP41 NAME = 'CCD secondary' / Temperature sensor name.
# HIERARCH ESO INS TEMP41 RMS = 0.007856 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP41 VAL = 148.210 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP42 DETCOEF = 0.078137 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP42 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP42 ID = 'IBX1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP42 LRCONST = 17.002787 / Linear regression constant.
# HIERARCH ESO INS TEMP42 LRRMS = 0.002987 / Linear regression RMS.
# HIERARCH ESO INS TEMP42 MAX = 17.014000 / Maximum value.
# HIERARCH ESO INS TEMP42 MEAN = 17.004294 / Average value.
# HIERARCH ESO INS TEMP42 MIN = 16.998000 / Minimum value.
# HIERARCH ESO INS TEMP42 NAME = 'Isolation box control reference' / Temperature s
# ...
# HIERARCH ESO DRS CAL TH COEFF LL144 = -4.89219211872777E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG LL = 4 / degre polyn fit ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL339 = -1.96796681431292E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL96 = 0.0136947548591412 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL97 = -4.71686125676526E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL94 = -1.92931099579031E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL95 = 4285.31793744421 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL92 = -4.71475456922712E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL93 = 1.2417408320801E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL90 = 4255.35905554536 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL91 = 0.0136002275781055 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL98 = 5.41126818724673E-14 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL99 = -5.6987997148075E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X243 = -0.137170023812522 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X242 = 1116.36527791579 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X241 = -4038411.24628965 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X240 = 5478726598.96579 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X247 = 1090.5841750064 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X246 = -3980667.40732204 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X245 = 5449011751.18538 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X244 = 6.32104681381014E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X320 = 5525816552.83528 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X321 = -3491068.97687515 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X249 = 6.06537844171767E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X248 = -0.132806681183056 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X324 = 3.44056519181787E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X325 = 5418475451.06222 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X326 = -3388180.45496094 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X277 = 1015.44933871003 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X322 = 827.151851080666 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL310 = 6208.5592175972 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X323 = -0.087110221801753 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL219 = 1.92746621197525E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL218 = -2.44493621132655E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL217 = -5.60344719858959E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL216 = 0.0164974340275524 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL215 = 5156.64463737111 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL188 = 2.84546952649839E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL213 = -2.50155086346694E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL212 = -5.56228519089431E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL211 = 0.0163595251448049 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL210 = 5113.32309081527 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X48 = -0.344660202872213 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X49 = 2.15540756538413E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X40 = 5342417520.57978 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X41 = -5380117.1889772 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X42 = 2031.94137152142 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X43 = -0.341105356807122 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X44 = 2.14755235940068E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X45 = 5507893091.67861 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X46 = -5509664.90027341 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X47 = 2066.9484911119 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X188 = -0.204842752376019 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X189 = 1.04443286929681E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X184 = 9.04418133823661E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X185 = 6039993273.10133 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X186 = -4926109.85104328 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X187 = 1506.72810795367 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X180 = 5041973765.5467 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X181 = -4149955.865647 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X182 = 1281.01090143267 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL182 = -5.28992224129954E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL356 = 0.0219030538123176 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL357 = -7.48373478406819E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL354 = 1.83996529524369E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL355 = 6836.13155461449 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL352 = -7.40618052457227E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL181 = 0.015568132984546 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL350 = 6760.20255255794 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL351 = 0.0216630675299844 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL358 = -1.51125899445879E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL359 = 1.2041891452431E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL323 = -3.79428943804599E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL322 = -6.87764585874433E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL321 = 0.0203013447713614 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL320 = 6337.85399182186 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL327 = -6.96813070941366E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL326 = 0.0205177735754286 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL325 = 6404.54025031261 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL324 = 3.73200555793941E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL329 = 2.65634702764014E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL328 = -3.07968692325555E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X287 = 972.918489743556 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X286 = -3828000.08270379 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X119 = 1.37031970979332E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X118 = -0.241233713437821 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X113 = -0.252684710328857 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X112 = 1656.70202652919 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X111 = -4828008.76877452 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X110 = 5276639666.42996 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X117 = 1592.69467157136 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X116 = -4673963.97734314 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X115 = 5144034823.1752 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X114 = 1.4454122127425E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH LITTROW ONE MEAN = -0.498820901882911 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH LITTROW THREE MAXDEV = 54.7565544754996 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF LL168 = -3.8931259317024E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL107 = -4.71621561784593E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL106 = 0.01388373069564 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL105 = 4346.52376628496 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL104 = 1.6974919701917E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL103 = -2.02992423526543E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL102 = -4.68507781488358E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL101 = 0.0137844340761462 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL100 = 4315.70565295689 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH ORDER NRED = 26 / nb red orders
# HIERARCH ESO DRS CAL TH COEFF LL109 = 2.07708322446234E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL108 = -2.226511001428E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL166 = 0.0151962460540156 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X280 = 5173315970.57998 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL198 = -2.21472047512796E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL199 = 1.96538725138932E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL194 = 2.36976137766863E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL195 = 4987.62167433 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL196 = 0.0159548038664225 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG X = 4 / degre polyn fit x(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL190 = 4947.08393633662 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL191 = 0.015821913258217 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL192 = -5.37001571498656E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL193 = -2.68129391402795E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X209 = 8.56057988982092E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X208 = -0.173426483232285 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X207 = 1317.66226682526 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X206 = -4449893.49368752 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X205 = 5635855254.40923 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X204 = 8.7281288213125E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X203 = -0.175332373394308 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X202 = 1320.9292722499 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X201 = -4423375.35589532 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X200 = 5555109461.0436 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X99 = 1.75499736465702E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X98 = -0.30054012508953 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X93 = -0.335422082721551 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X92 = 2140.45175283535 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X91 = -6071180.80187502 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X90 = 6458079374.61261 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X97 = 1930.20561445525 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X96 = -5510111.4555403 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X95 = 5899035542.69607 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X94 = 1.9712912417742E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X281 = -3542093.30061935 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH FILE LINES = 'TH_sel_R100000_A0.5-0.25-0.1.dat' / file n
# HIERARCH ESO DRS CAL TH COEFF LL74 = 1.48215235537791E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL75 = 4167.94707660233 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL76 = 0.0133092575559721 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL77 = -4.54924211214637E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL70 = 4139.60218747361 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL71 = 0.0132147252623319 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL72 = -4.49415160016939E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL73 = -1.76026382030527E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL78 = -1.04875266818261E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL79 = 7.72295213261954E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X278 = -0.11694021165418 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X279 = 5.0506322953006E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X272 = 1048.1016461445 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X273 = -0.121851156301293 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X270 = 5745480585.84616 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X271 = -4007125.75684661 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X276 = -3919307.12767633 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X19 = 2.72709130969944E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X274 = 5.31289541413626E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X275 = 5673158428.14696 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL240 = 5432.76608491195 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL241 = 0.0173938785506963 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL242 = -5.94383900694E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL243 = -1.29218685883972E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL244 = 6.46036615823522E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL245 = 5481.69253579326 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL246 = 0.0175468672719893 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL247 = -5.94451231489326E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL248 = -3.50275222870067E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL249 = 3.5582157526601E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH LITTROW THREE RMS = 23.6877005306437 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF X71 = -5569755.63292467 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X70 = 5759403675.58363 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X73 = -0.32564055421055 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X72 = 2020.03609074224 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X75 = 5617078837.83369 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X74 = 1.96876442676524E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X77 = 1944.1500124535 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X76 = -5396197.80619639 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X79 = 1.86983534781741E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X78 = -0.311335314687522 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X157 = 1640.20701287166 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X156 = -5114947.8066943 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X155 = 5982013155.61748 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X154 = 1.15415924006857E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X153 = -0.214095906097137 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X152 = 1489.45898711645 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X151 = -4605813.78837838 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X150 = 5341330475.27345 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X159 = 1.24968107713836E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X158 = -0.233782254797734 / coeff x=(ll,order)
# ARCFILE = 'ADP.2014-09-26T16:52:09.357.fits' / Archive File Name
# P3ORIG  = 'IDP     '           / ESO internal data product
# HDRVER  = '2014-09-26T22:16:50.006' / ESO Archive header timetag
# COMMENT processed by hotfly version 2.0 on 2025-04-26T16:58:07.731 UT

# %%
fits.info(fname)
# Out:
# Filename: ../../Type2/OGLEJ004319.46-731705.7/ADP.2014-09-26T16:52:09.357.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    3360   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [313155D, 313155E, 313155E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([3781.33, 3781.34, 3781.35, ..., 6912.85, 6912.86, 6912.87], [-4.32542648e+01, -2.14104633e+01, -2.81518154e+01, ...,  1.15610027e+01,  1.74185829e+01,  3.86470747e+00], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (313155,)), ('FLUX', '>f4', (313155,)), ('ERR', '>f4', (313155,))]))

# %%
plt.figure(figsize=(15,3))
plt.plot(xd['WAVE'][0],xd['FLUX'][0],'.-')
plt.ylim(0,500)
plt.xlim(6525,6600)
plt.margins(x=0)
