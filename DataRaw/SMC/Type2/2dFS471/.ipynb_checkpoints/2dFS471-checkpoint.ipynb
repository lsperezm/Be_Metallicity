# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.modeling import models, fitting
fitter = fitting.LinearLSQFitter()
from scipy.ndimage import median_filter

# %%
fname='../../Type2/2dFS471/ADP.2014-10-07T13:37:18.583.fits'

# %%
fits.getheader(fname)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                    8 / number of bits per data pixel
# NAXIS   =                    0 / number of data axes
# EXTEND  =                    T / FITS dataset may contain extensions
# DATASUM = '0       '           / data unit checksum updated 2014-10-06T14:40:38
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2014-09-09T05:10:10.509' / UT date when this file was written
# INSTRUME= 'HARPS   '           / Instrument used.
# RA      =            10.788130 / 00:43:09.1 RA (J2000) pointing (deg)
# DEC     =            -73.32759 / -73:19:39.3 DEC (J2000) pointing (deg)
# EQUINOX =                2000. / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =            1300.0000 / Total integration time
# MJD-OBS =       56909.20032487 / MJD start (2014-09-09T04:48:28.069)
# DATE-OBS= '2014-09-09T04:48:28.069' / Date of observation
# UTC     =            17303.000 / 04:48:23.000 UTC at start (sec)
# LST     =            83885.997 / 23:18:05.997 LST at start (sec)
# PI-COI  = 'UNKNOWN '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# ORIGIN  = 'ESO     '           / European Southern Observatory
# TELESCOP= 'ESO-3.6 '           / ESO Telescope Name
# M_EPOCH =                    F / T if resulting from multiple epochs
# SINGLEXP=                    T / T if resulting from single exposure
# PRODLVL =                    2 / Product level: 1-raw 2-science grade 3-advanced
# DISPELEM= 'HARPS Echelle'      / Dispersive element name
# SPECSYS = 'BARYCENT'           / Reference frame
# OBJECT  = 'smc-cep-0518'       / Object
# TEXPTIME=               1300.0 / [s] Total integration time of all exposures
# EXT_OBJ =                    F / T if extended
# MJD-END =       56909.21537117 / [d] End of observation
# PROG_ID = '190.D-0237(F)'      / ESO Programme ID
# OBID1   =            100361481 / Observation block ID
# PROCSOFT= 'EGGS_3.5'
# OBSTECH = 'ECHELLE '           / Observation technique
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# FLUXCAL = 'UNCALIBRATED'       / Type of flux calibration
# CONTNORM=                    F / T if normalised to the continuum
# WAVELMIN=              378.145 / [nm] Minimum wavelength
# WAVELMAX=              691.299 / [nm] Maximum wavelength
# SPEC_BIN=                0.001 / [nm] Wavelength bin size
# TOT_FLUX=                    F / T if photom. cond. and all src flux captured
# FLUXERR =                 -1.0 / Uncertainty in flux scale (%)
# NCOMBINE=                    1 / # of combined raw science data files
# REFERENC= '        '           / Bibliographic reference
# SNR     =                  5.4 / Median signal to noise
# SPEC_RES=              80000.0 / Reference spectral resolving power
# GAIN    =                 0.66 / Conversion from electrons to ADU
# DETRON  =                  3.3 / Readout noise per output (e-)
# ASSOC1  = 'ANCILLARY.HARPSTAR' / Associated file 1 category
# ASSON1  = 'HARPS.2014-09-09T04:48:28.069_DRS_EGGS_3.5.tar' / Associated file 1 n
# ASSOM1  = '7a71a922e532a449670cf8f5c9a02693' / Associated file 1 md5sum
# PROV1   = 'HARPS.2014-09-09T04:48:28.069.fits' / Originating file name
# HIERARCH ESO ADA ABSROT END = 89.96976 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 89.96976 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID DEC = 0.00000 / 00:00:00.0 Guide star DEC J2000
# HIERARCH ESO ADA GUID RA = 0.000000 / 00:00:00.0 Guide star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.00000 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIPS = 2 / # of chips in detector array
# HIERARCH ESO DET DATE = '2001-11-01' / Installation date
# HIERARCH ESO DET DEC = 0.00000000 / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 12351 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 87.259 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 87.198 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'harps - Harps' / Name of detector system
# HIERARCH ESO DET OUTPUTS = 2 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0.00000000 / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = '104kpx/rr' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = '104kHz,1,high' / Readout speed
# HIERARCH ESO DET SHUT ID = 'SESO    ' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.017 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.017 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'IRIS    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = 900.0 / Interval between two successive te
# HIERARCH ESO DET TELE NO = 3 / # of sources active
# HIERARCH ESO DET TLM1 END = 150.60 / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = 'CCD Sensor1' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = 'CCD T1  ' / Description of telemetry param.
# HIERARCH ESO DET TLM1 START = 150.60 / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = 283.80 / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = 'Box Temp' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = 'EBOX T  ' / Description of telemetry param.
# HIERARCH ESO DET TLM2 START = 283.80 / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = 2.20 / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = 'CCD Vacuum' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = 'CCD Vacuum' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = 2.20 / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 1 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 1 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1299.999968 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1300.0904 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 4296 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 4096 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1300.000000 / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Observation category
# HIERARCH ESO DPR TECH = 'ECHELLE ' / Observation technique
# HIERARCH ESO DPR TYPE = 'STAR,DARK,NONE' / Observation type
# HIERARCH ESO INS ADC1 DEC = -731937.237432 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC1 END = 119.7540 / Position angle at end [deg].
# HIERARCH ESO INS ADC1 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC1 RA = 4309.393765 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADC2 DEC = -731937.237432 / -~~:~~:~~.~ DEC (J2000) pointing
# HIERARCH ESO INS ADC2 END = 271.7400 / Position angle at end [deg].
# HIERARCH ESO INS ADC2 MODE = 'AUTO    ' / ADC mode.
# HIERARCH ESO INS ADC2 RA = 4309.396818 / ~~:~~:~~.~ RA (J2000) pointing [de
# HIERARCH ESO INS ADCS NAME = 'IN      ' / ADC slide position.
# HIERARCH ESO INS ADCS NO = 2 / ADC slide position.
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DET1 CTMAX = 102. / Maximum count during exposure.
# HIERARCH ESO INS DET1 CTMEAN = 56.7 / Average counts during exposure.
# HIERARCH ESO INS DET1 CTMIN = 11. / Minimum count during exposure.
# HIERARCH ESO INS DET1 CTRMS = 11.59 / RMS of counts during exposure.
# HIERARCH ESO INS DET1 CTTOT = 73711. / Total counts during exposure.
# HIERARCH ESO INS DET1 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET1 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET1 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET1 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET1 TMMEAN = 0.50 / Normalised mean exposure time.
# HIERARCH ESO INS DET1 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DET2 CTMAX = 45. / Maximum count during exposure.
# HIERARCH ESO INS DET2 CTMEAN = 20.0 / Average counts during exposure.
# HIERARCH ESO INS DET2 CTMIN = 6. / Minimum count during exposure.
# HIERARCH ESO INS DET2 CTRMS = 4.99 / RMS of counts during exposure.
# HIERARCH ESO INS DET2 CTTOT = 26032. / Total counts during exposure.
# HIERARCH ESO INS DET2 ID = 'EXPM    ' / Exposure meter identifier.
# HIERARCH ESO INS DET2 NAME = 'ExpMeter' / Detector name.
# HIERARCH ESO INS DET2 OFFDRK = 0. / Average dark background counts.
# HIERARCH ESO INS DET2 OFFSKY = 1. / Average sky background counts.
# HIERARCH ESO INS DET2 TMMEAN = 0.50 / Normalised mean exposure time.
# HIERARCH ESO INS DET2 UIT = 1.000 / User defined Integration time [sec
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.HARPS_ICS-195279' / Data dictionary
# HIERARCH ESO INS HEFS ST = T / High Eff. Fiber Shutter If T=EGGS
# HIERARCH ESO INS ID = 'HARPS/1.57' / Instrument ID.
# HIERARCH ESO INS LAMP3 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS LAMP7 ST = F / Lamp activated.
# HIERARCH ESO INS MIRR1 ID = 'FIBB    ' / Mirror unique ID.
# HIERARCH ESO INS MIRR1 NAME = 'FIBB    ' / Mirror name.
# HIERARCH ESO INS MIRR1 NO = 4 / Mirror slide position.
# HIERARCH ESO INS MODE = 'EGGS    ' / Instrument mode used.
# HIERARCH ESO INS OPTI2 ID = 'CES     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI2 NAME = 'CES     ' / OPTIi name.
# HIERARCH ESO INS OPTI2 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI2 TYPE = 'FIBHEAD ' / OPTIi element.
# HIERARCH ESO INS OPTI3 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI3 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI3 NO = 2 / OPTIi slot number.
# HIERARCH ESO INS OPTI3 TYPE = 'COVER   ' / OPTIi element.
# HIERARCH ESO INS OPTI4 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI4 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI4 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI4 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS OPTI4 TYPE = 'I2CELL  ' / OPTIi element.
# HIERARCH ESO INS OPTI5 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI5 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI5 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI5 TYPE = 'LAMPSELA' / OPTIi element.
# HIERARCH ESO INS OPTI6 ID = 'NONE    ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI6 NAME = 'NONE    ' / OPTIi name.
# HIERARCH ESO INS OPTI6 NO = 4 / OPTIi slot number.
# HIERARCH ESO INS OPTI6 TYPE = 'LAMPSELB' / OPTIi element.
# HIERARCH ESO INS OPTI7 ID = 'OUT     ' / OPTIi unique ID.
# HIERARCH ESO INS OPTI7 NAME = 'OUT     ' / OPTIi name.
# HIERARCH ESO INS OPTI7 NO = 1 / OPTIi slot number.
# HIERARCH ESO INS OPTI7 TYPE = 'POLHEAD ' / OPTIi element.
# HIERARCH ESO INS PATH = 'DEFAULT ' / Optical path used.
# HIERARCH ESO INS ROT1 ENC = 6 / Absolute position [Enc].
# HIERARCH ESO INS ROT1 POS = 0.025 / Density [density].
# HIERARCH ESO INS SENS1 DETCOEF = 0.656387 / RMS of linear regression slope.
# HIERARCH ESO INS SENS1 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS1 ID = 'PRSS    ' / sensor ID.
# HIERARCH ESO INS SENS1 LRCONST = 0.006439 / Linear regression constant.
# HIERARCH ESO INS SENS1 LRRMS = 0.000011 / Linear regression RMS.
# HIERARCH ESO INS SENS1 MAX = 0.006486 / Maximum value.
# HIERARCH ESO INS SENS1 MEAN = 0.006466 / Average value.
# HIERARCH ESO INS SENS1 MIN = 0.006427 / Minimum value.
# HIERARCH ESO INS SENS1 NAME = 'Vacuum vessel pressure' / sensor common name.
# HIERARCH ESO INS SENS1 RMS = 0.000019 / RMS of samples over exposure.
# HIERARCH ESO INS SENS1 VAL = 0.006486 / Sensor numeric value.
# HIERARCH ESO INS SENS2 DETCOEF = 0.924030 / RMS of linear regression slope.
# HIERARCH ESO INS SENS2 GRAD = -0.000142 / Linear regression slope.
# HIERARCH ESO INS SENS2 ID = 'LNLV    ' / sensor ID.
# HIERARCH ESO INS SENS2 LRCONST = 91.398514 / Linear regression constant.
# HIERARCH ESO INS SENS2 LRRMS = 0.016966 / Linear regression RMS.
# HIERARCH ESO INS SENS2 MAX = 91.390000 / Maximum value.
# HIERARCH ESO INS SENS2 MEAN = 91.291667 / Average value.
# HIERARCH ESO INS SENS2 MIN = 91.200000 / Minimum value.
# HIERARCH ESO INS SENS2 NAME = 'LN2 level' / sensor common name.
# HIERARCH ESO INS SENS2 RMS = 0.061554 / RMS of samples over exposure.
# HIERARCH ESO INS SENS2 VAL = 91.210000 / Sensor numeric value.
# HIERARCH ESO INS SENS6 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS SENS6 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS SENS6 ID = 'PRFP    ' / sensor ID.
# HIERARCH ESO INS SENS6 LRCONST = 0.000000 / Linear regression constant.
# HIERARCH ESO INS SENS6 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS SENS6 MAX = 0.000000 / Maximum value.
# HIERARCH ESO INS SENS6 MEAN = 0.000000 / Average value.
# HIERARCH ESO INS SENS6 MIN = 0.000000 / Minimum value.
# HIERARCH ESO INS SENS6 NAME = 'Fabry Perot P' / sensor common name.
# HIERARCH ESO INS SENS6 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS SENS6 VAL = 2.900000 / Sensor numeric value.
# HIERARCH ESO INS SENSOR2 SWSIM = T / If T, function is software simulat
# HIERARCH ESO INS SENSOR4 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR5 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR6 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR7 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR8 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SENSOR9 SWSIM = F / If T, function is software simulat
# HIERARCH ESO INS SHUT1 ID = 'PMSH    ' / Shutter ID.
# HIERARCH ESO INS SHUT1 NAME = 'PM_Shutter' / Shutter name.
# HIERARCH ESO INS SHUT1 ST = T / Shutter open.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS TEMP1 DETCOEF = 0.955848 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP1 GRAD = -0.000081 / Linear regression slope.
# HIERARCH ESO INS TEMP1 ID = 'CFAS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP1 LRCONST = 13.722754 / Linear regression constant.
# HIERARCH ESO INS TEMP1 LRRMS = 0.007270 / Linear regression RMS.
# HIERARCH ESO INS TEMP1 MAX = 13.720000 / Maximum value.
# HIERARCH ESO INS TEMP1 MEAN = 13.661667 / Average value.
# HIERARCH ESO INS TEMP1 MIN = 13.610000 / Minimum value.
# HIERARCH ESO INS TEMP1 NAME = 'HCFA air temperature' / Temperature sensor name.
# HIERARCH ESO INS TEMP1 RMS = 0.034601 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP1 VAL = 13.610 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP10 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP10 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP10 ID = 'PA108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP10 LRCONST = 16.824333 / Linear regression constant.
# HIERARCH ESO INS TEMP10 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP10 MAX = 16.826000 / Maximum value.
# HIERARCH ESO INS TEMP10 MEAN = 16.825333 / Average value.
# HIERARCH ESO INS TEMP10 MIN = 16.825000 / Minimum value.
# HIERARCH ESO INS TEMP10 NAME = 'CFC inside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP10 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP10 VAL = 16.826 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP11 DETCOEF = 1.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP11 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP11 ID = 'PA209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP11 LRCONST = 16.979000 / Linear regression constant.
# HIERARCH ESO INS TEMP11 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP11 MAX = 16.982000 / Maximum value.
# HIERARCH ESO INS TEMP11 MEAN = 16.981000 / Average value.
# HIERARCH ESO INS TEMP11 MIN = 16.980000 / Minimum value.
# HIERARCH ESO INS TEMP11 NAME = 'Opt. Bench top-Detector' / Temperature sensor na
# HIERARCH ESO INS TEMP11 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP11 VAL = 16.982 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP12 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP12 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP12 ID = 'PA210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP12 LRCONST = 16.989667 / Linear regression constant.
# HIERARCH ESO INS TEMP12 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP12 MAX = 16.991000 / Maximum value.
# HIERARCH ESO INS TEMP12 MEAN = 16.990667 / Average value.
# HIERARCH ESO INS TEMP12 MIN = 16.990000 / Minimum value.
# HIERARCH ESO INS TEMP12 NAME = 'Opt. Bench bottom-Detector' / Temperature sensor
# HIERARCH ESO INS TEMP12 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP12 VAL = 16.991 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP13 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP13 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP13 ID = 'PA211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP13 LRCONST = 17.044667 / Linear regression constant.
# HIERARCH ESO INS TEMP13 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP13 MAX = 17.048000 / Maximum value.
# HIERARCH ESO INS TEMP13 MEAN = 17.046667 / Average value.
# HIERARCH ESO INS TEMP13 MIN = 17.046000 / Minimum value.
# HIERARCH ESO INS TEMP13 NAME = 'Opt. Bench top-left' / Temperature sensor name.
# HIERARCH ESO INS TEMP13 RMS = 0.000943 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP13 VAL = 17.048 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP14 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP14 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP14 ID = 'PA212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP14 LRCONST = 17.027333 / Linear regression constant.
# HIERARCH ESO INS TEMP14 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP14 MAX = 17.029000 / Maximum value.
# HIERARCH ESO INS TEMP14 MEAN = 17.028333 / Average value.
# HIERARCH ESO INS TEMP14 MIN = 17.028000 / Minimum value.
# HIERARCH ESO INS TEMP14 NAME = 'Opt. Bench bottom-Collimator' / Temperature sens
# HIERARCH ESO INS TEMP14 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP14 VAL = 17.029 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP15 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP15 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP15 ID = 'PA213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP15 LRCONST = 17.000000 / Linear regression constant.
# HIERARCH ESO INS TEMP15 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP15 MAX = 17.000000 / Maximum value.
# HIERARCH ESO INS TEMP15 MEAN = 17.000000 / Average value.
# HIERARCH ESO INS TEMP15 MIN = 17.000000 / Minimum value.
# HIERARCH ESO INS TEMP15 NAME = 'Opt. Bench top-right' / Temperature sensor name.
# HIERARCH ESO INS TEMP15 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP15 VAL = 17.000 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP16 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP16 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP16 ID = 'PA214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP16 LRCONST = 17.032667 / Linear regression constant.
# HIERARCH ESO INS TEMP16 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP16 MAX = 17.033000 / Maximum value.
# HIERARCH ESO INS TEMP16 MEAN = 17.032667 / Average value.
# HIERARCH ESO INS TEMP16 MIN = 17.032000 / Minimum value.
# HIERARCH ESO INS TEMP16 NAME = 'Opt. Bench bottom-right' / Temperature sensor na
# HIERARCH ESO INS TEMP16 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP16 VAL = 17.033 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP17 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP17 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP17 ID = 'PA215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP17 LRCONST = 17.045667 / Linear regression constant.
# HIERARCH ESO INS TEMP17 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP17 MAX = 17.045000 / Maximum value.
# HIERARCH ESO INS TEMP17 MEAN = 17.044667 / Average value.
# HIERARCH ESO INS TEMP17 MIN = 17.044000 / Minimum value.
# HIERARCH ESO INS TEMP17 NAME = 'Opt. Bench top-Collimator' / Temperature sensor
# HIERARCH ESO INS TEMP17 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP17 VAL = 17.044 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP18 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP18 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP18 ID = 'PA216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP18 LRCONST = 17.016333 / Linear regression constant.
# HIERARCH ESO INS TEMP18 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP18 MAX = 17.017000 / Maximum value.
# HIERARCH ESO INS TEMP18 MEAN = 17.016333 / Average value.
# HIERARCH ESO INS TEMP18 MIN = 17.016000 / Minimum value.
# HIERARCH ESO INS TEMP18 NAME = 'Opt. Bench bottom-left' / Temperature sensor nam
# HIERARCH ESO INS TEMP18 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP18 VAL = 17.016 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP19 ID = 'PA2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP19 NAME = 'Opt. Bench Spare 1' / Temperature sensor name.
# HIERARCH ESO INS TEMP19 VAL = 17.034 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP2 ID = 'IODS    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP2 NAME = 'Iodine cell temperature' / Temperature sensor na
# HIERARCH ESO INS TEMP2 VAL = 9999.000 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP20 ID = 'PA1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP20 NAME = 'VV inside Spare 1 - not conn.' / Temperature sen
# HIERARCH ESO INS TEMP20 VAL = 17.009 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP21 DETCOEF = -0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP21 GRAD = -0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP21 ID = 'PB101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP21 LRCONST = 17.022000 / Linear regression constant.
# HIERARCH ESO INS TEMP21 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP21 MAX = 17.022000 / Maximum value.
# HIERARCH ESO INS TEMP21 MEAN = 17.022000 / Average value.
# HIERARCH ESO INS TEMP21 MIN = 17.022000 / Minimum value.
# HIERARCH ESO INS TEMP21 NAME = 'Fiber Exit' / Temperature sensor name.
# HIERARCH ESO INS TEMP21 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP21 VAL = 17.022 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP22 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP22 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP22 ID = 'PB102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP22 LRCONST = 17.111333 / Linear regression constant.
# HIERARCH ESO INS TEMP22 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP22 MAX = 17.111000 / Maximum value.
# HIERARCH ESO INS TEMP22 MEAN = 17.110333 / Average value.
# HIERARCH ESO INS TEMP22 MIN = 17.110000 / Minimum value.
# HIERARCH ESO INS TEMP22 NAME = 'Collimator' / Temperature sensor name.
# HIERARCH ESO INS TEMP22 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP22 VAL = 17.110 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP23 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP23 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP23 ID = 'PB103   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP23 LRCONST = 17.051667 / Linear regression constant.
# HIERARCH ESO INS TEMP23 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP23 MAX = 17.051000 / Maximum value.
# HIERARCH ESO INS TEMP23 MEAN = 17.050667 / Average value.
# HIERARCH ESO INS TEMP23 MIN = 17.050000 / Minimum value.
# HIERARCH ESO INS TEMP23 NAME = 'Echelle Grating' / Temperature sensor name.
# HIERARCH ESO INS TEMP23 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP23 VAL = 17.051 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP24 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP24 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP24 ID = 'PB104   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP24 LRCONST = 17.066000 / Linear regression constant.
# HIERARCH ESO INS TEMP24 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP24 MAX = 17.066000 / Maximum value.
# HIERARCH ESO INS TEMP24 MEAN = 17.066000 / Average value.
# HIERARCH ESO INS TEMP24 MIN = 17.066000 / Minimum value.
# HIERARCH ESO INS TEMP24 NAME = 'Grism   ' / Temperature sensor name.
# HIERARCH ESO INS TEMP24 RMS = 0.000000 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP24 VAL = 17.066 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP25 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP25 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP25 ID = 'PB105   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP25 LRCONST = 17.027333 / Linear regression constant.
# HIERARCH ESO INS TEMP25 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP25 MAX = 17.027000 / Maximum value.
# HIERARCH ESO INS TEMP25 MEAN = 17.026333 / Average value.
# HIERARCH ESO INS TEMP25 MIN = 17.026000 / Minimum value.
# HIERARCH ESO INS TEMP25 NAME = 'Camera Optics Detector side' / Temperature senso
# HIERARCH ESO INS TEMP25 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP25 VAL = 17.027 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP26 DETCOEF = 1.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP26 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP26 ID = 'PB106   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP26 LRCONST = 16.826000 / Linear regression constant.
# HIERARCH ESO INS TEMP26 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP26 MAX = 16.829000 / Maximum value.
# HIERARCH ESO INS TEMP26 MEAN = 16.828000 / Average value.
# HIERARCH ESO INS TEMP26 MIN = 16.827000 / Minimum value.
# HIERARCH ESO INS TEMP26 NAME = 'Camera Optics Collimator side' / Temperature sen
# HIERARCH ESO INS TEMP26 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP26 VAL = 16.827 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP27 DETCOEF = 0.250000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP27 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP27 ID = 'PB107   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP27 LRCONST = 16.158000 / Linear regression constant.
# HIERARCH ESO INS TEMP27 LRRMS = 0.000707 / Linear regression RMS.
# HIERARCH ESO INS TEMP27 MAX = 16.160000 / Maximum value.
# HIERARCH ESO INS TEMP27 MEAN = 16.159000 / Average value.
# HIERARCH ESO INS TEMP27 MIN = 16.158000 / Minimum value.
# HIERARCH ESO INS TEMP27 NAME = 'Detector-Head body back' / Temperature sensor na
# HIERARCH ESO INS TEMP27 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP27 VAL = 16.160 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP28 DETCOEF = 0.964286 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP28 GRAD = -0.000003 / Linear regression slope.
# HIERARCH ESO INS TEMP28 ID = 'PB108   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP28 LRCONST = 16.354333 / Linear regression constant.
# HIERARCH ESO INS TEMP28 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP28 MAX = 16.353000 / Maximum value.
# HIERARCH ESO INS TEMP28 MEAN = 16.351333 / Average value.
# HIERARCH ESO INS TEMP28 MIN = 16.350000 / Minimum value.
# HIERARCH ESO INS TEMP28 NAME = 'Detector-Head holding ring' / Temperature sensor
# HIERARCH ESO INS TEMP28 RMS = 0.001247 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP28 VAL = 16.352 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP29 DETCOEF = 0.428571 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP29 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP29 ID = 'PB209   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP29 LRCONST = 15.192667 / Linear regression constant.
# HIERARCH ESO INS TEMP29 LRRMS = 0.000943 / Linear regression RMS.
# HIERARCH ESO INS TEMP29 MAX = 15.196000 / Maximum value.
# HIERARCH ESO INS TEMP29 MEAN = 15.194667 / Average value.
# HIERARCH ESO INS TEMP29 MIN = 15.193000 / Minimum value.
# HIERARCH ESO INS TEMP29 NAME = 'VV outside Foot S2' / Temperature sensor name.
# HIERARCH ESO INS TEMP29 RMS = 0.001247 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP29 VAL = 15.193 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP3 DETCOEF = 0.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP3 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP3 ID = 'PA101   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP3 LRCONST = 17.107333 / Linear regression constant.
# HIERARCH ESO INS TEMP3 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP3 MAX = 17.108000 / Maximum value.
# HIERARCH ESO INS TEMP3 MEAN = 17.107333 / Average value.
# HIERARCH ESO INS TEMP3 MIN = 17.107000 / Minimum value.
# HIERARCH ESO INS TEMP3 NAME = 'VV inside top' / Temperature sensor name.
# HIERARCH ESO INS TEMP3 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP3 VAL = 17.107 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP30 DETCOEF = 0.847990 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP30 GRAD = 0.000013 / Linear regression slope.
# HIERARCH ESO INS TEMP30 ID = 'PB210   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP30 LRCONST = 14.156333 / Linear regression constant.
# HIERARCH ESO INS TEMP30 LRRMS = 0.002593 / Linear regression RMS.
# HIERARCH ESO INS TEMP30 MAX = 14.177000 / Maximum value.
# HIERARCH ESO INS TEMP30 MEAN = 14.171333 / Average value.
# HIERARCH ESO INS TEMP30 MIN = 14.162000 / Minimum value.
# HIERARCH ESO INS TEMP30 NAME = 'Air-Coude room W' / Temperature sensor name.
# HIERARCH ESO INS TEMP30 RMS = 0.006650 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP30 VAL = 14.163 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP31 DETCOEF = 0.057692 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP31 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP31 ID = 'PB211   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP31 LRCONST = 15.368667 / Linear regression constant.
# HIERARCH ESO INS TEMP31 LRRMS = 0.001650 / Linear regression RMS.
# HIERARCH ESO INS TEMP31 MAX = 15.370000 / Maximum value.
# HIERARCH ESO INS TEMP31 MEAN = 15.367667 / Average value.
# HIERARCH ESO INS TEMP31 MIN = 15.366000 / Minimum value.
# HIERARCH ESO INS TEMP31 NAME = 'Air-HARPS Enclosure' / Temperature sensor name.
# HIERARCH ESO INS TEMP31 RMS = 0.001700 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP31 VAL = 15.365 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP32 DETCOEF = 0.182432 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP32 GRAD = -0.000005 / Linear regression slope.
# HIERARCH ESO INS TEMP32 ID = 'PB212   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP32 LRCONST = 17.068333 / Linear regression constant.
# HIERARCH ESO INS TEMP32 LRRMS = 0.005185 / Linear regression RMS.
# HIERARCH ESO INS TEMP32 MAX = 17.069000 / Maximum value.
# HIERARCH ESO INS TEMP32 MEAN = 17.062333 / Average value.
# HIERARCH ESO INS TEMP32 MIN = 17.055000 / Minimum value.
# HIERARCH ESO INS TEMP32 NAME = 'Air-HARPS Isolation Box' / Temperature sensor na
# HIERARCH ESO INS TEMP32 RMS = 0.005735 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP32 VAL = 17.064 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP33 DETCOEF = 0.382653 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP33 GRAD = -0.000004 / Linear regression slope.
# HIERARCH ESO INS TEMP33 ID = 'PB213   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP33 LRCONST = 17.360333 / Linear regression constant.
# HIERARCH ESO INS TEMP33 LRRMS = 0.002593 / Linear regression RMS.
# HIERARCH ESO INS TEMP33 MAX = 17.359000 / Maximum value.
# HIERARCH ESO INS TEMP33 MEAN = 17.355333 / Average value.
# HIERARCH ESO INS TEMP33 MIN = 17.351000 / Minimum value.
# HIERARCH ESO INS TEMP33 NAME = 'Air-through Fan 4 IB' / Temperature sensor name.
# HIERARCH ESO INS TEMP33 RMS = 0.003300 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP33 VAL = 17.358 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP34 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP34 GRAD = -0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP34 ID = 'PB214   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP34 LRCONST = 17.025667 / Linear regression constant.
# HIERARCH ESO INS TEMP34 LRRMS = 0.000236 / Linear regression RMS.
# HIERARCH ESO INS TEMP34 MAX = 17.025000 / Maximum value.
# HIERARCH ESO INS TEMP34 MEAN = 17.024667 / Average value.
# HIERARCH ESO INS TEMP34 MIN = 17.024000 / Minimum value.
# HIERARCH ESO INS TEMP34 NAME = 'Image Scrambler outside VV' / Temperature sensor
# HIERARCH ESO INS TEMP34 RMS = 0.000471 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP34 VAL = 17.026 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP35 DETCOEF = 0.009174 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP35 GRAD = -0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP35 ID = 'PB215   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP35 LRCONST = 16.564000 / Linear regression constant.
# HIERARCH ESO INS TEMP35 LRRMS = 0.008485 / Linear regression RMS.
# HIERARCH ESO INS TEMP35 MAX = 16.569000 / Maximum value.
# HIERARCH ESO INS TEMP35 MEAN = 16.562000 / Average value.
# HIERARCH ESO INS TEMP35 MIN = 16.550000 / Minimum value.
# HIERARCH ESO INS TEMP35 NAME = 'CFC outside VV' / Temperature sensor name.
# HIERARCH ESO INS TEMP35 RMS = 0.008524 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP35 VAL = 16.553 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP36 DETCOEF = 0.750000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP36 GRAD = -0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP36 ID = 'PB216   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP36 LRCONST = 17.051667 / Linear regression constant.
# HIERARCH ESO INS TEMP36 LRRMS = 0.000471 / Linear regression RMS.
# HIERARCH ESO INS TEMP36 MAX = 17.051000 / Maximum value.
# HIERARCH ESO INS TEMP36 MEAN = 17.049667 / Average value.
# HIERARCH ESO INS TEMP36 MIN = 17.049000 / Minimum value.
# HIERARCH ESO INS TEMP36 NAME = 'VV outside Detector side' / Temperature sensor n
# HIERARCH ESO INS TEMP36 RMS = 0.000943 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP36 VAL = 17.049 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP37 DETCOEF = 1.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP37 GRAD = 0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP37 ID = 'PB2RA   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP37 LRCONST = 17.155000 / Linear regression constant.
# HIERARCH ESO INS TEMP37 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP37 MAX = 17.158000 / Maximum value.
# HIERARCH ESO INS TEMP37 MEAN = 17.157000 / Average value.
# HIERARCH ESO INS TEMP37 MIN = 17.156000 / Minimum value.
# HIERARCH ESO INS TEMP37 NAME = 'VV outside Collimator side' / Temperature sensor
# HIERARCH ESO INS TEMP37 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP37 VAL = 17.158 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP38 ID = 'PB1RB   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP38 NAME = 'Spectrograph Spare 2' / Temperature sensor name.
# HIERARCH ESO INS TEMP38 VAL = 17.058 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP4 DETCOEF = 1.000000 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP4 GRAD = -0.000002 / Linear regression slope.
# HIERARCH ESO INS TEMP4 ID = 'PA102   ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP4 LRCONST = 16.962000 / Linear regression constant.
# HIERARCH ESO INS TEMP4 LRRMS = 0.000000 / Linear regression RMS.
# HIERARCH ESO INS TEMP4 MAX = 16.961000 / Maximum value.
# HIERARCH ESO INS TEMP4 MEAN = 16.960000 / Average value.
# HIERARCH ESO INS TEMP4 MIN = 16.959000 / Minimum value.
# HIERARCH ESO INS TEMP4 NAME = 'VV inside bottom' / Temperature sensor name.
# HIERARCH ESO INS TEMP4 RMS = 0.000816 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP4 VAL = 16.959 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP40 DETCOEF = 0.051421 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP40 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP40 ID = 'CCD1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP40 LRCONST = 148.149107 / Linear regression constant.
# HIERARCH ESO INS TEMP40 LRRMS = 0.002498 / Linear regression RMS.
# HIERARCH ESO INS TEMP40 MAX = 148.160000 / Maximum value.
# HIERARCH ESO INS TEMP40 MEAN = 148.150115 / Average value.
# HIERARCH ESO INS TEMP40 MIN = 148.140000 / Minimum value.
# HIERARCH ESO INS TEMP40 NAME = 'CCD control reference' / Temperature sensor name
# HIERARCH ESO INS TEMP40 RMS = 0.002565 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP40 VAL = 148.150 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP41 DETCOEF = 0.001002 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP41 GRAD = 0.000000 / Linear regression slope.
# HIERARCH ESO INS TEMP41 ID = 'CCD2    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP41 LRCONST = 148.216865 / Linear regression constant.
# HIERARCH ESO INS TEMP41 LRRMS = 0.004529 / Linear regression RMS.
# HIERARCH ESO INS TEMP41 MAX = 148.220000 / Maximum value.
# HIERARCH ESO INS TEMP41 MEAN = 148.217113 / Average value.
# HIERARCH ESO INS TEMP41 MIN = 148.210000 / Minimum value.
# HIERARCH ESO INS TEMP41 NAME = 'CCD secondary' / Temperature sensor name.
# HIERARCH ESO INS TEMP41 RMS = 0.004532 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP41 VAL = 148.220 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP42 DETCOEF = 0.074412 / RMS of linear regression slope.
# HIERARCH ESO INS TEMP42 GRAD = 0.000001 / Linear regression slope.
# HIERARCH ESO INS TEMP42 ID = 'IBX1    ' / Temperature sensor ID.
# HIERARCH ESO INS TEMP42 LRCONST = 17.003661 / Linear regression constant.
# HIERARCH ESO INS TEMP42 LRRMS = 0.001269 / Linear regression RMS.
# HIERARCH ESO INS TEMP42 MAX = 17.007000 / Maximum value.
# HIERARCH ESO INS TEMP42 MEAN = 17.004284 / Average value.
# HIERARCH ESO INS TEMP42 MIN = 17.001000 / Minimum value.
# HIERARCH ESO INS TEMP42 NAME = 'Isolation box control reference' / Temperature s
# HIERARCH ESO INS TEMP42 RMS = 0.001319 / RMS of samples over exposure.
# HIERARCH ESO INS TEMP42 VAL = 17.005 / Temperature sensor numeric value.
# HIERARCH ESO INS TEMP43 DETCOEF = 0.047284 / RMS of linear regression slope.
# ...
# HIERARCH ESO DRS CAL TH COEFF LL144 = 3.76922186505809E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG LL = 4 / degre polyn fit ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL339 = -1.84630648248589E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL96 = 0.0136909317566811 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL97 = -4.68626889164072E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL94 = 1.04471331622073E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL95 = 4285.32025375579 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL92 = -4.64029294117863E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL93 = -1.33154551236626E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL90 = 4255.36177386829 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL91 = 0.0135920674581055 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL98 = -1.15393726907202E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL99 = 1.08975121371545E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X243 = -0.142110254322499 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X242 = 1156.76580155865 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X241 = -4185249.32708789 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X240 = 5678858398.97543 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X247 = 1330.82933199473 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X246 = -4863969.54383366 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X245 = 6666860622.83897 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X244 = 6.54758069055873E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X320 = 5495506743.19763 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X321 = -3472105.80186515 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X249 = 7.38183406177135E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X248 = -0.161847957159778 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X324 = 3.42242523937542E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X325 = 5450142525.42774 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X326 = -3407663.08827207 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X277 = 1020.28124260116 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X322 = 822.702803306327 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL310 = 6208.55891039254 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X323 = -0.0866463077835806 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL219 = 2.05264157201318E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL218 = -2.54316803686393E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL217 = -5.60274346417895E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL216 = 0.0164979812907276 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL215 = 5156.64411280885 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL188 = 1.63884084837766E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL213 = -3.73525648276121E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL212 = -5.53101415499339E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL211 = 0.0163568191082601 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL210 = 5113.32361988844 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X48 = -0.314363478095099 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X49 = 1.96719443299959E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X40 = 5063144332.94031 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X41 = -5101148.73413319 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X42 = 1927.44312637187 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X43 = -0.323708244967209 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X44 = 2.03894147379107E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X45 = 5014282482.85574 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X46 = -5019024.88984528 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X47 = 1884.06635360596 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X188 = -0.211919913463367 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X189 = 1.08028661980956E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X184 = 9.6966603768725E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X185 = 6252599093.44906 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X186 = -5098447.18152094 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X187 = 1559.11370924572 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X180 = 5414764784.82861 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X181 = -4454958.04743135 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X182 = 1374.58814142668 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL182 = -5.3167294970123E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL356 = 0.02189954702572 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL357 = -7.46285411620852E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL354 = 2.12525493501522E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL355 = 6836.13314490746 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL352 = -7.39839325952946E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL181 = 0.0155699235903227 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL350 = 6760.2035720979 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL351 = 0.0216617428557828 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL358 = -1.86675529042578E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL359 = 1.29170997812844E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL323 = -3.66229827433795E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL322 = -6.88018370311982E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL321 = 0.0203016943090801 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL320 = 6337.8541254988 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL327 = -7.00791949634533E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL326 = 0.0205226937746258 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL325 = 6404.53941034583 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL324 = 3.54097307671345E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL329 = 1.79507073014117E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL328 = -1.9965505593037E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X287 = 1024.07176233814 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X286 = -4030701.89532704 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X119 = 1.44516133168296E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X118 = -0.25450007288436 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X113 = -0.247579305222094 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X112 = 1623.04505714199 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X111 = -4729395.70156963 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X110 = 5168291297.59674 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X117 = 1680.87877964572 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X116 = -4934486.39953231 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X115 = 5432657128.41674 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X114 = 1.41637106006747E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH LITTROW ONE MEAN = 0.0386618380061789 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH LITTROW THREE MAXDEV = 50.8208129378529 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF LL168 = -4.31332128792243E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL107 = -4.74878915187691E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL106 = 0.0138873850808408 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL105 = 4346.52275414046 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL104 = 1.38305312370887E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL103 = -6.28113955314111E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL102 = -4.72622575573275E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL101 = 0.0137887821810509 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL100 = 4315.70455901604 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH ORDER NRED = 26 / nb red orders
# HIERARCH ESO DRS CAL TH COEFF LL109 = 5.73325716206211E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL108 = -1.03327673730226E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL166 = 0.0151942785825433 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X280 = 5311500691.62962 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL198 = -1.08672613255551E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL199 = 2.41550411914707E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL194 = 1.70804631063633E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL195 = 4987.62164172303 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL196 = 0.0159558231321945 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH DEG X = 4 / degre polyn fit x(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL190 = 4947.08357829584 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL191 = 0.0158247171549042 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL192 = -5.39549686765253E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL193 = -1.93495426250082E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X209 = 8.55253589958102E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X208 = -0.173258310439972 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X207 = 1316.34459925535 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X206 = -4445307.6355425 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X205 = 5629873543.34795 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X204 = 8.71989244996136E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X203 = -0.175167140640831 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X202 = 1319.68624349407 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X201 = -4419219.33833855 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X200 = 5549898729.97321 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X99 = 1.73455601846298E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X98 = -0.297036561925113 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X93 = -0.307984585682988 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X92 = 1964.3168324925 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X91 = -5568650.38946008 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X90 = 5920417894.04541 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X97 = 1907.68776253927 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X96 = -5445791.37008789 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X95 = 5830141355.4206 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X94 = 1.81101350324247E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X281 = -3636093.62181023 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH FILE LINES = 'TH_sel_R100000_A0.5-0.25-0.1.dat' / file n
# HIERARCH ESO DRS CAL TH COEFF LL74 = 3.85255505287314E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL75 = 4167.94736126159 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL76 = 0.0133054133764744 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL77 = -4.49983671965686E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL70 = 4139.60192797026 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL71 = 0.0132124023781681 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL72 = -4.45611972851843E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL73 = -3.4846286746005E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL78 = -2.9085058171418E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL79 = 2.92617384166493E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF X278 = -0.117493259899946 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X279 = 5.07436980841145E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X272 = 997.474824933856 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X273 = -0.116004953003304 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X270 = 5464254948.02384 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X271 = -3812274.56600102 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X276 = -3938069.47777562 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X19 = 2.63860913951147E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X274 = 5.05973452274465E-06 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X275 = 5700478613.94391 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF LL240 = 5432.76859570304 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL241 = 0.0173891970314364 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL242 = -5.93408557814393E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL243 = -7.55162214180308E-13 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL244 = -6.98323776148617E-17 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL245 = 5481.68124024954 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL246 = 0.0175810139362413 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL247 = -6.25161161455252E-07 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL248 = 6.97177879501947E-12 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH COEFF LL249 = -8.35360964601865E-16 / coeff ll(x,order)
# HIERARCH ESO DRS CAL TH LITTROW THREE RMS = 25.5264413008907 / Littrow  (m/s)
# HIERARCH ESO DRS CAL TH COEFF X71 = -4966260.60477139 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X70 = 5131304998.48094 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X73 = -0.290819621045696 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X72 = 1802.59123690422 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X75 = 5326156368.10823 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X74 = 1.75966092868292E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X77 = 1844.90683766842 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X76 = -5118722.21131658 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X79 = 1.77579595938607E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X78 = -0.295559526932485 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X157 = 1538.7785163356 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X156 = -4796582.83951593 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X155 = 5607281442.92587 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X154 = 1.11442757592722E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X153 = -0.206678175756572 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X152 = 1437.52709319681 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X151 = -4444224.58866658 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X150 = 5152783602.5958 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X159 = 1.1734220032898E-05 / coeff x=(ll,order)
# HIERARCH ESO DRS CAL TH COEFF X158 = -0.219420390767916 / coeff x=(ll,order)
# ARCFILE = 'ADP.2014-10-07T13:37:18.583.fits' / Archive File Name
# P3ORIG  = 'IDP     '           / ESO internal data product
# HDRVER  = '2014-10-07T15:00:12.249' / ESO Archive header timetag
# COMMENT processed by hotfly version 2.0 on 2025-04-26T17:10:39.190 UT

# %%
fits.info(fname)
# Out:
# Filename: ../../Type2/2dFS471/ADP.2014-10-07T13:37:18.583.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU    3357   ()
#   1  SPECTRUM      1 BinTableHDU     45   1R x 3C   [313155D, 313155E, 313155E]

# %%
#plt.figure(figsize=(20,20))
#plt.imshow(fits.getdata(fname3).T[600:800],norm='log',vmin=200,aspect=10)
xd = fits.getdata(fname)
xd
# Out:
# FITS_rec([([3781.45, 3781.46, 3781.47, ..., 6912.97, 6912.98, 6912.99], [ 4.27932816e+01,  3.19139633e+01, -2.36646328e+01, ...,  3.07093811e+01, -1.56325424e+00, -9.01970148e-01], [nan, nan, nan, ..., nan, nan, nan])],
#          dtype=(numpy.record, [('WAVE', '>f8', (313155,)), ('FLUX', '>f4', (313155,)), ('ERR', '>f4', (313155,))]))

# %%
plt.figure(figsize=(15,4))
plt.plot(xd['WAVE'][0],xd['FLUX'][0],'.-')
#plt.ylim(-.1,1)
plt.xlim(6500,6600)
plt.axvline(x=6562.8)
plt.margins(x=0)
